# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# %%
# Function to generate device locations
def generate_device_locations(device_count, bs_location, bs_radius):
  device_locations_polar = np.column_stack([bs_radius * np.sqrt(np.random.rand(device_count)), 2 * np.pi * np.random.rand(device_count)])
  rD = device_locations_polar[:, 0]
  thetaD = device_locations_polar[:, 1]
  device_locations = np.column_stack([bs_location[0] + rD * np.cos(thetaD), bs_location[1] + rD * np.sin(thetaD)])
  return device_locations, rD, thetaD

# %%
# Function to generate event locations
def generate_event_locations(event_count, bs_location, bs_radius):
  event_locations_polar = np.column_stack([bs_radius * np.sqrt(np.random.rand(event_count)), 2 * np.pi * np.random.rand(event_count)])
  rE = event_locations_polar[:, 0]
  thetaE = event_locations_polar[:, 1]
  event_locations = np.column_stack([bs_location[0] + rE * np.cos(thetaE), bs_location[1] + rE * np.sin(thetaE)])
  return event_locations, rE, thetaE

# %%
# Function to calculate device probabilities based on event locations
def calculate_device_probabilities(device_count, event_count, xD, yD, xE, yE, k):
  device_probabilities = np.zeros(device_count)  # Initialize as a 1D array of zeros for each device
  for d in range(device_count):
    device_x_cord = xD[d]
    device_y_cord = yD[d]
    probMult = 1
    for e in range(event_count):
      event_x_cord = xE[e]
      event_y_cord = yE[e]
      probMult *= (1 - np.exp(-np.sqrt((device_x_cord - event_x_cord) ** 2 + (device_y_cord - event_y_cord) ** 2) / k))
    device_probabilities[d] = 1 - probMult
  return device_probabilities

# %%
# Function to generate device alarm status
def generate_device_alarm_status(device_count, device_probabilities):
  random_numbers = np.random.rand(device_count)
  alarm_status = random_numbers < device_probabilities
  return alarm_status

# %%
# Function to generate device transmission status
def generate_device_transmission_status(device_count, device_alarm_status):
  transmission_probability = np.zeros(device_count)
  transmission_probability[device_alarm_status] = 1
  random_numbers = np.random.rand(device_count)
  device_status = random_numbers < transmission_probability
  return device_status

# %%
def modeling(device_count, event_count, bs_location, bs_radius, k, sparsity, num_samples):
  # Preallocate fixed-size NumPy arrays
  all_EventCount = np.zeros(num_samples, dtype=int)
  all_DeviceActiveCount = np.zeros(num_samples, dtype=int)
  all_DeviceProbability = np.zeros((num_samples, device_count), dtype=float)
  all_DeviceAlarmStatus = np.zeros((num_samples, device_count), dtype=bool)
  all_DeviceStatus = np.zeros((num_samples, device_count), dtype=bool)
  all_DeviceLocations = np.zeros((num_samples, device_count, 2), dtype=float)
  all_DeviceLocationsPolar = np.zeros((num_samples, device_count, 2), dtype=float)
  all_EventLocations = np.zeros((num_samples, event_count, 2), dtype=float)
  all_EventLocationsPolar = np.zeros((num_samples, event_count, 2), dtype=float)

  total_samples = 0
  sample_index = 0
  device_active_mean = 0.0

  while sample_index < num_samples:
    total_samples += 1

    device_active_count = sparsity

    # Generate device locations
    device_locations, rD, thetaD = generate_device_locations(device_count, bs_location, bs_radius)
    xD, yD = device_locations[:, 0], device_locations[:, 1]

    # Generate device alarm and transmission status
    active_indices = np.random.choice(device_count, device_active_count, replace=False)
    device_alarm_status = np.zeros(device_count, dtype=bool)
    device_status = np.zeros(device_count, dtype=bool)
    device_alarm_status[active_indices] = True
    device_status[active_indices] = True

    # Running average update for device_active_mean
    device_active_mean += (device_active_count - device_active_mean) / total_samples

    print(f'Sample = {sample_index + 1}, Event Count = {event_count}, Active Devices = {device_active_count}, Mean = {device_active_mean:.3f}')

    if device_active_count == sparsity:
      # Store results in preallocated NumPy arrays
      all_EventCount[sample_index] = event_count
      all_DeviceActiveCount[sample_index] = device_active_count
      all_DeviceProbability[sample_index] = all_DeviceProbability[sample_index]
      all_DeviceAlarmStatus[sample_index] = device_alarm_status
      all_DeviceStatus[sample_index] = device_status
      all_DeviceLocations[sample_index] = device_locations
      all_DeviceLocationsPolar[sample_index] = np.column_stack([rD, thetaD])
      all_EventLocations[sample_index] = all_EventLocations[sample_index]
      all_EventLocationsPolar[sample_index] = all_EventLocationsPolar[sample_index]

      sample_index += 1  # Move to the next sample
      print(f'Sample {sample_index} completed')

  # Mount Google Drive and save data
  drive.mount('/content/drive')
  np.savez_compressed('/content/drive/My Drive/Github/mtc-device-activation/e4_general_model_uncorrelated.npz',
    all_EventCount=all_EventCount,
    all_DeviceActiveCount=all_DeviceActiveCount,
    all_DeviceProbability=all_DeviceProbability,
    all_DeviceAlarmStatus=all_DeviceAlarmStatus,
    all_DeviceStatus=all_DeviceStatus,
    all_DeviceLocations=all_DeviceLocations,
    all_DeviceLocationsPolar=all_DeviceLocationsPolar,
    all_EventLocations=all_EventLocations,
    all_EventLocationsPolar=all_EventLocationsPolar,
    device_count=device_count,
    event_count=event_count,
    bs_location=bs_location,
    bs_radius=bs_radius,
    k=k,
    sparsity=sparsity,
    num_samples=num_samples
  )

  print('Saved to Google Drive')

# %%
# Run the modeling with parameters
modeling(device_count=400,
        event_count=4,
        bs_location=np.array([60, 60]) / 2,
        bs_radius=20,
        k=1.7,
        sparsity=20,
        num_samples=1000)
# Out:
# Sample = 1, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 1 completed
# Sample = 2, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 2 completed
# Sample = 3, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 3 completed
# Sample = 4, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 4 completed
# Sample = 5, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 5 completed
# Sample = 6, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 6 completed
# Sample = 7, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 7 completed
# Sample = 8, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 8 completed
# Sample = 9, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 9 completed
# Sample = 10, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 10 completed
# Sample = 11, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 11 completed
# Sample = 12, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 12 completed
# Sample = 13, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 13 completed
# Sample = 14, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 14 completed
# Sample = 15, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 15 completed
# Sample = 16, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 16 completed
# Sample = 17, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 17 completed
# Sample = 18, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 18 completed
# Sample = 19, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 19 completed
# Sample = 20, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 20 completed
# Sample = 21, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 21 completed
# Sample = 22, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 22 completed
# Sample = 23, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 23 completed
# Sample = 24, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 24 completed
# Sample = 25, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 25 completed
# Sample = 26, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 26 completed
# Sample = 27, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 27 completed
# Sample = 28, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 28 completed
# Sample = 29, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 29 completed
# Sample = 30, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 30 completed
# Sample = 31, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 31 completed
# Sample = 32, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 32 completed
# Sample = 33, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 33 completed
# Sample = 34, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 34 completed
# Sample = 35, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 35 completed
# Sample = 36, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 36 completed
# Sample = 37, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 37 completed
# Sample = 38, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 38 completed
# Sample = 39, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 39 completed
# Sample = 40, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 40 completed
# Sample = 41, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 41 completed
# Sample = 42, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 42 completed
# Sample = 43, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 43 completed
# Sample = 44, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 44 completed
# Sample = 45, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 45 completed
# Sample = 46, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 46 completed
# Sample = 47, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 47 completed
# Sample = 48, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 48 completed
# Sample = 49, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 49 completed
# Sample = 50, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 50 completed
# Sample = 51, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 51 completed
# Sample = 52, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 52 completed
# Sample = 53, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 53 completed
# Sample = 54, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 54 completed
# Sample = 55, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 55 completed
# Sample = 56, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 56 completed
# Sample = 57, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 57 completed
# Sample = 58, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 58 completed
# Sample = 59, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 59 completed
# Sample = 60, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 60 completed
# Sample = 61, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 61 completed
# Sample = 62, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 62 completed
# Sample = 63, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 63 completed
# Sample = 64, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 64 completed
# Sample = 65, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 65 completed
# Sample = 66, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 66 completed
# Sample = 67, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 67 completed
# Sample = 68, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 68 completed
# Sample = 69, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 69 completed
# Sample = 70, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 70 completed
# Sample = 71, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 71 completed
# Sample = 72, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 72 completed
# Sample = 73, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 73 completed
# Sample = 74, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 74 completed
# Sample = 75, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 75 completed
# Sample = 76, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 76 completed
# Sample = 77, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 77 completed
# Sample = 78, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 78 completed
# Sample = 79, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 79 completed
# Sample = 80, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 80 completed
# Sample = 81, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 81 completed
# Sample = 82, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 82 completed
# Sample = 83, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 83 completed
# Sample = 84, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 84 completed
# Sample = 85, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 85 completed
# Sample = 86, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 86 completed
# Sample = 87, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 87 completed
# Sample = 88, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 88 completed
# Sample = 89, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 89 completed
# Sample = 90, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 90 completed
# Sample = 91, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 91 completed
# Sample = 92, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 92 completed
# Sample = 93, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 93 completed
# Sample = 94, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 94 completed
# Sample = 95, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 95 completed
# Sample = 96, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 96 completed
# Sample = 97, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 97 completed
# Sample = 98, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 98 completed
# Sample = 99, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 99 completed
# Sample = 100, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 100 completed
# Sample = 101, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 101 completed
# Sample = 102, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 102 completed
# Sample = 103, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 103 completed
# Sample = 104, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 104 completed
# Sample = 105, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 105 completed
# Sample = 106, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 106 completed
# Sample = 107, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 107 completed
# Sample = 108, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 108 completed
# Sample = 109, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 109 completed
# Sample = 110, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 110 completed
# Sample = 111, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 111 completed
# Sample = 112, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 112 completed
# Sample = 113, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 113 completed
# Sample = 114, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 114 completed
# Sample = 115, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 115 completed
# Sample = 116, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 116 completed
# Sample = 117, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 117 completed
# Sample = 118, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 118 completed
# Sample = 119, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 119 completed
# Sample = 120, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 120 completed
# Sample = 121, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 121 completed
# Sample = 122, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 122 completed
# Sample = 123, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 123 completed
# Sample = 124, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 124 completed
# Sample = 125, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 125 completed
# Sample = 126, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 126 completed
# Sample = 127, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 127 completed
# Sample = 128, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 128 completed
# Sample = 129, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 129 completed
# Sample = 130, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 130 completed
# Sample = 131, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 131 completed
# Sample = 132, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 132 completed
# Sample = 133, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 133 completed
# Sample = 134, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 134 completed
# Sample = 135, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 135 completed
# Sample = 136, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 136 completed
# Sample = 137, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 137 completed
# Sample = 138, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 138 completed
# Sample = 139, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 139 completed
# Sample = 140, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 140 completed
# Sample = 141, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 141 completed
# Sample = 142, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 142 completed
# Sample = 143, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 143 completed
# Sample = 144, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 144 completed
# Sample = 145, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 145 completed
# Sample = 146, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 146 completed
# Sample = 147, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 147 completed
# Sample = 148, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 148 completed
# Sample = 149, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 149 completed
# Sample = 150, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 150 completed
# Sample = 151, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 151 completed
# Sample = 152, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 152 completed
# Sample = 153, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 153 completed
# Sample = 154, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 154 completed
# Sample = 155, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 155 completed
# Sample = 156, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 156 completed
# Sample = 157, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 157 completed
# Sample = 158, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 158 completed
# Sample = 159, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 159 completed
# Sample = 160, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 160 completed
# Sample = 161, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 161 completed
# Sample = 162, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 162 completed
# Sample = 163, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 163 completed
# Sample = 164, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 164 completed
# Sample = 165, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 165 completed
# Sample = 166, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 166 completed
# Sample = 167, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 167 completed
# Sample = 168, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 168 completed
# Sample = 169, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 169 completed
# Sample = 170, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 170 completed
# Sample = 171, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 171 completed
# Sample = 172, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 172 completed
# Sample = 173, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 173 completed
# Sample = 174, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 174 completed
# Sample = 175, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 175 completed
# Sample = 176, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 176 completed
# Sample = 177, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 177 completed
# Sample = 178, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 178 completed
# Sample = 179, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 179 completed
# Sample = 180, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 180 completed
# Sample = 181, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 181 completed
# Sample = 182, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 182 completed
# Sample = 183, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 183 completed
# Sample = 184, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 184 completed
# Sample = 185, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 185 completed
# Sample = 186, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 186 completed
# Sample = 187, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 187 completed
# Sample = 188, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 188 completed
# Sample = 189, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 189 completed
# Sample = 190, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 190 completed
# Sample = 191, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 191 completed
# Sample = 192, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 192 completed
# Sample = 193, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 193 completed
# Sample = 194, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 194 completed
# Sample = 195, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 195 completed
# Sample = 196, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 196 completed
# Sample = 197, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 197 completed
# Sample = 198, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 198 completed
# Sample = 199, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 199 completed
# Sample = 200, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 200 completed
# Sample = 201, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 201 completed
# Sample = 202, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 202 completed
# Sample = 203, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 203 completed
# Sample = 204, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 204 completed
# Sample = 205, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 205 completed
# Sample = 206, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 206 completed
# Sample = 207, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 207 completed
# Sample = 208, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 208 completed
# Sample = 209, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 209 completed
# Sample = 210, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 210 completed
# Sample = 211, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 211 completed
# Sample = 212, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 212 completed
# Sample = 213, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 213 completed
# Sample = 214, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 214 completed
# Sample = 215, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 215 completed
# Sample = 216, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 216 completed
# Sample = 217, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 217 completed
# Sample = 218, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 218 completed
# Sample = 219, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 219 completed
# Sample = 220, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 220 completed
# Sample = 221, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 221 completed
# Sample = 222, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 222 completed
# Sample = 223, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 223 completed
# Sample = 224, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 224 completed
# Sample = 225, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 225 completed
# Sample = 226, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 226 completed
# Sample = 227, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 227 completed
# Sample = 228, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 228 completed
# Sample = 229, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 229 completed
# Sample = 230, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 230 completed
# Sample = 231, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 231 completed
# Sample = 232, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 232 completed
# Sample = 233, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 233 completed
# Sample = 234, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 234 completed
# Sample = 235, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 235 completed
# Sample = 236, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 236 completed
# Sample = 237, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 237 completed
# Sample = 238, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 238 completed
# Sample = 239, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 239 completed
# Sample = 240, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 240 completed
# Sample = 241, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 241 completed
# Sample = 242, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 242 completed
# Sample = 243, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 243 completed
# Sample = 244, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 244 completed
# Sample = 245, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 245 completed
# Sample = 246, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 246 completed
# Sample = 247, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 247 completed
# Sample = 248, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 248 completed
# Sample = 249, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 249 completed
# Sample = 250, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 250 completed
# Sample = 251, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 251 completed
# Sample = 252, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 252 completed
# Sample = 253, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 253 completed
# Sample = 254, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 254 completed
# Sample = 255, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 255 completed
# Sample = 256, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 256 completed
# Sample = 257, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 257 completed
# Sample = 258, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 258 completed
# Sample = 259, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 259 completed
# Sample = 260, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 260 completed
# Sample = 261, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 261 completed
# Sample = 262, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 262 completed
# Sample = 263, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 263 completed
# Sample = 264, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 264 completed
# Sample = 265, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 265 completed
# Sample = 266, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 266 completed
# Sample = 267, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 267 completed
# Sample = 268, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 268 completed
# Sample = 269, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 269 completed
# Sample = 270, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 270 completed
# Sample = 271, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 271 completed
# Sample = 272, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 272 completed
# Sample = 273, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 273 completed
# Sample = 274, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 274 completed
# Sample = 275, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 275 completed
# Sample = 276, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 276 completed
# Sample = 277, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 277 completed
# Sample = 278, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 278 completed
# Sample = 279, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 279 completed
# Sample = 280, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 280 completed
# Sample = 281, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 281 completed
# Sample = 282, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 282 completed
# Sample = 283, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 283 completed
# Sample = 284, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 284 completed
# Sample = 285, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 285 completed
# Sample = 286, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 286 completed
# Sample = 287, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 287 completed
# Sample = 288, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 288 completed
# Sample = 289, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 289 completed
# Sample = 290, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 290 completed
# Sample = 291, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 291 completed
# Sample = 292, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 292 completed
# Sample = 293, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 293 completed
# Sample = 294, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 294 completed
# Sample = 295, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 295 completed
# Sample = 296, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 296 completed
# Sample = 297, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 297 completed
# Sample = 298, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 298 completed
# Sample = 299, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 299 completed
# Sample = 300, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 300 completed
# Sample = 301, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 301 completed
# Sample = 302, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 302 completed
# Sample = 303, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 303 completed
# Sample = 304, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 304 completed
# Sample = 305, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 305 completed
# Sample = 306, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 306 completed
# Sample = 307, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 307 completed
# Sample = 308, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 308 completed
# Sample = 309, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 309 completed
# Sample = 310, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 310 completed
# Sample = 311, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 311 completed
# Sample = 312, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 312 completed
# Sample = 313, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 313 completed
# Sample = 314, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 314 completed
# Sample = 315, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 315 completed
# Sample = 316, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 316 completed
# Sample = 317, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 317 completed
# Sample = 318, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 318 completed
# Sample = 319, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 319 completed
# Sample = 320, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 320 completed
# Sample = 321, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 321 completed
# Sample = 322, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 322 completed
# Sample = 323, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 323 completed
# Sample = 324, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 324 completed
# Sample = 325, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 325 completed
# Sample = 326, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 326 completed
# Sample = 327, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 327 completed
# Sample = 328, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 328 completed
# Sample = 329, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 329 completed
# Sample = 330, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 330 completed
# Sample = 331, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 331 completed
# Sample = 332, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 332 completed
# Sample = 333, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 333 completed
# Sample = 334, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 334 completed
# Sample = 335, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 335 completed
# Sample = 336, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 336 completed
# Sample = 337, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 337 completed
# Sample = 338, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 338 completed
# Sample = 339, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 339 completed
# Sample = 340, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 340 completed
# Sample = 341, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 341 completed
# Sample = 342, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 342 completed
# Sample = 343, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 343 completed
# Sample = 344, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 344 completed
# Sample = 345, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 345 completed
# Sample = 346, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 346 completed
# Sample = 347, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 347 completed
# Sample = 348, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 348 completed
# Sample = 349, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 349 completed
# Sample = 350, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 350 completed
# Sample = 351, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 351 completed
# Sample = 352, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 352 completed
# Sample = 353, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 353 completed
# Sample = 354, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 354 completed
# Sample = 355, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 355 completed
# Sample = 356, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 356 completed
# Sample = 357, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 357 completed
# Sample = 358, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 358 completed
# Sample = 359, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 359 completed
# Sample = 360, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 360 completed
# Sample = 361, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 361 completed
# Sample = 362, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 362 completed
# Sample = 363, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 363 completed
# Sample = 364, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 364 completed
# Sample = 365, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 365 completed
# Sample = 366, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 366 completed
# Sample = 367, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 367 completed
# Sample = 368, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 368 completed
# Sample = 369, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 369 completed
# Sample = 370, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 370 completed
# Sample = 371, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 371 completed
# Sample = 372, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 372 completed
# Sample = 373, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 373 completed
# Sample = 374, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 374 completed
# Sample = 375, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 375 completed
# Sample = 376, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 376 completed
# Sample = 377, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 377 completed
# Sample = 378, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 378 completed
# Sample = 379, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 379 completed
# Sample = 380, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 380 completed
# Sample = 381, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 381 completed
# Sample = 382, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 382 completed
# Sample = 383, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 383 completed
# Sample = 384, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 384 completed
# Sample = 385, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 385 completed
# Sample = 386, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 386 completed
# Sample = 387, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 387 completed
# Sample = 388, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 388 completed
# Sample = 389, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 389 completed
# Sample = 390, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 390 completed
# Sample = 391, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 391 completed
# Sample = 392, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 392 completed
# Sample = 393, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 393 completed
# Sample = 394, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 394 completed
# Sample = 395, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 395 completed
# Sample = 396, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 396 completed
# Sample = 397, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 397 completed
# Sample = 398, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 398 completed
# Sample = 399, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 399 completed
# Sample = 400, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 400 completed
# Sample = 401, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 401 completed
# Sample = 402, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 402 completed
# Sample = 403, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 403 completed
# Sample = 404, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 404 completed
# Sample = 405, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 405 completed
# Sample = 406, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 406 completed
# Sample = 407, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 407 completed
# Sample = 408, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 408 completed
# Sample = 409, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 409 completed
# Sample = 410, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 410 completed
# Sample = 411, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 411 completed
# Sample = 412, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 412 completed
# Sample = 413, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 413 completed
# Sample = 414, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 414 completed
# Sample = 415, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 415 completed
# Sample = 416, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 416 completed
# Sample = 417, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 417 completed
# Sample = 418, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 418 completed
# Sample = 419, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 419 completed
# Sample = 420, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 420 completed
# Sample = 421, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 421 completed
# Sample = 422, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 422 completed
# Sample = 423, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 423 completed
# Sample = 424, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 424 completed
# Sample = 425, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 425 completed
# Sample = 426, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 426 completed
# Sample = 427, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 427 completed
# Sample = 428, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 428 completed
# Sample = 429, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 429 completed
# Sample = 430, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 430 completed
# Sample = 431, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 431 completed
# Sample = 432, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 432 completed
# Sample = 433, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 433 completed
# Sample = 434, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 434 completed
# Sample = 435, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 435 completed
# Sample = 436, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 436 completed
# Sample = 437, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 437 completed
# Sample = 438, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 438 completed
# Sample = 439, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 439 completed
# Sample = 440, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 440 completed
# Sample = 441, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 441 completed
# Sample = 442, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 442 completed
# Sample = 443, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 443 completed
# Sample = 444, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 444 completed
# Sample = 445, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 445 completed
# Sample = 446, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 446 completed
# Sample = 447, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 447 completed
# Sample = 448, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 448 completed
# Sample = 449, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 449 completed
# Sample = 450, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 450 completed
# Sample = 451, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 451 completed
# Sample = 452, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 452 completed
# Sample = 453, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 453 completed
# Sample = 454, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 454 completed
# Sample = 455, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 455 completed
# Sample = 456, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 456 completed
# Sample = 457, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 457 completed
# Sample = 458, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 458 completed
# Sample = 459, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 459 completed
# Sample = 460, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 460 completed
# Sample = 461, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 461 completed
# Sample = 462, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 462 completed
# Sample = 463, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 463 completed
# Sample = 464, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 464 completed
# Sample = 465, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 465 completed
# Sample = 466, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 466 completed
# Sample = 467, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 467 completed
# Sample = 468, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 468 completed
# Sample = 469, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 469 completed
# Sample = 470, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 470 completed
# Sample = 471, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 471 completed
# Sample = 472, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 472 completed
# Sample = 473, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 473 completed
# Sample = 474, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 474 completed
# Sample = 475, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 475 completed
# Sample = 476, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 476 completed
# Sample = 477, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 477 completed
# Sample = 478, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 478 completed
# Sample = 479, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 479 completed
# Sample = 480, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 480 completed
# Sample = 481, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 481 completed
# Sample = 482, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 482 completed
# Sample = 483, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 483 completed
# Sample = 484, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 484 completed
# Sample = 485, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 485 completed
# Sample = 486, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 486 completed
# Sample = 487, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 487 completed
# Sample = 488, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 488 completed
# Sample = 489, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 489 completed
# Sample = 490, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 490 completed
# Sample = 491, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 491 completed
# Sample = 492, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 492 completed
# Sample = 493, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 493 completed
# Sample = 494, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 494 completed
# Sample = 495, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 495 completed
# Sample = 496, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 496 completed
# Sample = 497, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 497 completed
# Sample = 498, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 498 completed
# Sample = 499, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 499 completed
# Sample = 500, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 500 completed
# Sample = 501, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 501 completed
# Sample = 502, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 502 completed
# Sample = 503, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 503 completed
# Sample = 504, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 504 completed
# Sample = 505, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 505 completed
# Sample = 506, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 506 completed
# Sample = 507, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 507 completed
# Sample = 508, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 508 completed
# Sample = 509, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 509 completed
# Sample = 510, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 510 completed
# Sample = 511, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 511 completed
# Sample = 512, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 512 completed
# Sample = 513, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 513 completed
# Sample = 514, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 514 completed
# Sample = 515, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 515 completed
# Sample = 516, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 516 completed
# Sample = 517, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 517 completed
# Sample = 518, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 518 completed
# Sample = 519, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 519 completed
# Sample = 520, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 520 completed
# Sample = 521, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 521 completed
# Sample = 522, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 522 completed
# Sample = 523, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 523 completed
# Sample = 524, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 524 completed
# Sample = 525, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 525 completed
# Sample = 526, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 526 completed
# Sample = 527, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 527 completed
# Sample = 528, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 528 completed
# Sample = 529, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 529 completed
# Sample = 530, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 530 completed
# Sample = 531, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 531 completed
# Sample = 532, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 532 completed
# Sample = 533, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 533 completed
# Sample = 534, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 534 completed
# Sample = 535, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 535 completed
# Sample = 536, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 536 completed
# Sample = 537, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 537 completed
# Sample = 538, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 538 completed
# Sample = 539, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 539 completed
# Sample = 540, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 540 completed
# Sample = 541, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 541 completed
# Sample = 542, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 542 completed
# Sample = 543, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 543 completed
# Sample = 544, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 544 completed
# Sample = 545, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 545 completed
# Sample = 546, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 546 completed
# Sample = 547, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 547 completed
# Sample = 548, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 548 completed
# Sample = 549, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 549 completed
# Sample = 550, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 550 completed
# Sample = 551, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 551 completed
# Sample = 552, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 552 completed
# Sample = 553, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 553 completed
# Sample = 554, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 554 completed
# ...
# Sample 817 completed
# Sample = 818, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 818 completed
# Sample = 819, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 819 completed
# Sample = 820, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 820 completed
# Sample = 821, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 821 completed
# Sample = 822, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 822 completed
# Sample = 823, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 823 completed
# Sample = 824, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 824 completed
# Sample = 825, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 825 completed
# Sample = 826, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 826 completed
# Sample = 827, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 827 completed
# Sample = 828, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 828 completed
# Sample = 829, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 829 completed
# Sample = 830, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 830 completed
# Sample = 831, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 831 completed
# Sample = 832, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 832 completed
# Sample = 833, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 833 completed
# Sample = 834, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 834 completed
# Sample = 835, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 835 completed
# Sample = 836, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 836 completed
# Sample = 837, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 837 completed
# Sample = 838, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 838 completed
# Sample = 839, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 839 completed
# Sample = 840, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 840 completed
# Sample = 841, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 841 completed
# Sample = 842, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 842 completed
# Sample = 843, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 843 completed
# Sample = 844, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 844 completed
# Sample = 845, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 845 completed
# Sample = 846, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 846 completed
# Sample = 847, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 847 completed
# Sample = 848, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 848 completed
# Sample = 849, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 849 completed
# Sample = 850, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 850 completed
# Sample = 851, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 851 completed
# Sample = 852, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 852 completed
# Sample = 853, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 853 completed
# Sample = 854, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 854 completed
# Sample = 855, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 855 completed
# Sample = 856, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 856 completed
# Sample = 857, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 857 completed
# Sample = 858, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 858 completed
# Sample = 859, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 859 completed
# Sample = 860, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 860 completed
# Sample = 861, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 861 completed
# Sample = 862, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 862 completed
# Sample = 863, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 863 completed
# Sample = 864, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 864 completed
# Sample = 865, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 865 completed
# Sample = 866, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 866 completed
# Sample = 867, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 867 completed
# Sample = 868, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 868 completed
# Sample = 869, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 869 completed
# Sample = 870, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 870 completed
# Sample = 871, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 871 completed
# Sample = 872, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 872 completed
# Sample = 873, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 873 completed
# Sample = 874, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 874 completed
# Sample = 875, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 875 completed
# Sample = 876, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 876 completed
# Sample = 877, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 877 completed
# Sample = 878, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 878 completed
# Sample = 879, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 879 completed
# Sample = 880, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 880 completed
# Sample = 881, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 881 completed
# Sample = 882, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 882 completed
# Sample = 883, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 883 completed
# Sample = 884, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 884 completed
# Sample = 885, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 885 completed
# Sample = 886, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 886 completed
# Sample = 887, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 887 completed
# Sample = 888, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 888 completed
# Sample = 889, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 889 completed
# Sample = 890, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 890 completed
# Sample = 891, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 891 completed
# Sample = 892, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 892 completed
# Sample = 893, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 893 completed
# Sample = 894, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 894 completed
# Sample = 895, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 895 completed
# Sample = 896, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 896 completed
# Sample = 897, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 897 completed
# Sample = 898, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 898 completed
# Sample = 899, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 899 completed
# Sample = 900, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 900 completed
# Sample = 901, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 901 completed
# Sample = 902, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 902 completed
# Sample = 903, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 903 completed
# Sample = 904, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 904 completed
# Sample = 905, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 905 completed
# Sample = 906, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 906 completed
# Sample = 907, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 907 completed
# Sample = 908, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 908 completed
# Sample = 909, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 909 completed
# Sample = 910, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 910 completed
# Sample = 911, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 911 completed
# Sample = 912, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 912 completed
# Sample = 913, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 913 completed
# Sample = 914, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 914 completed
# Sample = 915, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 915 completed
# Sample = 916, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 916 completed
# Sample = 917, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 917 completed
# Sample = 918, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 918 completed
# Sample = 919, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 919 completed
# Sample = 920, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 920 completed
# Sample = 921, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 921 completed
# Sample = 922, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 922 completed
# Sample = 923, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 923 completed
# Sample = 924, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 924 completed
# Sample = 925, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 925 completed
# Sample = 926, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 926 completed
# Sample = 927, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 927 completed
# Sample = 928, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 928 completed
# Sample = 929, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 929 completed
# Sample = 930, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 930 completed
# Sample = 931, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 931 completed
# Sample = 932, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 932 completed
# Sample = 933, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 933 completed
# Sample = 934, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 934 completed
# Sample = 935, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 935 completed
# Sample = 936, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 936 completed
# Sample = 937, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 937 completed
# Sample = 938, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 938 completed
# Sample = 939, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 939 completed
# Sample = 940, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 940 completed
# Sample = 941, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 941 completed
# Sample = 942, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 942 completed
# Sample = 943, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 943 completed
# Sample = 944, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 944 completed
# Sample = 945, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 945 completed
# Sample = 946, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 946 completed
# Sample = 947, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 947 completed
# Sample = 948, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 948 completed
# Sample = 949, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 949 completed
# Sample = 950, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 950 completed
# Sample = 951, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 951 completed
# Sample = 952, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 952 completed
# Sample = 953, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 953 completed
# Sample = 954, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 954 completed
# Sample = 955, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 955 completed
# Sample = 956, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 956 completed
# Sample = 957, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 957 completed
# Sample = 958, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 958 completed
# Sample = 959, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 959 completed
# Sample = 960, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 960 completed
# Sample = 961, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 961 completed
# Sample = 962, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 962 completed
# Sample = 963, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 963 completed
# Sample = 964, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 964 completed
# Sample = 965, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 965 completed
# Sample = 966, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 966 completed
# Sample = 967, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 967 completed
# Sample = 968, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 968 completed
# Sample = 969, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 969 completed
# Sample = 970, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 970 completed
# Sample = 971, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 971 completed
# Sample = 972, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 972 completed
# Sample = 973, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 973 completed
# Sample = 974, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 974 completed
# Sample = 975, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 975 completed
# Sample = 976, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 976 completed
# Sample = 977, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 977 completed
# Sample = 978, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 978 completed
# Sample = 979, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 979 completed
# Sample = 980, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 980 completed
# Sample = 981, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 981 completed
# Sample = 982, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 982 completed
# Sample = 983, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 983 completed
# Sample = 984, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 984 completed
# Sample = 985, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 985 completed
# Sample = 986, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 986 completed
# Sample = 987, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 987 completed
# Sample = 988, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 988 completed
# Sample = 989, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 989 completed
# Sample = 990, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 990 completed
# Sample = 991, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 991 completed
# Sample = 992, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 992 completed
# Sample = 993, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 993 completed
# Sample = 994, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 994 completed
# Sample = 995, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 995 completed
# Sample = 996, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 996 completed
# Sample = 997, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 997 completed
# Sample = 998, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 998 completed
# Sample = 999, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 999 completed
# Sample = 1000, Event Count = 4, Active Devices = 20, Mean = 20.000
# Sample 1000 completed
# Mounted at /content/drive
# Saved to Google Drive

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load saved data
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/e4_general_model_uncorrelated.npz', allow_pickle=True)

# Select sample index (modify if needed)
sample_index = 800

# Extract data from the saved file
EventCount = data['all_EventCount'][sample_index]
DeviceActiveCount = data['all_DeviceActiveCount'][sample_index]
DeviceProbability = data['all_DeviceProbability'][sample_index]
DeviceAlarmStatus = data['all_DeviceAlarmStatus'][sample_index]
DeviceStatus = data['all_DeviceStatus'][sample_index].astype(bool)  # Ensure boolean type
DeviceLocations = data['all_DeviceLocations'][sample_index]
DeviceLocationsPolar = data['all_DeviceLocationsPolar'][sample_index]
EventLocations = data['all_EventLocations'][sample_index]
EventLocationsPolar = data['all_EventLocationsPolar'][sample_index]

# Check the shape of the arrays (for debugging purposes)
print(f"DeviceLocations shape: {DeviceLocations.shape}")
print(f"EventLocations shape: {EventLocations.shape}")
print(f"DeviceProbability shape: {DeviceProbability.shape}")
print(f"DeviceStatus shape: {DeviceStatus.shape}")

# Extract X, Y coordinates for devices and events
xD, yD = DeviceLocations[:, 0], DeviceLocations[:, 1]
xE, yE = EventLocations[:, 0], EventLocations[:, 1]

# Load base station location
bs_location = data['bs_location']

# Plotting
plt.figure(figsize=(12, 6))

# **Subplot 1: Device Active Probabilities**
plt.subplot(1, 2, 1)
plt.scatter(xE, yE, color='m', marker='x', label='Events')  # Event locations
plt.scatter(bs_location[0], bs_location[1], color='k', marker='s', label='Base Station')  # Base station
sc = plt.scatter(xD, yD, c=DeviceProbability, cmap='coolwarm', vmin=0, vmax=1, label='Devices')  # Device probabilities
plt.colorbar(sc, label="Activation Probability")  # Color scale
plt.grid(True)
plt.axis('equal')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f'Device Activation Probabilities')
plt.legend()

# **Subplot 2: Device Active States**
plt.subplot(1, 2, 2)
plt.scatter(bs_location[0], bs_location[1], color='k', marker='s', label='Base Station')
# Devices that are inactive
plt.scatter(xD[~DeviceStatus], yD[~DeviceStatus], color='b', label='Inactive Devices')
# Devices that are active
plt.scatter(xD[DeviceStatus], yD[DeviceStatus], color='r', label='Active Devices')
plt.scatter(xE, yE, color='m', marker='x', label='Events')
plt.grid(True)
plt.axis('equal')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f'Device Activation States')
plt.legend()

# **Overall Title**
plt.suptitle(f'Event Count: {EventCount}, Active Devices: {DeviceActiveCount}')

# Show plot
plt.show()
# Out:
# DeviceLocations shape: (400, 2)
# EventLocations shape: (4, 2)
# DeviceProbability shape: (400,)
# DeviceStatus shape: (400,)

# %%
data['all_DeviceStatus'].shape
# Out:
# (1000, 400)
