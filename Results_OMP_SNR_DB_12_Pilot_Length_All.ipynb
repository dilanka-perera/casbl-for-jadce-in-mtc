# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(0, 1000)

# %% [markdown]
# Orthogonal Matching Pursuit (OMP)

# %%
def omp_algorithm(theta, y, sparsity_level, stopping_criterion=1e-4):
    L, N = theta.shape
    _, M = y.shape

    residual = y.copy()
    support = []

    for _ in range(sparsity_level):
        # Step 1: Compute proxy (theta^H * residual)
        proxy = theta.conj().T @ residual  # N x M
        row_energy = np.sum(np.abs(proxy)**2, axis=1)

        # Step 2: Exclude already selected atoms
        row_energy[support] = 0
        idx = np.argmax(row_energy)
        support.append(idx)

        # Step 3: Solve least squares on current support
        theta_s = theta[:, support]  # L x |S|
        x_temp, _, _, _ = np.linalg.lstsq(theta_s, y, rcond=None)  # |S| x M

        # Step 4: Update residual
        residual = y - theta_s @ x_temp

        # Step 5: Early stopping if residual is small
        if np.linalg.norm(residual) < stopping_criterion:
            break

    # Step 6: Final x_hat reconstruction
    x_hat = np.zeros((N, M), dtype=np.complex128)
    for i, idx in enumerate(support):
        x_hat[idx, :] = x_temp[i, :]  # x_temp already correct

    # Step 7: Binary gamma (1 if row is active)
    gamma = (np.linalg.norm(x_hat, axis=1) > 1e-6).astype(int)

    return x_hat, gamma

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = omp_algorithm(theta, received_signal, sparsity)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 34.52it/s]
# Processing Samples:   0%|          | 1/1000 [00:00<03:14,  5.12it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 45.21it/s]
# Processing Samples:   0%|          | 2/1000 [00:00<02:46,  5.98it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 57.30it/s]
# Processing Samples:   0%|          | 3/1000 [00:00<02:26,  6.82it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   0%|          | 4/1000 [00:00<02:10,  7.62it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 40.48it/s]
# Processing Samples:   0%|          | 5/1000 [00:00<02:26,  6.80it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 34.43it/s]
# Processing Samples:   1%|          | 6/1000 [00:00<02:39,  6.24it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:00, 19.29it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:00<00:00, 20.23it/s]
# Processing Samples:   1%|          | 8/1000 [00:01<03:32,  4.66it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 10/1000 [00:01<02:32,  6.48it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 12/1000 [00:01<02:02,  8.08it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:00<00:00, 43.32it/s]
# Processing Samples:   1%|▏         | 14/1000 [00:01<01:58,  8.33it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:00<00:00, 43.78it/s]
# Processing Samples:   2%|▏         | 15/1000 [00:02<02:44,  5.97it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 17/1000 [00:02<02:13,  7.38it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 18/1000 [00:02<02:06,  7.79it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 19/1000 [00:02<02:01,  8.10it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 21/1000 [00:02<01:34, 10.31it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 23/1000 [00:02<01:19, 12.33it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▎         | 25/1000 [00:03<01:12, 13.49it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 27/1000 [00:03<01:07, 14.49it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 29/1000 [00:03<01:03, 15.35it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 31/1000 [00:03<00:58, 16.55it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 33/1000 [00:03<00:56, 17.01it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▎         | 35/1000 [00:03<00:54, 17.81it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▎         | 37/1000 [00:03<00:59, 16.19it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 39/1000 [00:03<01:07, 14.29it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 38.62it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 41/1000 [00:04<01:24, 11.36it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 43/1000 [00:04<01:25, 11.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 25.59it/s]
# Processing Samples:   4%|▍         | 45/1000 [00:04<01:52,  8.50it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.73it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   5%|
/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|██▉       | 297/1000 [00:23<00:50, 13.80it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|██▉       | 299/1000 [00:23<00:47, 14.67it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 301/1000 [00:23<00:49, 14.15it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 303/1000 [00:23<00:50, 13.88it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 305/1000 [00:23<00:48, 14.37it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███       | 307/1000 [00:23<00:47, 14.58it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███       | 309/1000 [00:24<00:48, 14.16it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███       | 311/1000 [00:24<00:49, 13.85it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███▏      | 313/1000 [00:24<00:47, 14.59it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 315/1000 [00:24<00:46, 14.75it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 317/1000 [00:24<00:45, 15.04it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 319/1000 [00:24<00:50, 13.44it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 321/1000 [00:24<00:49, 13.59it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 323/1000 [00:25<00:47, 14.20it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▎      | 325/1000 [00:25<00:47, 14.11it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 327/1000 [00:25<00:47, 14.25it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 329/1000 [00:25<00:46, 14.28it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# ...
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 58.73it/s]
# Processing Samples:  91%|█████████ | 912/1000 [01:27<00:11,  7.48it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 56.24it/s]
# Processing Samples:  91%|█████████▏| 913/1000 [01:27<00:11,  7.79it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 59.26it/s]
# Processing Samples:  91%|█████████▏| 914/1000 [01:27<00:10,  7.98it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 915/1000 [01:27<00:10,  8.30it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 917/1000 [01:27<00:09,  8.96it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 918/1000 [01:28<00:09,  8.96it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 920/1000 [01:28<00:08,  9.78it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 922/1000 [01:28<00:07, 10.08it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 57.49it/s]
# Processing Samples:  92%|█████████▏| 923/1000 [01:28<00:07,  9.73it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 924/1000 [01:28<00:07,  9.65it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 52.87it/s]
# Processing Samples:  92%|█████████▎| 925/1000 [01:28<00:08,  9.18it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 926/1000 [01:28<00:08,  9.23it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 928/1000 [01:29<00:07,  9.56it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 929/1000 [01:29<00:07,  9.54it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 57.36it/s]
# Processing Samples:  93%|█████████▎| 930/1000 [01:29<00:07,  9.25it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 932/1000 [01:29<00:07,  9.49it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 57.22it/s]
# Processing Samples:  93%|█████████▎| 934/1000 [01:29<00:06,  9.45it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▎| 936/1000 [01:29<00:06,  9.85it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 938/1000 [01:30<00:06, 10.05it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 940/1000 [01:30<00:05, 10.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 942/1000 [01:30<00:05, 10.08it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.66it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 48.35it/s]
# Processing Samples:  94%|█████████▍| 944/1000 [01:31<00:07,  7.05it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.60it/s]
# Processing Samples:  94%|█████████▍| 945/1000 [01:31<00:09,  5.77it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.69it/s]
# Processing Samples:  95%|█████████▍| 946/1000 [01:31<00:10,  4.92it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.20it/s]
# Processing Samples:  95%|█████████▍| 947/1000 [01:31<00:12,  4.27it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 23.48it/s]
# Processing Samples:  95%|█████████▍| 948/1000 [01:32<00:12,  4.13it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.11it/s]
# Processing Samples:  95%|█████████▍| 949/1000 [01:32<00:13,  3.86it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.29it/s]
# Processing Samples:  95%|█████████▌| 950/1000 [01:32<00:14,  3.56it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 46.51it/s]
# Processing Samples:  95%|█████████▌| 951/1000 [01:33<00:11,  4.12it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 58.57it/s]
# Processing Samples:  95%|█████████▌| 952/1000 [01:33<00:09,  4.85it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  95%|█████████▌| 954/1000 [01:33<00:06,  6.69it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 955/1000 [01:33<00:06,  7.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 957/1000 [01:33<00:04,  8.86it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 959/1000 [01:33<00:04,  9.76it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 961/1000 [01:33<00:03, 10.29it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 25.34it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.01it/s]
# Processing Samples:  96%|█████████▋| 963/1000 [01:34<00:05,  6.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.61it/s]
# Processing Samples:  96%|█████████▋| 964/1000 [01:34<00:06,  5.35it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 22.98it/s]
# Processing Samples:  97%|█████████▋| 966/1000 [01:35<00:06,  5.45it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.21it/s]
# Processing Samples:  97%|█████████▋| 967/1000 [01:35<00:06,  4.81it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.11it/s]
# Processing Samples:  97%|█████████▋| 968/1000 [01:35<00:07,  4.28it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 21.24it/s]
# Processing Samples:  97%|█████████▋| 969/1000 [01:36<00:07,  4.04it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 23.35it/s]
# Processing Samples:  97%|█████████▋| 970/1000 [01:36<00:07,  3.96it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.43it/s]
# Processing Samples:  97%|█████████▋| 971/1000 [01:36<00:07,  3.67it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.60it/s]
# Processing Samples:  97%|█████████▋| 972/1000 [01:36<00:08,  3.47it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.24it/s]
# Processing Samples:  97%|█████████▋| 974/1000 [01:37<00:06,  4.08it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.79it/s]
# Processing Samples:  98%|█████████▊| 975/1000 [01:37<00:06,  3.87it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.72it/s]
# Processing Samples:  98%|█████████▊| 976/1000 [01:37<00:06,  3.72it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 22.19it/s]
# Processing Samples:  98%|█████████▊| 977/1000 [01:38<00:06,  3.66it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 24.64it/s]
# Processing Samples:  98%|█████████▊| 978/1000 [01:38<00:05,  3.74it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.09it/s]
# Processing Samples:  98%|█████████▊| 979/1000 [01:38<00:05,  3.52it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.76it/s]
# Processing Samples:  98%|█████████▊| 980/1000 [01:39<00:05,  3.39it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.47it/s]
# Processing Samples:  98%|█████████▊| 981/1000 [01:39<00:05,  3.34it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.35it/s]
# Processing Samples:  98%|█████████▊| 982/1000 [01:39<00:05,  3.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.37it/s]
# Processing Samples:  98%|█████████▊| 983/1000 [01:40<00:05,  3.18it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 19.33it/s]
# Processing Samples:  98%|█████████▊| 984/1000 [01:40<00:05,  3.16it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 25.23it/s]
# Processing Samples:  98%|█████████▊| 985/1000 [01:40<00:04,  3.35it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.18it/s]
# Processing Samples:  99%|█████████▊| 986/1000 [01:41<00:04,  3.22it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▉| 988/1000 [01:41<00:02,  4.83it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 55.71it/s]
# Processing Samples:  99%|█████████▉| 989/1000 [01:41<00:02,  5.41it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 55.17it/s]
# Processing Samples:  99%|█████████▉| 990/1000 [01:41<00:01,  5.88it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 53.89it/s]
# Processing Samples:  99%|█████████▉| 991/1000 [01:41<00:01,  6.23it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▉| 992/1000 [01:41<00:01,  6.92it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▉| 993/1000 [01:41<00:00,  7.49it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 58.51it/s]
# Processing Samples:  99%|█████████▉| 994/1000 [01:41<00:00,  7.72it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|█████████▉| 996/1000 [01:42<00:00,  9.25it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|█████████▉| 998/1000 [01:42<00:00, 10.97it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|██████████| 1000/1000 [01:42<00:00,  9.77it/s]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-omp-snr-db-12-pilot-length-all.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved
