# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(400, 600)

# %% [markdown]
# Sparse Bayesian Learning (SBL)

# %%
def sbl_algorithm(theta, y, noise_var, max_iter=500, stopping_criterion=1e-4):
    # Sparse Bayesian Learning (SBL) for Multiple Measurement Vectors (MMV).

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess: identity matrix

    # Iterative update process
    for t in range(max_iter):
       # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute gamma update using the derived formula
        gamma_new = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Ensure non-negativity for numerical stability
        gamma_new = np.maximum(gamma_new, 1e-8)

        # Check for convergence: if change is below threshold, stop iterations
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma with new values
        Gamma = np.diagflat(gamma_new)

    # Return final estimates
    return mu_x, np.diag(Gamma)

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = sbl_algorithm(theta, received_signal, noise_power)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.51s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:25, 21.40s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:01, 20.64s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:40, 20.40s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:46<00:21, 21.94s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 21.66s/it]
# Processing Samples:   0%|          | 1/200 [02:07<7:02:57, 127.52s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:54, 22.85s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:22, 20.72s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:01, 20.50s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:26<00:43, 21.82s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:47<00:21, 21.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:11<00:00, 22.52s/it]
# Processing Samples:   1%|          | 2/200 [04:19<7:08:44, 129.92s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.67s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:26, 21.61s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:02, 20.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.55s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:47<00:22, 22.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:10<00:00, 22.40s/it]
# Processing Samples:   2%|▏         | 3/200 [06:29<7:07:03, 130.07s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:48, 21.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:21, 20.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:05<01:06, 22.19s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:26<00:43, 21.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:51<00:22, 22.79s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:12<00:00, 22.24s/it]
# Processing Samples:   2%|▏         | 4/200 [08:41<7:07:53, 130.99s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:38, 19.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:23, 20.79s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:02, 20.89s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:28<00:45, 22.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:49<00:22, 22.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:14<00:00, 23.19s/it]
# Processing Samples:   2%|▎         | 5/200 [10:56<7:09:37, 132.19s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:26, 21.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:03, 21.19s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:48<00:22, 22.24s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:12<00:00, 23.12s/it]
# Processing Samples:   3%|▎         | 6/200 [13:08<7:08:12, 132.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:38, 19.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:02, 20.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.77s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 22.11s/it]
# Processing Samples:   4%|▎         | 7/200 [15:16<7:00:36, 130.76s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:24, 21.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:01, 20.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:40, 20.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:46<00:22, 22.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 21.77s/it]
# Processing Samples:   4%|▍         | 8/200 [17:23<6:55:16, 129.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:52, 22.59s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:22, 20.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<00:59, 19.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:20, 20.93s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:09<00:00, 22.07s/it]
# Processing Samples:   4%|▍         | 9/200 [19:33<6:52:22, 129.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.98s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:03, 21.20s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:48<00:22, 22.34s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:09<00:00, 22.08s/it]
# Processing Samples:   5%|▌         | 10/200 [21:42<6:50:25, 129.61s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:53, 22.70s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:22, 20.65s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:00, 20.13s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.40s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:20, 20.92s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:09<00:00, 22.17s/it]
# Processing Samples:   6%|▌         | 11/200 [23:52<6:48:08, 129.57s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.41s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:02, 20.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.95s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.73s/it]
# Processing Samples:   6%|▌         | 12/200 [25:58<6:43:13, 128.69s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:50, 22.17s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:22, 20.53s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:00, 20.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:25<00:43, 21.66s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:46<00:21, 21.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:11<00:00, 22.67s/it]
# Processing Samples:   6%|▋         | 13/200 [28:10<6:43:39, 129.51s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.28s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.45s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.19s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:22, 22.13s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.73s/it]
# Processing Samples:   7%|▋         | 14/200 [30:16<6:38:14, 128.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.72s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.74s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.45s/it]
# Processing Samples:   8%|▊         | 15/200 [32:21<6:33:11, 127.52s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:51, 22.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:21, 20.45s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<00:59, 19.84s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.16s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:20, 20.84s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:08<00:00, 21.95s/it]
# Processing Samples:   8%|▊         | 16/200 [34:29<6:31:40, 127.72s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.62s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.75s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:02, 20.74s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.74s/it]
# Processing Samples:   8%|▊         | 17/200 [36:35<6:27:50, 127.16s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:23, 20.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:01, 20.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:40, 20.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.70s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.37s/it]
# Processing Samples:   9%|▉         | 18/200 [38:41<6:24:48, 126.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:48, 21.68s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:08<00:00, 22.12s/it]
# Processing Samples:  10%|▉         | 19/200 [40:50<6:23:51, 127.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.36s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:01, 20.64s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.32s/it]
# Processing Samples:  10%|█         | 20/200 [42:54<6:19:01, 126.34s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.98s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.16s/it]
# Processing Samples:  10%|█         | 21/200 [44:57<6:14:30, 125.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.27s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:20, 20.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.92s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.08s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:08<00:00, 22.22s/it]
# Processing Samples:  11%|█         | 22/200 [47:06<6:15:09, 126.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.19s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:02, 20.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.55s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.81s/it]
# Processing Samples:  12%|█▏        | 23/200 [49:12<6:12:41, 126.34s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:26, 21.67s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:01, 20.66s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.12s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.03s/it]
# Processing Samples:  12%|█▏        | 24/200 [51:17<6:09:15, 125.89s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.35s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.73s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.26s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.38s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.36s/it]
# Processing Samples:  12%|█▎        | 25/200 [53:22<6:06:03, 125.51s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.75s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.81s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.17s/it]
# Processing Samples:  13%|█▎        | 26/200 [55:23<6:00:26, 124.29s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.50s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.72s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.54s/it]
# Processing Samples:  14%|█▎        | 27/200 [57:24<5:55:19, 123.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.96s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.34s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.57s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.49s/it]
# Processing Samples:  14%|█▍        | 28/200 [59:24<5:50:35, 122.30s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:50, 22.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:20, 20.02s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.36s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.31s/it]
# Processing Samples:  14%|█▍        | 29/200 [1:01:29<5:50:58, 123.15s/it]
# Converged after 485 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.46s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.22s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.31s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:40, 20.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.11s/it]
# Processing Samples:  15%|█▌        | 30/200 [1:03:31<5:48:07, 122.87s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.47s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.93s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.83s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.62s/it]
# Processing Samples:  16%|█▌        | 31/200 [1:05:32<5:44:02, 122.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:24, 21.01s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<00:59, 19.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.47s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 20.52s/it]
# Processing Samples:  16%|█▌        | 32/200 [1:07:35<5:42:57, 122.49s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.40s/it]
# Processing Samples:  16%|█▋        | 33/200 [1:09:39<5:41:52, 122.83s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.76s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:01, 20.57s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.11s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.19s/it]
# Processing Samples:  17%|█▋        | 34/200 [1:11:43<5:40:54, 123.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.59s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.64s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.11s/it]
# Processing Samples:  18%|█▊        | 35/200 [1:13:42<5:35:51, 122.13s/it]
# Converged after 464 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.14s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:41, 20.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.30s/it]
# Processing Samples:  18%|█▊        | 36/200 [1:15:43<5:32:24, 121.61s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.02s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.37s/it]
# Processing Samples:  18%|█▊        | 37/200 [1:17:47<5:32:08, 122.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.59s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.70s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.86s/it]
# Processing Samples:  19%|█▉        | 38/200 [1:19:46<5:27:56, 121.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.86s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.70s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.48s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.69s/it]
# Processing Samples:  20%|█▉        | 39/200 [1:21:47<5:25:17, 121.23s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.18s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.61s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.50s/it]
# Processing Samples:  20%|██        | 40/200 [1:23:48<5:22:58, 121.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.99s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:42, 21.23s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:08<00:00, 22.32s/it]
# Processing Samples:  20%|██        | 41/200 [1:25:56<5:26:32, 123.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.78s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.11s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.86s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 19.60s/it]
# Processing Samples:  21%|██        | 42/200 [1:27:54<5:20:33, 121.73s/it]
# Converged after 410 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.02s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.66s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.63s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.80s/it]
# Converged after 447 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.60s/it]
# Processing Samples:  22%|██▏       | 43/200 [1:29:52<5:15:34, 120.60s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.99s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.78s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.62s/it]
# Processing Samples:  22%|██▏       | 44/200 [1:31:52<5:13:09, 120.45s/it]
# Converged after 486 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:29, 18.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.01s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.23s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.11s/it]
# Processing Samples:  22%|██▎       | 45/200 [1:33:51<5:10:07, 120.05s/it]
# Converged after 489 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:42, 20.43s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.11s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:41, 20.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.39s/it]
# Processing Samples:  23%|██▎       | 46/200 [1:35:52<5:08:47, 120.31s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:43, 20.65s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.64s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.06s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.99s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.74s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.81s/it]
# Processing Samples:  24%|██▎       | 47/200 [1:37:59<5:11:43, 122.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.51s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.11s/it]
# Processing Samples:  24%|██▍       | 48/200 [1:40:02<5:10:38, 122.62s/it]
# Converged after 478 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.56s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.63s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.52s/it]
# Processing Samples:  24%|██▍       | 49/200 [1:42:07<5:10:15, 123.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.37s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.09s/it]
# Converged after 430 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.04s/it]
# Processing Samples:  25%|██▌       | 50/200 [1:44:06<5:04:38, 121.86s/it]
# Converged after 449 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.42s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.36s/it]
# Processing Samples:  26%|██▌       | 51/200 [1:46:09<5:03:32, 122.23s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.91s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.83s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:48:11<5:01:28, 122.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.73s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:50:17<5:01:54, 123.23s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.69s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.70s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 21.07s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:52:18<4:58:12, 122.55s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.89s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.64s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.48s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.69s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.53s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:54:18<4:54:41, 121.94s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.60s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:21, 20.42s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.62s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.43s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:56:19<4:52:09, 121.73s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.53s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.06s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.62s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.33s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:58:23<4:51:50, 122.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:40, 20.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.11s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.27s/it]
# Processing Samples:  29%|██▉       | 58/200 [2:00:25<4:48:50, 122.04s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.89s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.85s/it]
# Processing Samples:  30%|██▉       | 59/200 [2:02:26<4:46:36, 121.96s/it]
# Converged after 489 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.91s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.96s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.55s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.36s/it]
# Processing Samples:  30%|███       | 60/200 [2:04:26<4:43:06, 121.33s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.36s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.28s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.64s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.41s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.62s/it]
# Processing Samples:  30%|███       | 61/200 [2:06:32<4:43:53, 122.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.18s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.69s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.86s/it]
# Processing Samples:  31%|███       | 62/200 [2:08:31<4:40:01, 121.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.71s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.64s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.10s/it]
# Processing Samples:  32%|███▏      | 63/200 [2:10:35<4:38:58, 122.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.68s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.62s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.45s/it]
# Processing Samples:  32%|███▏      | 64/200 [2:12:36<4:36:03, 121.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:47, 21.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.07s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 19.49s/it]
# Processing Samples:  32%|███▎      | 65/200 [2:14:34<4:31:51, 120.83s/it]
# Converged after 448 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:50, 22.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.93s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.34s/it]
# Processing Samples:  33%|███▎      | 66/200 [2:16:39<4:32:38, 122.08s/it]
# Converged after 486 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.05s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.65s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.90s/it]
# Processing Samples:  34%|███▎      | 67/200 [2:18:40<4:29:45, 121.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.82s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 20.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.30s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.04s/it]
# Processing Samples:  34%|███▍      | 68/200 [2:20:42<4:28:08, 121.88s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:39, 19.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 22.13s/it]
# Processing Samples:  34%|███▍      | 69/200 [2:22:49<4:29:10, 123.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.53s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.51s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 21.13s/it]
# Processing Samples:  35%|███▌      | 70/200 [2:24:48<4:24:41, 122.16s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.48s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.11s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.90s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.66s/it]
# Processing Samples:  36%|███▌      | 71/200 [2:26:50<4:22:12, 121.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.07s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.48s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.43s/it]
# Processing Samples:  36%|███▌      | 72/200 [2:28:50<4:19:07, 121.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.19s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.45s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.57s/it]
# Processing Samples:  36%|███▋      | 73/200 [2:30:55<4:19:24, 122.55s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.94s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.14s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.70s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.08s/it]
# Processing Samples:  37%|███▋      | 74/200 [2:32:56<4:16:30, 122.15s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.57s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.77s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.23s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.05s/it]
# Processing Samples:  38%|███▊      | 75/200 [2:34:58<4:14:04, 121.96s/it]
# Converged after 471 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.02s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.07s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.80s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.85s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.84s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:37:01<4:12:27, 122.16s/it]
# Converged after 495 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:47, 21.41s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.65s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.27s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.13s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.72s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:39:03<4:10:37, 122.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:23, 20.85s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:05<01:06, 22.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.23s/it]
# ...
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.76s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.79s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.53s/it]
# Processing Samples:  88%|████████▊ | 175/200 [6:01:13<50:37, 121.50s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.35s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:42, 21.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.53s/it]
# Converged after 470 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 19.64s/it]
# Processing Samples:  88%|████████▊ | 176/200 [6:03:12<48:21, 120.90s/it]
# Converged after 429 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.02s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.98s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.74s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:06<00:00, 21.77s/it]
# Processing Samples:  88%|████████▊ | 177/200 [6:05:18<46:56, 122.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.45s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:19, 19.90s/it]
# Converged after 490 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.26s/it]
# Processing Samples:  89%|████████▉ | 178/200 [6:07:21<44:55, 122.51s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.75s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.76s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.48s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.78s/it]
# Processing Samples:  90%|████████▉ | 179/200 [6:09:20<42:33, 121.58s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:51, 22.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:49<01:40, 25.00s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:09<01:07, 22.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:33<00:46, 23.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:54<00:22, 22.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:19<00:00, 23.51s/it]
# Processing Samples:  90%|█████████ | 180/200 [6:11:40<42:21, 127.07s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:01, 20.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.39s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.26s/it]
# Processing Samples:  90%|█████████ | 181/200 [6:13:46<40:03, 126.51s/it]
# Converged after 480 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:20, 20.05s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.81s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.27s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 21.92s/it]
# Processing Samples:  91%|█████████ | 182/200 [6:15:53<38:03, 126.84s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.45s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.38s/it]
# Processing Samples:  92%|█████████▏| 183/200 [6:17:58<35:44, 126.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.76s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.07s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 20.98s/it]
# Processing Samples:  92%|█████████▏| 184/200 [6:20:01<33:23, 125.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.42s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.16s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.45s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.54s/it]
# Processing Samples:  92%|█████████▎| 185/200 [6:22:06<31:16, 125.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.27s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.86s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.82s/it]
# Processing Samples:  93%|█████████▎| 186/200 [6:24:07<28:56, 124.06s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.40s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:21, 20.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.73s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.63s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.93s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.66s/it]
# Processing Samples:  94%|█████████▎| 187/200 [6:26:09<26:43, 123.33s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:47, 21.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:18, 19.75s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.50s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.56s/it]
# Processing Samples:  94%|█████████▍| 188/200 [6:28:14<24:47, 123.99s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.71s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.91s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.44s/it]
# Processing Samples:  94%|█████████▍| 189/200 [6:30:17<22:39, 123.61s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.92s/it]
# Processing Samples:  95%|█████████▌| 190/200 [6:32:18<20:29, 122.95s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.78s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.73s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.68s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.94s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.04s/it]
# Processing Samples:  96%|█████████▌| 191/200 [6:34:18<18:18, 122.05s/it]
# Converged after 447 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:21, 20.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.11s/it]
# Processing Samples:  96%|█████████▌| 192/200 [6:36:19<16:13, 121.69s/it]
# Converged after 454 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:50, 22.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:57, 19.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.18s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 21.97s/it]
# Processing Samples:  96%|█████████▋| 193/200 [6:38:27<14:24, 123.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:41, 20.57s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.55s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.21s/it]
# Processing Samples:  97%|█████████▋| 194/200 [6:40:30<12:20, 123.42s/it]
# Converged after 450 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.18s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.85s/it]
# Processing Samples:  98%|█████████▊| 195/200 [6:42:33<10:16, 123.21s/it]
# Converged after 486 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.40s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:21, 20.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.77s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.93s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.55s/it]
# Processing Samples:  98%|█████████▊| 196/200 [6:44:35<08:11, 122.78s/it]
# Converged after 489 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:19, 19.90s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.68s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.49s/it]
# Processing Samples:  98%|█████████▊| 197/200 [6:46:35<06:06, 122.08s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.20s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.61s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.36s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.36s/it]
# Processing Samples:  99%|█████████▉| 198/200 [6:48:39<04:05, 122.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.08s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:40, 20.33s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.15s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.13s/it]
# Processing Samples: 100%|█████████▉| 199/200 [6:50:41<02:02, 122.28s/it]
# Converged after 487 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.08s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.77s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 21.02s/it]
# Processing Samples: 100%|██████████| 200/200 [6:52:41<00:00, 123.81s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# Print average results
print("Avg HR  :", avg_hr)
print("Avg SRR :", avg_srr)
print("Avg FR  :", avg_fr)
print("Avg PR  :", avg_pr)
print("Avg RE  :", avg_re)
print("Avg F1  :", avg_f1)
print("Avg NMSE:", avg_nmse)
# Out:
# Avg HR  : [ 9.065 14.175 18.39  19.685 19.9   19.93 ]
# Avg SRR : [0.04023873 0.07541004 0.12721943 0.15901779 0.17302501 0.18013889]
# Avg FR  : [0.83184211 0.70210526 0.42921053 0.24789474 0.16052632 0.11447368]
# Avg PR  : [0.0734909  0.10409963 0.14002139 0.16246989 0.17442044 0.18119912]
# Avg RE  : [0.09065 0.14175 0.1839  0.19685 0.199   0.1993 ]
# Avg F1  : [0.08098691 0.11978478 0.15867553 0.17773737 0.18563374 0.18959174]
# Avg NMSE: [0.1426015  0.09330253 0.04317036 0.02192119 0.01483552 0.01154352]

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-sbl-snr-db-12-pilot-length-all-set-3.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved

# %%
import matplotlib.pyplot as plt

# Define the SNR values for x-axis
pilot_length_values = pilot_length_array

# Create subplots for different performance metrics
plt.figure(figsize=(15, 14))

# Plot Hit Rate (HR)
plt.subplot(4, 2, 1)
plt.plot(pilot_length_values, avg_hr, marker='o', linestyle='-', color='b', label='HR')
plt.xlabel("Pilot Length")
plt.ylabel("Hit Rate (%)")
plt.title("Hit Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot False Alarm Rate (FR)
plt.subplot(4, 2, 2)
plt.plot(pilot_length_values, avg_fr, marker='^', linestyle='-', color='g', label='FR')
plt.xlabel("Pilot Length")
plt.ylabel("False Alarm Rate (%)")
plt.title("False Alarm Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Support Recovery Rate (SRR)
plt.subplot(4, 2, 3)
plt.plot(pilot_length_values, avg_srr, marker='s', linestyle='-', color='r', label='SRR')
plt.xlabel("Pilot Length")
plt.ylabel("Support Recovery Rate")
plt.title("Support Recovery Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Precision (PR)
plt.subplot(4, 2, 4)
plt.plot(pilot_length_values, avg_pr, marker='x', linestyle='-', color='c', label='PR')
plt.xlabel("Pilot Length")
plt.ylabel("Precision")
plt.title("Precision vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Recall (RE)
plt.subplot(4, 2, 5)
plt.plot(pilot_length_values, avg_re, marker='p', linestyle='-', color='y', label='RE')
plt.xlabel("Pilot Length")
plt.ylabel("Recall")
plt.title("Recall vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot F1 Score (F1)
plt.subplot(4, 2, 6)
plt.plot(pilot_length_values, avg_f1, marker='*', linestyle='-', color='k', label='F1 Score')
plt.xlabel("Pilot Length")
plt.ylabel("F1 Score")
plt.title("F1 Score vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Normalized MSE (NMSE)
plt.subplot(4, 2, 7)
plt.plot(pilot_length_values, avg_nmse, marker='d', linestyle='-', color='m', label='NMSE')
plt.xlabel("Pilot Length")
plt.ylabel("Normalized MSE")
plt.title("Normalized MSE vs Pilot Length")
plt.yscale('log')  # Log scale for better visualization
plt.grid(True)
plt.legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_res_vs_ground_truth(sbl_results, Z, sample_index, snr_index, snr_value):
    """Plot sbl reconstructed signal vs ground truth (Z) for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    # Ground truth (Z)
    plt.plot(np.abs(Z[sample_index,:,0]), marker='s', linestyle='--', color='g', label="Ground Truth (Z)")

    # sbl Estimated Signal
    plt.plot(np.abs(sbl_results[sample_index, snr_index, :, 0]), marker='o', linestyle='-', color='b', label="sbl Estimate")

    plt.xlabel("Device Index")
    plt.ylabel("Magnitude of Signal")
    plt.title(f"sbl vs. Ground Truth (Sample {sample_index}, SNR {snr_value} dB)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_res_vs_ground_truth(z_res, all_z, sample_index, snr_index, snr_value)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_gamma_res_vs_ground_truth(gamma_res, gamma_true, sample_index, snr_index, snr_value):
    """Plot sbl estimated gamma vs ground truth gamma for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    device_indices = np.arange(len(gamma_true[sample_index]))  # X-axis: Device indices

    # Plot ground truth gamma (binary)
    plt.stem(device_indices, gamma_true[sample_index], linefmt='g--', markerfmt='gs', basefmt=" ", label="Ground Truth (γ)")

    # Plot sbl estimated gamma
    plt.stem(device_indices, gamma_res[sample_index, snr_index], linefmt='b-', markerfmt='bo', basefmt=" ", label="sbl Estimate (γ)")

    plt.xlabel("Device Index")
    plt.ylabel("Activity Indicator (0=Inactive, 1=Active)")
    plt.title(f"Device Activity (sbl vs. Ground Truth) - Sample {sample_index}, SNR {snr_value} dB")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_gamma_res_vs_ground_truth(gamma_res, all_gamma, sample_index, snr_index, snr_value)
