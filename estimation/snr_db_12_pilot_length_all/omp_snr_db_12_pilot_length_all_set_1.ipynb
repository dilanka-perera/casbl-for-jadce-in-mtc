# %%
base_path = "/content/drive/My Drive/Github/casbl-for-jadce-in-mtc"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from omp import omp

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]

max_iter = 500

# %%
sample_range = range(0, 200)
num_samples = len(sample_range)

# %%
# Final gamma and z results
z_result_all = np.empty((num_samples, len(pilot_length_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Run CASBL
        z_result, z_history = omp(
            theta, received_signal, sparsity
        )

        # Save outputs
        z_result_all[sample_index-sample_range[0], pilot_length_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 2/200 [00:00<00:12, 16.05it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▎         | 5/200 [00:00<00:10, 17.90it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▎         | 7/200 [00:00<00:10, 18.50it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   5%|▌         | 10/200 [00:00<00:09, 19.17it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▋         | 13/200 [00:00<00:09, 19.73it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 15/200 [00:00<00:10, 18.46it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 17/200 [00:00<00:09, 18.83it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|▉         | 19/200 [00:01<00:09, 18.99it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|█         | 21/200 [00:01<00:09, 19.02it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 24/200 [00:01<00:09, 19.42it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  13%|█▎        | 26/200 [00:01<00:08, 19.35it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 28/200 [00:01<00:08, 19.15it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  15%|█▌        | 30/200 [00:01<00:08, 18.90it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▌        | 32/200 [00:01<00:08, 18.78it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  17%|█▋        | 34/200 [00:01<00:09, 17.79it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 36/200 [00:01<00:09, 17.55it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  19%|█▉        | 38/200 [00:02<00:09, 17.62it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|██        | 40/200 [00:02<00:09, 17.59it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  21%|██        | 42/200 [00:02<00:09, 17.27it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▏       | 44/200 [00:02<00:09, 17.06it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  23%|██▎       | 46/200 [00:02<00:08, 17.24it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▍       | 48/200 [00:02<00:08, 17.05it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  25%|██▌       | 50/200 [00:02<00:08, 17.29it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▌       | 52/200 [00:02<00:08, 16.58it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  27%|██▋       | 54/200 [00:02<00:08, 16.87it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 56/200 [00:03<00:08, 17.13it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  29%|██▉       | 58/200 [00:03<00:08, 17.08it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 60/200 [00:03<00:08, 15.82it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███       | 62/200 [00:03<00:09, 15.03it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 64/200 [00:03<00:09, 13.92it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 66/200 [00:03<00:09, 14.13it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▍      | 68/200 [00:04<00:09, 13.24it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  35%|███▌      | 70/200 [00:04<00:10, 12.79it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 22.72it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 14.87it/s]
# Processing Samples:  36%|███▌      | 72/200 [00:04<00:20,  6.28it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:00<00:00, 23.24it/s]
# Processing Samples:  36%|███▋      | 73/200 [00:05<00:22,  5.58it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 20.03it/s]
# Processing Samples:  37%|███▋      | 74/200 [00:05<00:25,  4.88it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 30.06it/s]
# Processing Samples:  38%|███▊      | 75/200 [00:05<00:25,  4.87it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 77/200 [00:05<00:19,  6.30it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  40%|███▉      | 79/200 [00:05<00:15,  7.66it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  40%|████      | 81/200 [00:06<00:13,  8.58it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 37.93it/s]
# Processing Samples:  42%|████▏     | 83/200 [00:06<00:13,  8.48it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  42%|████▎     | 85/200 [00:06<00:12,  9.58it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:00<00:00, 18.74it/s]
# Processing Samples:  44%|████▎     | 87/200 [00:06<00:15,  7.31it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  44%|████▍     | 88/200 [00:07<00:14,  7.68it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  44%|████▍     | 89/200 [00:07<00:13,  8.07it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  45%|████▌     | 90/200 [00:07<00:13,  8.29it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: