# %%
base_path = "/content/drive/My Drive/Github/mtc-device-activation"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from omp import omp

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 2
pilot_length=pilot_length_array[pilot_length_index]

max_iter = 500
# Out:
# Mounted at /content/drive

# %%
sample_range = range(600, 800)
num_samples = len(sample_range)

# %%
# Final gamma and z results
z_result_all = np.empty((num_samples, len(snr_db_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for snr_db_index in tqdm(range(len(snr_db_array)), desc="Processing SNR DB Levels", leave=False, position=1):
        snr_db = snr_db_array[snr_db_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Run CASBL
        z_result, z_history = omp(
            theta, received_signal, sparsity
        )

        # Save outputs
        z_result_all[sample_index-sample_range[0], snr_db_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 2/200 [00:00<00:12, 15.71it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▎         | 5/200 [00:00<00:10, 19.27it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 8/200 [00:00<00:09, 20.91it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▌         | 11/200 [00:00<00:08, 21.73it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   7%|▋         | 14/200 [00:00<00:08, 22.00it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 17/200 [00:00<00:08, 22.18it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|█         | 20/200 [00:00<00:08, 22.26it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 23/200 [00:01<00:08, 21.07it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  13%|█▎        | 26/200 [00:01<00:08, 21.70it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 29/200 [00:01<00:07, 21.85it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▌        | 32/200 [00:01<00:07, 22.30it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 35/200 [00:01<00:07, 20.86it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  19%|█▉        | 38/200 [00:01<00:08, 19.72it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|██        | 41/200 [00:01<00:08, 18.60it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▏       | 43/200 [00:02<00:08, 17.65it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▎       | 45/200 [00:02<00:08, 17.57it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▎       | 47/200 [00:02<00:08, 17.65it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▍       | 49/200 [00:02<00:08, 17.94it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▌       | 51/200 [00:02<00:08, 17.89it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▋       | 53/200 [00:02<00:08, 17.96it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 55/200 [00:02<00:07, 18.29it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 57/200 [00:02<00:07, 18.16it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|██▉       | 59/200 [00:03<00:07, 17.88it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 61/200 [00:03<00:07, 18.25it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 63/200 [00:03<00:07, 17.51it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▎      | 65/200 [00:03<00:07, 17.09it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▎      | 67/200 [00:03<00:07, 17.58it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▍      | 69/200 [00:03<00:07, 17.82it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▌      | 71/200 [00:03<00:07, 17.63it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▋      | 73/200 [00:03<00:07, 17.98it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 75/200 [00:03<00:06, 18.25it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 77/200 [00:04<00:06, 18.03it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  40%|███▉      | 79/200 [00:04<00:06, 18.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  40%|████      | 81/200 [00:04<00:06, 18.22it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  42%|████▏     | 83/200 [00:04<00:06, 17.88it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  42%|████▎     | 85/200 [00:04<00:06, 17.11it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  44%|████▎     | 87/200 [00:04<00:06, 17.67it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  44%|████▍     | 89/200 [00:04<00:06, 18.05it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  46%|████▌     | 91/200 [00:04<00:05, 18.35it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  46%|████▋     | 93/200 [00:04<00:05, 18.46it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  48%|████▊     | 95/200 [00:05<00:06, 17.45it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  48%|████▊     | 97/200 [00:05<00:05, 17.45it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  50%|████▉     | 99/200 [00:05<00:05, 17.69it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  50%|█████     | 101/200 [00:05<00:05, 18.06it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  52%|█████▏    | 103/200 [00:05<00:05, 18.17it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  52%|█████▎    | 105/200 [00:05<00:05, 17.47it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  54%|█████▎    | 107/200 [00:05<00:05, 17.47it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  55%|█████▍    | 109/200 [00:05<00:05, 17.80it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  56%|█████▌    | 111/200 [00:05<00:05, 17.60it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  56%|█████▋    | 113/200 [00:06<00:04, 17.58it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  57%|█████▊    | 115/200 [00:06<00:04, 17.42it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  58%|█████▊    | 117/200 [00:06<00:04, 17.71it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  60%|█████▉    | 119/200 [00:06<00:04, 17.90it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  60%|██████    | 121/200 [00:06<00:04, 17.78it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  62%|██████▏   | 123/200 [00:06<00:04, 18.16it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  62%|██████▎   | 125/200 [00:06<00:04, 17.44it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  64%|██████▎   | 127/200 [00:06<00:04, 17.10it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  64%|██████▍   | 129/200 [00:06<00:04, 17.41it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  66%|██████▌   | 131/200 [00:07<00:03, 17.44it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  66%|██████▋   | 133/200 [00:07<00:03, 17.45it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  68%|██████▊   | 135/200 [00:07<00:03, 17.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  68%|██████▊   | 137/200 [00:07<00:03, 16.73it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  70%|██████▉   | 139/200 [00:07<00:03, 16.33it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  70%|███████   | 141/200 [00:07<00:03, 15.49it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  72%|███████▏  | 143/200 [00:07<00:03, 15.40it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  72%|███████▎  | 145/200 [00:07<00:03, 15.02it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  74%|███████▎  | 147/200 [00:08<00:03, 15.19it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  74%|███████▍  | 149/200 [00:08<00:03, 15.37it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  76%|███████▌  | 151/200 [00:08<00:03, 15.59it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  76%|███████▋  | 153/200 [00:08<00:03, 15.04it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  78%|███████▊  | 155/200 [00:08<00:02, 15.69it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  78%|███████▊  | 157/200 [00:08<00:02, 15.80it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  80%|███████▉  | 159/200 [00:08<00:02, 16.21it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  80%|████████  | 161/200 [00:09<00:02, 15.80it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  82%|████████▏ | 163/200 [00:09<00:02, 14.87it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  82%|████████▎ | 165/200 [00:09<00:02, 14.70it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  84%|████████▎ | 167/200 [00:09<00:02, 14.95it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  84%|████████▍ | 169/200 [00:09<00:01, 16.09it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  86%|████████▌ | 172/200 [00:09<00:01, 18.00it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  88%|████████▊ | 175/200 [00:09<00:01, 19.15it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  89%|████████▉ | 178/200 [00:09<00:01, 19.53it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  90%|█████████ | 180/200 [00:10<00:01, 19.61it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  91%|█████████ | 182/200 [00:10<00:00, 19.64it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 184/200 [00:10<00:00, 19.08it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 186/200 [00:10<00:00, 19.29it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 188/200 [00:10<00:00, 19.27it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 191/200 [00:10<00:00, 20.25it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  97%|█████████▋| 194/200 [00:10<00:00, 20.32it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  98%|█████████▊| 197/200 [00:10<00:00, 20.32it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|██████████| 200/200 [00:11<00:00, 18.09it/s]

# %%
np.savez_compressed(
    f'{base_path}/estimation/snr_db_all_pilot_length_30/data/omp_snr_db_all_pilot_length_30_set_4.npz',
    z_result_all=z_result_all,
)

print("All results have been saved")
# Out:
# All results have been saved
