# %%
base_path = "/content/drive/My Drive/Github/mtc-device-activation"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from omp import omp

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 2
pilot_length=pilot_length_array[pilot_length_index]

max_iter = 500
# Out:
# Mounted at /content/drive

# %%
sample_range = range(600, 800)
num_samples = len(sample_range)

# %%
# Final gamma and z results
z_result_all = np.empty((num_samples, len(snr_db_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for snr_db_index in tqdm(range(len(snr_db_array)), desc="Processing SNR DB Levels", leave=False, position=1):
        snr_db = snr_db_array[snr_db_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Run CASBL
        z_result, z_history = omp(
            theta, received_signal, sparsity
        )

        # Save outputs
        z_result_all[sample_index-sample_range[0], snr_db_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR DB Levels:  83%|████████▎ | 5/6 [00:00<00:00, 48.32it/s]
# Processing Samples:   0%|          | 1/200 [00:00<00:26,  7.64it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 3/200 [00:00<00:16, 11.74it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▎         | 5/200 [00:00<00:14, 13.62it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▎         | 7/200 [00:00<00:13, 14.05it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 9/200 [00:00<00:13, 14.33it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▌         | 11/200 [00:00<00:12, 15.04it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▋         | 13/200 [00:00<00:12, 15.44it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 15/200 [00:01<00:12, 15.01it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 17/200 [00:01<00:12, 15.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|▉         | 19/200 [00:01<00:11, 15.29it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|█         | 21/200 [00:01<00:11, 15.42it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 23/200 [00:01<00:11, 15.97it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▎        | 25/200 [00:01<00:10, 16.44it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▎        | 27/200 [00:01<00:10, 16.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 29/200 [00:01<00:10, 15.82it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▌        | 31/200 [00:02<00:10, 15.97it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▋        | 33/200 [00:02<00:10, 16.14it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 35/200 [00:02<00:10, 15.58it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 37/200 [00:02<00:10, 15.94it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|█▉        | 39/200 [00:02<00:09, 16.78it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  21%|██        | 42/200 [00:02<00:08, 19.01it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▎       | 45/200 [00:02<00:07, 20.16it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▍       | 48/200 [00:02<00:07, 21.25it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▌       | 51/200 [00:03<00:06, 22.14it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  27%|██▋       | 54/200 [00:03<00:06, 21.95it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 57/200 [00:03<00:06, 21.02it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 60/200 [00:03<00:06, 22.11it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 63/200 [00:03<00:06, 22.74it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 66/200 [00:03<00:05, 23.08it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▍      | 69/200 [00:03<00:05, 23.03it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▌      | 72/200 [00:03<00:05, 22.68it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 75/200 [00:04<00:05, 22.69it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  39%|███▉      | 78/200 [00:04<00:05, 22.59it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  40%|████      | 81/200 [00:04<00:05, 21.48it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  42%|████▏     | 84/200 [00:04<00:05, 21.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  44%|████▎     | 87/200 [00:04<00:05, 21.71it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  45%|████▌     | 90/200 [00:04<00:04, 22.48it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  46%|████▋     | 93/200 [00:04<00:04, 22.39it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  48%|████▊     | 96/200 [00:05<00:04, 22.70it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  50%|████▉     | 99/200 [00:05<00:04, 22.62it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  51%|█████     | 102/200 [00:05<00:04, 22.45it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  52%|█████▎    | 105/200 [00:05<00:04, 21.62it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  54%|█████▍    | 108/200 [00:05<00:04, 22.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  56%|█████▌    | 111/200 [00:05<00:04, 22.18it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  57%|█████▋    | 114/200 [00:05<00:03, 22.65it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  58%|█████▊    | 117/200 [00:05<00:03, 22.73it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  60%|██████    | 120/200 [00:06<00:03, 22.65it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  62%|██████▏   | 123/200 [00:06<00:03, 22.15it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  63%|██████▎   | 126/200 [00:06<00:03, 22.49it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  64%|██████▍   | 129/200 [00:06<00:03, 21.47it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  66%|██████▌   | 132/200 [00:06<00:03, 21.77it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  68%|██████▊   | 135/200 [00:06<00:02, 21.82it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  69%|██████▉   | 138/200 [00:06<00:02, 22.18it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  70%|███████   | 141/200 [00:07<00:02, 22.20it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  72%|███████▏  | 144/200 [00:07<00:02, 22.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  74%|███████▎  | 147/200 [00:07<00:02, 21.79it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  75%|███████▌  | 150/200 [00:07<00:02, 21.98it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  76%|███████▋  | 153/200 [00:07<00:02, 20.64it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  78%|███████▊  | 156/200 [00:07<00:02, 20.97it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  80%|███████▉  | 159/200 [00:07<00:01, 21.13it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  81%|████████  | 162/200 [00:08<00:01, 21.50it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  82%|████████▎ | 165/200 [00:08<00:01, 21.56it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR DB Levels:  67%|██████▋   | 4/6 [00:00<00:00, 32.82it/s]
# Processing Samples:  84%|████████▍ | 168/200 [00:08<00:02, 15.97it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  85%|████████▌ | 170/200 [00:08<00:01, 15.72it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  86%|████████▋ | 173/200 [00:08<00:01, 17.40it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  88%|████████▊ | 176/200 [00:08<00:01, 18.94it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  90%|████████▉ | 179/200 [00:09<00:01, 19.73it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  91%|█████████ | 182/200 [00:09<00:00, 20.31it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▎| 185/200 [00:09<00:00, 20.23it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 188/200 [00:09<00:00, 20.99it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 191/200 [00:09<00:00, 20.70it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  97%|█████████▋| 194/200 [00:09<00:00, 19.71it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  98%|█████████▊| 197/200 [00:09<00:00, 20.12it/s]
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR DB Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|██████████| 200/200 [00:10<00:00, 19.85it/s]

# %%
np.savez_compressed(
    f'{base_path}/estimation/snr_db_all_pilot_length_30/data/omp_snr_db_all_pilot_length_30_set_4.npz',
    z_result_all=z_result_all,
)

print("All results have been saved")
# Out:
# All results have been saved
