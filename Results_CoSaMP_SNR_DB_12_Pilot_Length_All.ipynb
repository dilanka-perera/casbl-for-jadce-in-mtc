# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(0, 1000)

# %% [markdown]
# Compressive Sampling Matching Pursuit (CoSaMP)

# %%
def cosamp_algorithm(theta, y, sparsity_level, max_iter=500, stopping_criterion=1e-4, lambda_reg=1e-2):
    L, N = theta.shape
    _, M = y.shape

    x_hat = np.zeros((N, M), dtype=np.complex128)
    residual = y.copy()
    support = set()

    for t in range(max_iter):
        # Step 1: Compute proxy
        proxy = theta.conj().T @ residual
        row_energy = np.sum(np.abs(proxy)**2, axis=1)
        omega = np.argpartition(row_energy, -2 * sparsity_level)[-2 * sparsity_level:]

        # Step 2: Merge with previous support
        merged_support = list(set(omega).union(support))
        theta_s = theta[:, merged_support]

        # Step 3: Regularized LS on merged support
        A = theta_s
        AHA = A.conj().T @ A + lambda_reg * np.eye(A.shape[1])
        AHY = A.conj().T @ y
        x_temp = np.linalg.solve(AHA, AHY)

        # Step 4: Prune to top-K rows
        row_energy_temp = np.sum(np.abs(x_temp)**2, axis=1)
        top_indices = np.argpartition(row_energy_temp, -sparsity_level)[-sparsity_level:]
        support = set([merged_support[i] for i in top_indices])

        # Step 5: Final LS on pruned support
        theta_final = theta[:, list(support)]
        A = theta_final
        AHA = A.conj().T @ A + lambda_reg * np.eye(A.shape[1])
        AHY = A.conj().T @ y
        x_support = np.linalg.solve(AHA, AHY)

        # Step 6: Construct full x_hat
        x_hat.fill(0)
        for i, idx in enumerate(support):
            x_hat[idx, :] = x_support[i, :]

        # Step 7: Update residual
        new_residual = y - theta @ x_hat

        # Step 8: Check stopping
        if np.linalg.norm(new_residual) < stopping_criterion:
            print(f"CoSaMP converged at iteration {t+1}")
            break

        residual = new_residual

    # Step 9: Binary support vector
    gamma = (np.linalg.norm(x_hat, axis=1) > 1e-6).astype(int)
    return x_hat, gamma

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = cosamp_algorithm(theta, received_signal, sparsity)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.83it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.05it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.17it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.27s/it]
# Processing Samples:  38%|███▊      | 376/1000 [20:18<40:19,  3.88s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.41it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.72it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.08it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.12it/s]
# Processing Samples:  38%|███▊      | 377/1000 [20:22<38:25,  3.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.86it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.07it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.25it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples:  38%|███▊      | 378/1000 [20:24<35:16,  3.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.76it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.17it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.21it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Processing Samples:  38%|███▊      | 379/1000 [20:27<33:07,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.75it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  1.27it/s]
# Processing Samples:  38%|███▊      | 380/1000 [20:31<34:45,  3.36s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:08,  1.68s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:02<00:05,  1.40s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:03<00:03,  1.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:01,  1.16it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:04<00:00,  1.39it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.60it/s]
# Processing Samples:  38%|███▊      | 381/1000 [20:36<40:03,  3.88s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.71it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.19it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.28it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Samples:  38%|███▊      | 382/1000 [20:39<36:25,  3.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.99it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.16it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.26it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Processing Samples:  38%|███▊      | 383/1000 [20:41<33:41,  3.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.88it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.21it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.22it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.29it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Processing Samples:  38%|███▊      | 384/1000 [20:44<31:54,  3.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.24it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:03<00:07,  2.00s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:04,  1.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:00,  1.07it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.30it/s]
# Processing Samples:  38%|███▊      | 385/1000 [20:50<41:32,  4.05s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.78it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.27it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples:  39%|███▊      | 386/1000 [20:53<37:20,  3.65s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.87it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.26it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.28it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  39%|███▊      | 387/1000 [20:56<34:23,  3.37s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.73it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.09it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.17it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.19it/s]
# Processing Samples:  39%|███▉      | 388/1000 [20:59<32:36,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.83it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:02<00:04,  1.09s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:04,  1.66s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.17it/s]
# Processing Samples:  39%|███▉      | 389/1000 [21:05<42:02,  4.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.79it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.17it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.19it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.20it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  39%|███▉      | 390/1000 [21:08<37:47,  3.72s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.77it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.19it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.28it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  39%|███▉      | 391/1000 [21:10<34:38,  3.41s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.84it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.26it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.34it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Processing Samples:  39%|███▉      | 392/1000 [21:13<32:23,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.78it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.61it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:03<00:03,  1.16s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.22s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.05it/s]
# Processing Samples:  39%|███▉      | 393/1000 [21:19<41:21,  4.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.94it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.20it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.29it/s]
# Processing Samples:  39%|███▉      | 394/1000 [21:22<36:59,  3.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.79it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.19it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.24it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.31it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.26it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Processing Samples:  40%|███▉      | 395/1000 [21:25<34:01,  3.37s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.96it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.20it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Samples:  40%|███▉      | 396/1000 [21:27<32:00,  3.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.89it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.23it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.04it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:03<00:02,  1.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.21s/it]
# Processing Samples:  40%|███▉      | 397/1000 [21:33<41:03,  4.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.86it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.21it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.27it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.33it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.31it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.29it/s]
# Processing Samples:  40%|███▉      | 398/1000 [21:36<36:44,  3.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.88it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.28it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.28it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Processing Samples:  40%|███▉      | 399/1000 [21:39<33:42,  3.36s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.84it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.19it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.22it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Samples:  40%|████      | 400/1000 [21:42<31:40,  3.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.91it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.15it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.23it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:03<00:01,  1.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.22s/it]
# Processing Samples:  40%|████      | 401/1000 [21:47<38:32,  3.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.07it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.32it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:02<00:01,  1.64it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.98it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.07it/s]
# Processing Samples:  40%|████      | 402/1000 [21:50<36:55,  3.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.77it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.16it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.27it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.29it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Samples:  40%|████      | 403/1000 [21:53<33:55,  3.41s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.81it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.11it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.24it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Processing Samples:  40%|████      | 404/1000 [21:56<31:49,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.71it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.22it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.29it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.32it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
# Processing Samples:  40%|████      | 405/1000 [21:59<31:49,  3.21s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:08,  1.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:03<00:06,  1.74s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:03,  1.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:01,  1.01it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:00,  1.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.47it/s]
# Processing Samples:  41%|████      | 406/1000 [22:05<39:12,  3.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.85it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.20it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.24it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.20it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Samples:  41%|████      | 407/1000 [22:07<35:31,  3.59s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.75it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.15it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.27it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.25it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  41%|████      | 408/1000 [22:10<33:00,  3.35s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.76it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.02it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.18it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.17it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.23it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Samples:  41%|████      | 409/1000 [22:13<31:20,  3.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.03it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:02<00:05,  1.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:04,  1.43s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.23it/s]
# Processing Samples:  41%|████      | 410/1000 [22:19<40:11,  4.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.82it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.20it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.28it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.32it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Processing Samples:  41%|████      | 411/1000 [22:22<36:02,  3.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.85it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.12it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.27it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.31it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.29it/s]
# Processing Samples:  41%|████      | 412/1000 [22:25<33:02,  3.37s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.76it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.17it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.21it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.21it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.26it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Samples:  41%|████▏     | 413/1000 [22:27<31:09,  3.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.92it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.67it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:03<00:03,  1.19s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.24s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.02it/s]
# Processing Samples:  41%|████▏     | 414/1000 [22:34<40:09,  4.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.84it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.08it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.30it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.24it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  42%|████▏     | 415/1000 [22:36<36:05,  3.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.80it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.21it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.20it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.27it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  42%|████▏     | 416/1000 [22:39<33:14,  3.41s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.89it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.01it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.18it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.18it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.21it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  42%|████▏     | 417/1000 [22:42<31:18,  3.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.78it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.15it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.60it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Processing Samples:  42%|████▏     | 418/1000 [22:48<39:53,  4.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.66it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.09it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.16it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.25it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  42%|████▏     | 419/1000 [22:51<35:54,  3.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.89it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.26it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.23it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  42%|████▏     | 420/1000 [22:54<33:04,  3.42s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.12it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.12it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.21it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.18it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  42%|████▏     | 421/1000 [22:56<31:11,  3.23s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.62it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.08it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.90it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:03<00:02,  1.13s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.20s/it]
# Processing Samples:  42%|████▏     | 422/1000 [23:03<39:52,  4.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.77it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.06it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.19it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.19it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.23it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Samples:  42%|████▏     | 423/1000 [23:05<35:49,  3.73s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.76it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.12it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.16it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.19it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.17it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  42%|████▏     | 424/1000 [23:08<33:07,  3.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.24it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.19it/s]
# Processing Samples:  42%|████▎     | 425/1000 [23:11<31:10,  3.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.93it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.16it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.32s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.24s/it]
# Processing Samples:  43%|████▎     | 426/1000 [23:17<39:20,  4.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.60it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.02it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.12it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.18it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  43%|████▎     | 427/1000 [23:20<35:35,  3.73s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.73it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.11it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.19it/s]
# Processing Samples:  43%|████▎     | 428/1000 [23:23<32:50,  3.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.75it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  2.00it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.20it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.24it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Samples:  43%|████▎     | 429/1000 [23:25<30:47,  3.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.72it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.08it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.21it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.49it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.25s/it]
# Processing Samples:  43%|████▎     | 430/1000 [23:31<36:42,  3.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.05it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.14it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:02<00:01,  1.50it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.72it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.88it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.01it/s]
# Processing Samples:  43%|████▎     | 431/1000 [23:34<35:44,  3.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.67it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.14it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.23it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.18it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  43%|████▎     | 432/1000 [23:37<32:53,  3.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.63it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.08it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.24it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.26it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Samples:  43%|████▎     | 433/1000 [23:40<30:49,  3.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.70it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.00it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.20it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.25it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.21it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  1.86it/s]
# Processing Samples:  43%|████▎     | 434/1000 [23:43<30:08,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:09,  1.94s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:03<00:06,  1.71s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:04,  1.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.02s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:00,  1.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.45it/s]
# Processing Samples:  44%|████▎     | 435/1000 [23:49<37:42,  4.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.73it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.23it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.20it/s]
# Processing Samples:  44%|████▎     | 436/1000 [23:52<34:10,  3.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.86it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.29it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.25it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Processing Samples:  44%|████▎     | 437/1000 [23:54<31:29,  3.36s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.64it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.08it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.15it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.23it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.25it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.14it/s]
# Processing Samples:  44%|████▍     | 438/1000 [23:57<29:56,  3.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.19it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:03<00:08,  2.01s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:04<00:04,  1.60s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.20s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:00,  1.07it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.29it/s]
# Processing Samples:  44%|████▍     | 439/1000 [24:03<38:38,  4.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.84it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.13it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.25it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  44%|████▍     | 440/1000 [24:06<34:43,  3.72s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.09it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.16it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Processing Samples:  44%|████▍     | 441/1000 [24:09<32:01,  3.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.12it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.26it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.20it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.18it/s]
# Processing Samples:  44%|████▍     | 442/1000 [24:12<30:13,  3.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.63it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:02<00:04,  1.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:03<00:04,  1.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.23s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.14it/s]
# Processing Samples:  44%|████▍     | 443/1000 [24:18<38:18,  4.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.75it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.05it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.15it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.17it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  44%|████▍     | 444/1000 [24:21<34:33,  3.73s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.69it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.07it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.20it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.25it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.19it/s]
# Processing Samples:  44%|████▍     | 445/1000 [24:24<31:57,  3.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.04it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.20it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.19it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.20it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Samples:  45%|████▍     | 446/1000 [24:26<30:03,  3.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.60it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:02<00:03,  1.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Processing Samples:  45%|████▍     | 447/1000 [24:33<38:20,  4.16s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.81it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.16it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.17it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.23it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.25it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  45%|████▍     | 448/1000 [24:35<34:28,  3.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.77it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.01it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.16it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.15it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.20it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Samples:  45%|████▍     | 449/1000 [24:38<31:49,  3.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.70it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.08it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.18it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.19it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  45%|████▌     | 450/1000 [24:41<29:55,  3.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.72it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.84it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:03<00:02,  1.15s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:06<00:00,  1.19s/it]
# Processing Samples:  45%|████▌     | 451/1000 [24:47<38:06,  4.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.81it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.06it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.22it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.21it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.21it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.14it/s]
# Processing Samples:  45%|████▌     | 452/1000 [24:50<34:23,  3.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:01,  2.04it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.17it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.21it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.18it/s]
# Processing Samples:  45%|████▌     | 453/1000 [24:53<31:44,  3.48s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.71it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.10it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.16it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# ...
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.64it/s]
# Processing Samples:  97%|█████████▋| 974/1000 [55:00<01:37,  3.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.16it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.01it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.86it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.83it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.68it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.66it/s]
# Processing Samples:  98%|█████████▊| 975/1000 [55:02<01:22,  3.30s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.22it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.90it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.85it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.67it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.59it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.62it/s]
# Processing Samples:  98%|█████████▊| 976/1000 [55:04<01:11,  2.98s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.16it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.84it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.85it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.79it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.64it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.66it/s]
# Processing Samples:  98%|█████████▊| 977/1000 [55:06<01:03,  2.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.79it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.89it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.67it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.04it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:04<00:01,  1.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.14s/it]
# Processing Samples:  98%|█████████▊| 978/1000 [55:12<01:19,  3.61s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:02,  1.91it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.41it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.50it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.59it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.60it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.58it/s]
# Processing Samples:  98%|█████████▊| 979/1000 [55:14<01:08,  3.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.06it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.04it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.83it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.81it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.75it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.64it/s]
# Processing Samples:  98%|█████████▊| 980/1000 [55:17<00:58,  2.93s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.01it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.00it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.81it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.75it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.65it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.65it/s]
# Processing Samples:  98%|█████████▊| 981/1000 [55:19<00:51,  2.72s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.12it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.87it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.88it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.82it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.68it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.65it/s]
# Processing Samples:  98%|█████████▊| 982/1000 [55:21<00:46,  2.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.13it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.86it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.88it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.35it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.05it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:05<00:00,  1.15s/it]
# Processing Samples:  98%|█████████▊| 983/1000 [55:26<00:56,  3.30s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.21it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.50it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:00,  2.13it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.39it/s]
# Processing Samples:  98%|█████████▊| 984/1000 [55:29<00:50,  3.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.88it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.94it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.85it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.76it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.71it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.67it/s]
# Processing Samples:  98%|█████████▊| 985/1000 [55:31<00:43,  2.89s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.99it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.02it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.94it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.76it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.69it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.54it/s]
# Processing Samples:  99%|█████████▊| 986/1000 [55:33<00:37,  2.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.09it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.02it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.81it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.79it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.73it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.62it/s]
# Processing Samples:  99%|█████████▊| 987/1000 [55:36<00:33,  2.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.04it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.06it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.82it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.80it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:04<00:00,  1.22s/it]
# Processing Samples:  99%|█████████▉| 988/1000 [55:40<00:38,  3.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.29it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.73it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:00,  2.03it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.17it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.31it/s]
# Processing Samples:  99%|█████████▉| 989/1000 [55:44<00:35,  3.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.95it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.92it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.93it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.74it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.72it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.69it/s]
# Processing Samples:  99%|█████████▉| 990/1000 [55:46<00:29,  2.91s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.87it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.95it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.91it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.73it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.72it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.68it/s]
# Processing Samples:  99%|█████████▉| 991/1000 [55:48<00:24,  2.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.92it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.95it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.92it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.77it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.76it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.74it/s]
# Processing Samples:  99%|█████████▉| 992/1000 [55:50<00:20,  2.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.81it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.93it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.88it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.75it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.18it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:04<00:00,  1.26s/it]
# Processing Samples:  99%|█████████▉| 993/1000 [55:55<00:22,  3.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.30it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  1.70it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:00,  2.01it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.16it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.29it/s]
# Processing Samples:  99%|█████████▉| 994/1000 [55:58<00:19,  3.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.14it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.88it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.85it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.82it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.67it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.69it/s]
# Processing Samples: 100%|█████████▉| 995/1000 [56:00<00:14,  2.91s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.14it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.88it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.87it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.82it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.66it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.68it/s]
# Processing Samples: 100%|█████████▉| 996/1000 [56:03<00:10,  2.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.03it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.84it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.71it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.67it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.64it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.63it/s]
# Processing Samples: 100%|█████████▉| 997/1000 [56:05<00:07,  2.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.80it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.91it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.91it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.72it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.01it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:04<00:00,  1.10s/it]
# Processing Samples: 100%|█████████▉| 998/1000 [56:09<00:06,  3.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:01<00:06,  1.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.06it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:02<00:02,  1.45it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.78it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:03<00:00,  2.00it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:03<00:00,  2.14it/s]
# Processing Samples: 100%|█████████▉| 999/1000 [56:13<00:03,  3.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:00<00:01,  3.07it/s]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:00<00:01,  3.02it/s]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:01<00:01,  2.84it/s]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.80it/s]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [00:01<00:00,  2.76it/s]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [00:02<00:00,  2.63it/s]
# Processing Samples: 100%|██████████| 1000/1000 [56:15<00:00,  3.38s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-cosamp-snr-db-12-pilot-length-all.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved
