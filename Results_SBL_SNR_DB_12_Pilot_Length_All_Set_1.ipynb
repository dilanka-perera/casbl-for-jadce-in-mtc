# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(0, 200)

# %% [markdown]
# Sparse Bayesian Learning (SBL)

# %%
def sbl_algorithm(theta, y, noise_var, max_iter=500, stopping_criterion=1e-4):
    # Sparse Bayesian Learning (SBL) for Multiple Measurement Vectors (MMV).

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess: identity matrix

    # Iterative update process
    for t in range(max_iter):
       # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute gamma update using the derived formula
        gamma_new = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Ensure non-negativity for numerical stability
        gamma_new = np.maximum(gamma_new, 1e-8)

        # Check for convergence: if change is below threshold, stop iterations
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma with new values
        Gamma = np.diagflat(gamma_new)

    # Return final estimates
    return mu_x, np.diag(Gamma)

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = sbl_algorithm(theta, received_signal, noise_power)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.41s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.40s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.80s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.91s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.23s/it]
# Processing Samples:   0%|          | 1/200 [01:52<6:13:20, 112.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.39s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.45s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.75s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.97s/it]
# Processing Samples:   1%|          | 2/200 [03:47<6:16:56, 114.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.19s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.39s/it]
# Processing Samples:   2%|▏         | 3/200 [05:40<6:12:53, 113.57s/it]
# Converged after 500 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:47, 21.51s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:23, 20.98s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<00:59, 19.68s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:19, 19.70s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 19.75s/it]
# Processing Samples:   2%|▏         | 4/200 [07:40<6:18:23, 115.83s/it]
# Converged after 452 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.81s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.38s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.70s/it]
# Processing Samples:   2%|▎         | 5/200 [09:34<6:15:12, 115.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.89s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.82s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.05s/it]
# Processing Samples:   3%|▎         | 6/200 [11:31<6:14:47, 115.92s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.31s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.01s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.20s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.57s/it]
# Processing Samples:   4%|▎         | 7/200 [13:29<6:14:30, 116.43s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.13s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.51s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.63s/it]
# Processing Samples:   4%|▍         | 8/200 [15:22<6:09:51, 115.58s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.65s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.45s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.51s/it]
# Processing Samples:   4%|▍         | 9/200 [17:22<6:11:43, 116.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.25s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.51s/it]
# Processing Samples:   5%|▌         | 10/200 [19:16<6:06:51, 115.85s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.73s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.34s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.45s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.68s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.59s/it]
# Processing Samples:   6%|▌         | 11/200 [21:11<6:04:22, 115.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.73s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.01s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 18.64s/it]
# Processing Samples:   6%|▌         | 12/200 [23:02<5:58:15, 114.34s/it]
# Converged after 440 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.93s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 19.94s/it]
# Processing Samples:   6%|▋         | 13/200 [24:59<5:58:45, 115.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.01s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:40, 20.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.94s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.80s/it]
# Processing Samples:   7%|▋         | 14/200 [26:59<6:01:21, 116.57s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.28s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.74s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.95s/it]
# Converged after 463 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.26s/it]
# Processing Samples:   8%|▊         | 15/200 [28:52<5:55:59, 115.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.05s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.69s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.13s/it]
# Processing Samples:   8%|▊         | 16/200 [30:48<5:54:51, 115.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.79s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.05s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:30<00:18, 18.37s/it]
# Converged after 441 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 18.85s/it]
# Processing Samples:   8%|▊         | 17/200 [32:38<5:47:57, 114.08s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.95s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.71s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.72s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.27s/it]
# Processing Samples:   9%|▉         | 18/200 [34:34<5:47:45, 114.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.95s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.49s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.77s/it]
# Processing Samples:  10%|▉         | 19/200 [36:28<5:45:06, 114.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:14, 18.60s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.71s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.92s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.23s/it]
# Processing Samples:  10%|█         | 20/200 [38:25<5:45:01, 115.01s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.71s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.56s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.70s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.18s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.36s/it]
# Processing Samples:  10%|█         | 21/200 [40:18<5:41:22, 114.43s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.76s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.92s/it]
# Processing Samples:  11%|█         | 22/200 [42:14<5:40:43, 114.85s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.59s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.34s/it]
# Processing Samples:  12%|█▏        | 23/200 [44:06<5:36:51, 114.19s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.60s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.01s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.11s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.81s/it]
# Processing Samples:  12%|█▏        | 24/200 [46:01<5:35:50, 114.49s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.43s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.85s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.65s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.03s/it]
# Processing Samples:  12%|█▎        | 25/200 [47:57<5:35:15, 114.95s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.99s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.14s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.14s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.39s/it]
# Converged after 486 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.64s/it]
# Processing Samples:  13%|█▎        | 26/200 [49:52<5:33:08, 114.88s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.92s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.98s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.64s/it]
# Processing Samples:  14%|█▎        | 27/200 [51:46<5:30:20, 114.57s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.04s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.00s/it]
# Processing Samples:  14%|█▍        | 28/200 [53:39<5:27:05, 114.10s/it]
# Converged after 452 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.13s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.56s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.15s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.47s/it]
# Processing Samples:  14%|█▍        | 29/200 [55:33<5:25:00, 114.04s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:54, 18.25s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.34s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.61s/it]
# Processing Samples:  15%|█▌        | 30/200 [57:28<5:23:45, 114.27s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.22s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.11s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.56s/it]
# Processing Samples:  16%|█▌        | 31/200 [59:22<5:21:29, 114.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.24s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.62s/it]
# Processing Samples:  16%|█▌        | 32/200 [1:01:17<5:20:21, 114.41s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.42s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.84s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.06s/it]
# Processing Samples:  16%|█▋        | 33/200 [1:03:12<5:19:28, 114.78s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.46s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.50s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.41s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 18.51s/it]
# Processing Samples:  17%|█▋        | 34/200 [1:05:03<5:14:06, 113.53s/it]
# Converged after 413 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.98s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.70s/it]
# Processing Samples:  18%|█▊        | 35/200 [1:06:57<5:12:59, 113.82s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:53, 17.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.71s/it]
# Processing Samples:  18%|█▊        | 36/200 [1:08:52<5:11:51, 114.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.30s/it]
# Processing Samples:  18%|█▊        | 37/200 [1:10:48<5:11:48, 114.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.40s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:36, 18.25s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.54s/it]
# Processing Samples:  19%|█▉        | 38/200 [1:12:41<5:08:30, 114.27s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.34s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:14, 18.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.92s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.86s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.18s/it]
# Processing Samples:  20%|█▉        | 39/200 [1:14:38<5:08:30, 114.97s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.73s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.11s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.17s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.55s/it]
# Processing Samples:  20%|██        | 40/200 [1:16:32<5:05:24, 114.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.27s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.81s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:54, 18.32s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.82s/it]
# Processing Samples:  20%|██        | 41/200 [1:18:27<5:04:09, 114.78s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.37s/it]
# Processing Samples:  21%|██        | 42/200 [1:20:20<5:01:13, 114.39s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:54, 18.26s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.45s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.80s/it]
# Processing Samples:  22%|██▏       | 43/200 [1:22:16<5:00:10, 114.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.04s/it]
# Processing Samples:  22%|██▏       | 44/200 [1:24:11<4:58:51, 114.94s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.94s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.95s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.53s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.55s/it]
# Processing Samples:  22%|██▎       | 45/200 [1:26:05<4:56:11, 114.65s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.50s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.91s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.96s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.12s/it]
# Processing Samples:  23%|██▎       | 46/200 [1:28:02<4:55:43, 115.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.69s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.24s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 18.94s/it]
# Processing Samples:  24%|██▎       | 47/200 [1:29:54<4:51:09, 114.18s/it]
# Converged after 457 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.86s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.75s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.60s/it]
# Processing Samples:  24%|██▍       | 48/200 [1:31:48<4:49:07, 114.13s/it]
# Converged after 478 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.89s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.01s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.27s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.53s/it]
# Processing Samples:  24%|██▍       | 49/200 [1:33:42<4:47:01, 114.05s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.02s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.81s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.68s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.05s/it]
# Processing Samples:  25%|██▌       | 50/200 [1:35:37<4:46:14, 114.50s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.05s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.50s/it]
# Processing Samples:  26%|██▌       | 51/200 [1:37:31<4:43:33, 114.18s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.07s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.68s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.31s/it]
# Converged after 498 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 19.92s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:39:27<4:43:06, 114.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.96s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.38s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:41:20<4:40:00, 114.29s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.75s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.69s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:43:15<4:38:47, 114.57s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.98s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.57s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.05s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.45s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:45:09<4:36:11, 114.29s/it]
# Converged after 490 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.81s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:53, 17.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.34s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.58s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.63s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:47:03<4:34:26, 114.35s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.88s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.86s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.35s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:49:00<4:33:58, 114.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.52s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.67s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.41s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.54s/it]
# Processing Samples:  29%|██▉       | 58/200 [1:50:54<4:31:28, 114.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.48s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.07s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.71s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.09s/it]
# Processing Samples:  30%|██▉       | 59/200 [1:52:50<4:30:58, 115.31s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.75s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.94s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 22.07s/it]
# Processing Samples:  30%|███       | 60/200 [1:54:53<4:34:14, 117.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.80s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.56s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.59s/it]
# Processing Samples:  30%|███       | 61/200 [1:56:48<4:30:26, 116.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:38, 19.62s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.73s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.95s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.96s/it]
# Processing Samples:  31%|███       | 62/200 [1:58:45<4:28:42, 116.83s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.13s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.49s/it]
# Processing Samples:  32%|███▏      | 63/200 [2:00:43<4:27:32, 117.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 18.79s/it]
# Processing Samples:  32%|███▏      | 64/200 [2:02:34<4:21:33, 115.39s/it]
# Converged after 444 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.21s/it]
# Processing Samples:  32%|███▎      | 65/200 [2:04:30<4:19:57, 115.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.27s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.51s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.87s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.17s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.30s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.46s/it]
# Processing Samples:  33%|███▎      | 66/200 [2:06:24<4:16:50, 115.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.58s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.88s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.55s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.08s/it]
# Processing Samples:  34%|███▎      | 67/200 [2:08:20<4:15:45, 115.38s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.32s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.47s/it]
# Processing Samples:  34%|███▍      | 68/200 [2:10:14<4:12:41, 114.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.99s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.38s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.40s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.25s/it]
# Processing Samples:  34%|███▍      | 69/200 [2:12:08<4:10:14, 114.62s/it]
# Converged after 459 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.16s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.15s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.11s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.60s/it]
# Processing Samples:  35%|███▌      | 70/200 [2:14:02<4:08:04, 114.49s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.63s/it]
# Processing Samples:  36%|███▌      | 71/200 [2:15:57<4:06:31, 114.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.84s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:49<00:00, 17.90s/it]
# Processing Samples:  36%|███▌      | 72/200 [2:17:46<4:01:02, 112.99s/it]
# Converged after 385 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.89s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.53s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.61s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.57s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.81s/it]
# Processing Samples:  36%|███▋      | 73/200 [2:19:42<4:01:02, 113.87s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.27s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.60s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.97s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.15s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 18.80s/it]
# Processing Samples:  37%|███▋      | 74/200 [2:21:34<3:57:57, 113.31s/it]
# Converged after 457 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.02s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:13, 18.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.61s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.74s/it]
# Processing Samples:  38%|███▊      | 75/200 [2:23:30<3:57:30, 114.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:24, 17.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.48s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.18s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.20s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:25:26<3:57:03, 114.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.56s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.23s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 18.89s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:27:17<3:53:00, 113.67s/it]
# Converged after 451 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.38s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.78s/it]
# ...
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.91s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.74s/it]
# Processing Samples:  88%|████████▊ | 175/200 [5:33:40<47:41, 114.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.18s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.26s/it]
# Processing Samples:  88%|████████▊ | 176/200 [5:35:32<45:31, 113.82s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.51s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:54, 18.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.68s/it]
# Processing Samples:  88%|████████▊ | 177/200 [5:37:27<43:47, 114.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.31s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.82s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.63s/it]
# Processing Samples:  89%|████████▉ | 178/200 [5:39:21<41:50, 114.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.29s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.86s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.17s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.54s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.54s/it]
# Processing Samples:  90%|████████▉ | 179/200 [5:41:15<39:55, 114.06s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.95s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.27s/it]
# Processing Samples:  90%|█████████ | 180/200 [5:43:11<38:14, 114.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.67s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.48s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.54s/it]
# Processing Samples:  90%|█████████ | 181/200 [5:45:05<36:12, 114.36s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.57s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.63s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.05s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.90s/it]
# Processing Samples:  91%|█████████ | 182/200 [5:47:01<34:26, 114.82s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.25s/it]
# Processing Samples:  92%|█████████▏| 183/200 [5:48:53<32:19, 114.10s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.24s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.04s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.19s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.15s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.55s/it]
# Processing Samples:  92%|█████████▏| 184/200 [5:50:47<30:24, 114.05s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.84s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 19.06s/it]
# Processing Samples:  92%|█████████▎| 185/200 [5:52:39<28:19, 113.30s/it]
# Converged after 496 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.45s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.45s/it]
# Processing Samples:  93%|█████████▎| 186/200 [5:54:33<26:29, 113.55s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.15s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.50s/it]
# Processing Samples:  94%|█████████▎| 187/200 [5:56:26<24:34, 113.43s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.87s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:36, 18.07s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.45s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.49s/it]
# Processing Samples:  94%|█████████▍| 188/200 [5:58:19<22:41, 113.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.82s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.72s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.07s/it]
# Processing Samples:  94%|█████████▍| 189/200 [6:00:15<20:55, 114.12s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.95s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 19.16s/it]
# Processing Samples:  95%|█████████▌| 190/200 [6:02:07<18:54, 113.43s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:14, 18.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.27s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.80s/it]
# Processing Samples:  96%|█████████▌| 191/200 [6:04:02<17:03, 113.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 18.63s/it]
# Processing Samples:  96%|█████████▌| 192/200 [6:05:52<15:03, 112.93s/it]
# Converged after 447 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.34s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.91s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.44s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.68s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.77s/it]
# Processing Samples:  96%|█████████▋| 193/200 [6:07:47<13:14, 113.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.60s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.99s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.14s/it]
# Processing Samples:  97%|█████████▋| 194/200 [6:09:39<11:18, 113.06s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.68s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:54, 18.27s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.22s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.25s/it]
# Processing Samples:  98%|█████████▊| 195/200 [6:11:33<09:26, 113.22s/it]
# Converged after 466 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.86s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 17.00s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:51, 17.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:31<00:18, 18.84s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.28s/it]
# Processing Samples:  98%|█████████▊| 196/200 [6:13:22<07:27, 111.91s/it]
# Converged after 430 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.70s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.53s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.51s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.65s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.92s/it]
# Processing Samples:  98%|█████████▊| 197/200 [6:15:16<05:38, 112.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.12s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.13s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 18.74s/it]
# Processing Samples:  99%|█████████▉| 198/200 [6:17:07<03:43, 111.98s/it]
# Converged after 451 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.81s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:49<00:00, 18.18s/it]
# Processing Samples: 100%|█████████▉| 199/200 [6:18:56<01:51, 111.15s/it]
# Converged after 422 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.61s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.66s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.69s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:20, 20.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 19.96s/it]
# Processing Samples: 100%|██████████| 200/200 [6:20:53<00:00, 114.27s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# Print average results
print("Avg HR  :", avg_hr)
print("Avg SRR :", avg_srr)
print("Avg FR  :", avg_fr)
print("Avg PR  :", avg_pr)
print("Avg RE  :", avg_re)
print("Avg F1  :", avg_f1)
print("Avg NMSE:", avg_nmse)
# Out:
# Avg HR  : [ 9.695 14.17  18.13  19.7   19.875 19.95 ]
# Avg SRR : [0.04408565 0.0760577  0.12287425 0.16089295 0.17428426 0.18144599]
# Avg FR  : [0.79631579 0.68763158 0.45236842 0.23236842 0.14921053 0.10710526]
# Avg PR  : [0.07865811 0.10512795 0.13734351 0.16438619 0.176008   0.18220523]
# Avg RE  : [0.09695 0.1417  0.1813  0.197   0.19875 0.1995 ]
# Avg F1  : [0.08663715 0.12045952 0.15591072 0.17895616 0.18642674 0.19027332]
# Avg NMSE: [0.13836597 0.09381184 0.04558575 0.02126877 0.01465544 0.0113012 ]

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-sbl-snr-db-12-pilot-length-all-set-1.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved

# %%
import matplotlib.pyplot as plt

# Define the SNR values for x-axis
pilot_length_values = pilot_length_array

# Create subplots for different performance metrics
plt.figure(figsize=(15, 14))

# Plot Hit Rate (HR)
plt.subplot(4, 2, 1)
plt.plot(pilot_length_values, avg_hr, marker='o', linestyle='-', color='b', label='HR')
plt.xlabel("Pilot Length")
plt.ylabel("Hit Rate (%)")
plt.title("Hit Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot False Alarm Rate (FR)
plt.subplot(4, 2, 2)
plt.plot(pilot_length_values, avg_fr, marker='^', linestyle='-', color='g', label='FR')
plt.xlabel("Pilot Length")
plt.ylabel("False Alarm Rate (%)")
plt.title("False Alarm Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Support Recovery Rate (SRR)
plt.subplot(4, 2, 3)
plt.plot(pilot_length_values, avg_srr, marker='s', linestyle='-', color='r', label='SRR')
plt.xlabel("Pilot Length")
plt.ylabel("Support Recovery Rate")
plt.title("Support Recovery Rate vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Precision (PR)
plt.subplot(4, 2, 4)
plt.plot(pilot_length_values, avg_pr, marker='x', linestyle='-', color='c', label='PR')
plt.xlabel("Pilot Length")
plt.ylabel("Precision")
plt.title("Precision vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Recall (RE)
plt.subplot(4, 2, 5)
plt.plot(pilot_length_values, avg_re, marker='p', linestyle='-', color='y', label='RE')
plt.xlabel("Pilot Length")
plt.ylabel("Recall")
plt.title("Recall vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot F1 Score (F1)
plt.subplot(4, 2, 6)
plt.plot(pilot_length_values, avg_f1, marker='*', linestyle='-', color='k', label='F1 Score')
plt.xlabel("Pilot Length")
plt.ylabel("F1 Score")
plt.title("F1 Score vs Pilot Length")
plt.grid(True)
plt.legend()

# Plot Normalized MSE (NMSE)
plt.subplot(4, 2, 7)
plt.plot(pilot_length_values, avg_nmse, marker='d', linestyle='-', color='m', label='NMSE')
plt.xlabel("Pilot Length")
plt.ylabel("Normalized MSE")
plt.title("Normalized MSE vs Pilot Length")
plt.yscale('log')  # Log scale for better visualization
plt.grid(True)
plt.legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_res_vs_ground_truth(sbl_results, Z, sample_index, snr_index, snr_value):
    """Plot sbl reconstructed signal vs ground truth (Z) for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    # Ground truth (Z)
    plt.plot(np.abs(Z[sample_index,:,0]), marker='s', linestyle='--', color='g', label="Ground Truth (Z)")

    # sbl Estimated Signal
    plt.plot(np.abs(sbl_results[sample_index, snr_index, :, 0]), marker='o', linestyle='-', color='b', label="sbl Estimate")

    plt.xlabel("Device Index")
    plt.ylabel("Magnitude of Signal")
    plt.title(f"sbl vs. Ground Truth (Sample {sample_index}, SNR {snr_value} dB)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_res_vs_ground_truth(z_res, all_z, sample_index, snr_index, snr_value)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_gamma_res_vs_ground_truth(gamma_res, gamma_true, sample_index, snr_index, snr_value):
    """Plot sbl estimated gamma vs ground truth gamma for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    device_indices = np.arange(len(gamma_true[sample_index]))  # X-axis: Device indices

    # Plot ground truth gamma (binary)
    plt.stem(device_indices, gamma_true[sample_index], linefmt='g--', markerfmt='gs', basefmt=" ", label="Ground Truth (γ)")

    # Plot sbl estimated gamma
    plt.stem(device_indices, gamma_res[sample_index, snr_index], linefmt='b-', markerfmt='bo', basefmt=" ", label="sbl Estimate (γ)")

    plt.xlabel("Device Index")
    plt.ylabel("Activity Indicator (0=Inactive, 1=Active)")
    plt.title(f"Device Activity (sbl vs. Ground Truth) - Sample {sample_index}, SNR {snr_value} dB")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_gamma_res_vs_ground_truth(gamma_res, all_gamma, sample_index, snr_index, snr_value)
