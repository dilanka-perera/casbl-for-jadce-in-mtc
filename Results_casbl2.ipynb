# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data_general_model = np.load('/content/drive/My Drive/Github/mtc-device-activation/e4_general_model.npz', allow_pickle=True)
data_communication_simulation = np.load('/content/drive/My Drive/Github/mtc-device-activation/e4_communication_simulation.npz', allow_pickle=True)
# Out:
# Mounted at /content/drive

# %%
# Access the saved data from the .npz file
all_EventCount = data_general_model['all_EventCount']
all_DeviceActiveCount = data_general_model['all_DeviceActiveCount']
all_DeviceProbability = data_general_model['all_DeviceProbability']
all_DeviceAlarmStatus = data_general_model['all_DeviceAlarmStatus']
all_DeviceStatus = data_general_model['all_DeviceStatus']
all_DeviceLocations = data_general_model['all_DeviceLocations']
all_DeviceLocationsPolar = data_general_model['all_DeviceLocationsPolar']
all_EventLocations = data_general_model['all_EventLocations']
all_EventLocationsPolar = data_general_model['all_EventLocationsPolar']
device_count = data_general_model['device_count']
event_count = data_general_model['event_count']
bs_location = data_general_model['bs_location']
bs_radius = data_general_model['bs_radius']
k = data_general_model['k']
sparsity = data_general_model['sparsity']
num_samples = data_general_model['num_samples']

all_theta = data_communication_simulation['all_theta']
all_gamma = data_communication_simulation['all_gamma']
all_Z = data_communication_simulation['all_Z']
all_noise = data_communication_simulation['all_noise']
all_received_signal = data_communication_simulation['all_received_signal']
seq_length = data_communication_simulation['seq_length']
snr_db_array = data_communication_simulation['snr_db_array']
M = data_communication_simulation['M']

# %%
num_samples=10

# %%
print(M)
# Out:
# 4

# %%
print(all_DeviceLocations.shape)
# Out:
# (1000, 400, 2)

# %% [markdown]
# casbl2

# %%
import numpy as np

def casbl2_algorithm(A, y, N, sig2e, Tau_p, loc, k, max_iter_casbl2=500, stopping_criterion=1e-4):
    """Correlated Sparse Bayesian Learning (CaSBL2) for Multiple Measurement Vectors (MMV)."""

    M = y.shape[1]  # Number of antennas

    # Initialize Gamma (device activity probabilities)
    Gamma = np.eye(N) * 0.1  # Initial guess
    xhat_casbl2 = np.zeros((N, M), dtype=np.complex128)  # Final estimate

    # Compute pairwise distances (N x N matrix)
    distance_matrix = np.linalg.norm(loc[:, np.newaxis, :] - loc[np.newaxis, :, :], axis=2)

    # Compute correlation matrix C_{lm}
    correlation_matrix = np.exp(-distance_matrix / k)  # N x N

    for t in range(max_iter_casbl2):
        # Compute mean and covariance of x
        Gamma_inv = np.linalg.solve(Gamma, np.eye(Gamma.shape[0]))
        Sigma_x_inv = (1/sig2e) * A.conj().T @ A + Gamma_inv
        Sigma_x = np.linalg.solve(Sigma_x_inv, np.eye(Sigma_x_inv.shape[0], dtype=np.complex128))
        mu_x = (1/sig2e) * Sigma_x @ A.conj().T @ y

        # Compute Q(m) = (1/M) ||mu_x(m,:)||^2 + Sigma_x(m,m)
        Q = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Compute gamma update using sum over correlations
        gamma_new = correlation_matrix @ Q  # Vectorized sum over m

        # Ensure numerical stability
        gamma_new = np.nan_to_num(gamma_new, nan=0.0, posinf=1.0, neginf=0.0)

        # Check for convergence
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma
        Gamma = np.diagflat(gamma_new)

    return mu_x, np.diag(Gamma)  # Final estimates

# %%
# Placeholder arrays for casbl2 results
Z_casbl2 = np.zeros((num_samples, len(snr_db_array), device_count, M), dtype=np.complex128)  # casbl2 results
gamma_casbl2 = np.zeros((num_samples, len(snr_db_array), device_count), dtype=bool)  # casbl2 gamma values
hit_rate_casbl2 = np.zeros((num_samples, len(snr_db_array)))  # Hit rate for casbl2
miss_detection_rate_casbl2 = np.zeros((num_samples, len(snr_db_array)))  # Miss detection rate for casbl2
false_alarm_rate_casbl2 = np.zeros((num_samples, len(snr_db_array)))  # False alarm rate for casbl2
norm_mse_casbl2 = np.zeros((num_samples, len(snr_db_array)))  # Norm MSE for casbl2

# %%
from tqdm import tqdm

# Loop through each sample with an outer progress bar
for sample_index in tqdm(range(num_samples), desc="Processing Samples", position=0):
    theta = all_theta[sample_index]
    gamma = all_gamma[sample_index]  # True gamma values (ground truth)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for snr_index in tqdm(range(len(snr_db_array)), desc="Processing SNR Levels", leave=False, position=1):
        received_signal = all_received_signal[sample_index, snr_index]
        Z = all_Z[sample_index]
        snr_db = snr_db_array[snr_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.dot(theta, Z))**2)
        noise_power = signal_power / snr

        # Apply casbl2 algorithm for the current sample and SNR level
        Z_result, gamma_result = casbl2_algorithm(theta, received_signal, device_count, noise_power, seq_length, loc, 3.6)

        # Store the results
        Z_casbl2[sample_index, snr_index, :, :] = Z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_casbl2[sample_index, snr_index, :] = gamma_result_bool

        # Avoid division by zero in hit/miss/false alarm rate calculations
        active_devices = np.sum(gamma == 1)  # True active devices
        inactive_devices = np.sum(gamma == 0)  # True inactive devices

        # Calculate the hit rate for casbl2
        hit_rate_casbl2[sample_index, snr_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # Calculate the miss detection rate for casbl2
        miss_detection_rate_casbl2[sample_index, snr_index] = (
            100 * np.sum((gamma_result_bool == 0) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # Calculate the false alarm rate for casbl2
        false_alarm_rate_casbl2[sample_index, snr_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Calculate the normalized MSE for casbl2
        norm_mse_casbl2[sample_index, snr_index] = (
            np.linalg.norm(Z - Z_result)**2 / max(1e-10, np.linalg.norm(Z)**2)
        )  # Avoid division by zero
# Out:
# Processing Samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:57<04:46, 57.24s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:30<02:53, 43.32s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:54<01:43, 34.54s/it]
# Converged after 177 iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:36<01:14, 37.29s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:14<00:37, 37.43s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:48<00:00, 36.49s/it]
# Processing Samples:  10%|█         | 1/10 [03:48<34:18, 228.76s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:35<02:59, 35.85s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:11<02:23, 35.78s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:47<01:47, 35.97s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:24<01:12, 36.45s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [02:59<00:35, 35.84s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:35<00:00, 35.74s/it]
# Processing Samples:  20%|██        | 2/10 [07:24<29:26, 220.84s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:35<02:59, 35.82s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:14<02:30, 37.52s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:50<01:49, 36.63s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:26<01:13, 36.60s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:03<00:36, 36.75s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:38<00:00, 36.16s/it]
# Processing Samples:  30%|███       | 3/10 [11:02<25:39, 219.87s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:33<02:48, 33.77s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:10<02:22, 35.67s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:45<01:45, 35.29s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:19<01:09, 34.67s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [02:58<00:36, 36.43s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:34<00:00, 36.24s/it]
# Processing Samples:  40%|████      | 4/10 [14:37<21:47, 217.86s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:37<03:07, 37.46s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:12<02:23, 35.78s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:46<01:46, 35.35s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:23<01:11, 35.78s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:00<00:36, 36.20s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:38<00:00, 36.82s/it]
# Processing Samples:  50%|█████     | 5/10 [18:15<18:10, 218.03s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:38<03:11, 38.22s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:15<02:30, 37.58s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:50<01:49, 36.40s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:26<01:12, 36.49s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:03<00:36, 36.37s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:43<00:00, 37.58s/it]
# Processing Samples:  60%|██████    | 6/10 [21:58<14:39, 219.75s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:35<02:57, 35.47s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:09<02:19, 34.91s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:47<01:48, 36.22s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:22<01:11, 35.71s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:00<00:36, 36.46s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:38<00:00, 36.87s/it]
# Processing Samples:  70%|███████   | 7/10 [25:37<10:57, 219.23s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:37<03:07, 37.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:11<02:21, 35.45s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:45<01:44, 34.89s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:23<01:11, 35.83s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [02:57<00:35, 35.37s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:30<00:00, 34.61s/it]
# Processing Samples:  80%|████████  | 8/10 [29:07<07:13, 216.52s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:38<03:14, 38.80s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:14<02:27, 36.81s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:51<01:50, 36.84s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:26<01:12, 36.10s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:02<00:36, 36.37s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:37<00:00, 35.65s/it]
# Processing Samples:  90%|█████████ | 9/10 [32:45<03:36, 216.73s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:40<03:20, 40.07s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [01:14<02:27, 36.84s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [01:50<01:49, 36.55s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [02:26<01:12, 36.04s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [03:00<00:35, 35.37s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [03:37<00:00, 36.06s/it]
# Processing Samples: 100%|██████████| 10/10 [36:22<00:00, 218.28s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hit_rate_casbl2 = np.mean(hit_rate_casbl2, axis=0)  # Shape: (len(snr_db_array),)
avg_miss_detection_rate_casbl2 = np.mean(miss_detection_rate_casbl2, axis=0)  # Shape: (len(snr_db_array),)
avg_false_alarm_rate_casbl2 = np.mean(false_alarm_rate_casbl2, axis=0)  # Shape: (len(snr_db_array),)
avg_norm_mse_casbl2 = np.mean(norm_mse_casbl2, axis=0)  # Shape: (len(snr_db_array),)

# Print or log the results
print("Average Hit Rate across samples per SNR level:", avg_hit_rate_casbl2)
print("Average Miss Detection Rate across samples per SNR level:", avg_miss_detection_rate_casbl2)
print("Average False Alarm Rate across samples per SNR level:", avg_false_alarm_rate_casbl2)
print("Average Normalized MSE across samples per SNR level:", avg_norm_mse_casbl2)
# Out:
# Average Hit Rate across samples per SNR level: [40.  41.  61.  55.5 80.5 31. ]
# Average Miss Detection Rate across samples per SNR level: [60.  59.  39.  44.5 19.5 69. ]
# Average False Alarm Rate across samples per SNR level: [38.73684211 39.68421053 58.68421053 50.23684211 81.39473684 31.28947368]
# Average Normalized MSE across samples per SNR level: [3.35954118e+06 1.42797934e+08 1.66368485e+06 1.34809985e+07
#  2.07008327e+06 1.37116063e+06]

# %%
np.savez_compressed('/content/drive/My Drive/Github/mtc-device-activation/e4_results_casbl2.npz',
                    Z_casbl2=Z_casbl2,
                    gamma_casbl2=gamma_casbl2,
                    hit_rate_casbl2=hit_rate_casbl2,
                    miss_detection_rate_casbl2=miss_detection_rate_casbl2,
                    false_alarm_rate_casbl2=false_alarm_rate_casbl2,
                    norm_mse_casbl2=norm_mse_casbl2,
                    avg_hit_rate_casbl2=avg_hit_rate_casbl2,
                    avg_miss_detection_rate_casbl2=avg_miss_detection_rate_casbl2,
                    avg_false_alarm_rate_casbl2=avg_false_alarm_rate_casbl2,
                    avg_norm_mse_casbl2=avg_norm_mse_casbl2)

print("All results have been saved to 'communication_simulation_results_all_samples.npz'.")
# Out:
# All results have been saved to 'communication_simulation_results_all_samples.npz'.

# %%
import matplotlib.pyplot as plt

# Define the SNR values for x-axis
snr_values = snr_db_array

# Create subplots for different performance metrics
plt.figure(figsize=(12, 8))

# Plot Hit Rate
plt.subplot(2, 2, 1)
plt.plot(snr_values, avg_hit_rate_casbl2, marker='o', linestyle='-', color='b', label='Hit Rate')
plt.xlabel("SNR (dB)")
plt.ylabel("Hit Rate (%)")
plt.title("Hit Rate vs SNR")
plt.grid(True)
plt.legend()

# Plot Miss Detection Rate
plt.subplot(2, 2, 2)
plt.plot(snr_values, avg_miss_detection_rate_casbl2, marker='s', linestyle='-', color='r', label='Miss Detection Rate')
plt.xlabel("SNR (dB)")
plt.ylabel("Miss Detection Rate (%)")
plt.title("Miss Detection Rate vs SNR")
plt.grid(True)
plt.legend()

# Plot False Alarm Rate
plt.subplot(2, 2, 3)
plt.plot(snr_values, avg_false_alarm_rate_casbl2, marker='^', linestyle='-', color='g', label='False Alarm Rate')
plt.xlabel("SNR (dB)")
plt.ylabel("False Alarm Rate (%)")
plt.title("False Alarm Rate vs SNR")
plt.grid(True)
plt.legend()

# Plot Normalized MSE
plt.subplot(2, 2, 4)
plt.plot(snr_values, avg_norm_mse_casbl2, marker='d', linestyle='-', color='m', label='Normalized MSE')
plt.xlabel("SNR (dB)")
plt.ylabel("Normalized MSE")
plt.title("Normalized MSE vs SNR")
plt.yscale('log')  # Log scale for better visualization
plt.grid(True)
plt.legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_casbl2_vs_ground_truth(casbl2_results, Z, sample_index, snr_index, snr_value):
    """Plot casbl2 reconstructed signal vs ground truth (Z) for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    # Ground truth (Z)
    plt.plot(np.abs(Z[sample_index,:,0]), marker='s', linestyle='--', color='g', label="Ground Truth (Z)")

    # casbl2 Estimated Signal
    plt.plot(np.abs(casbl2_results[sample_index, snr_index, :, 0]), marker='o', linestyle='-', color='b', label="casbl2 Estimate")

    plt.xlabel("Device Index")
    plt.ylabel("Magnitude of Signal")
    plt.title(f"casbl2 vs. Ground Truth (Sample {sample_index}, SNR {snr_value} dB)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_casbl2_vs_ground_truth(Z_casbl2, all_Z, sample_index, snr_index, snr_value)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_gamma_casbl2_vs_ground_truth(gamma_casbl2, gamma_true, sample_index, snr_index, snr_value):
    """Plot casbl2 estimated gamma vs ground truth gamma for a single sample at a given SNR."""
    plt.figure(figsize=(10, 5))

    device_indices = np.arange(len(gamma_true[sample_index]))  # X-axis: Device indices

    # Plot ground truth gamma (binary)
    plt.stem(device_indices, gamma_true[sample_index], linefmt='g--', markerfmt='gs', basefmt=" ", label="Ground Truth (γ)")

    # Plot casbl2 estimated gamma
    plt.stem(device_indices, gamma_casbl2[sample_index, snr_index], linefmt='b-', markerfmt='bo', basefmt=" ", label="casbl2 Estimate (γ)")

    plt.xlabel("Device Index")
    plt.ylabel("Activity Indicator (0=Inactive, 1=Active)")
    plt.title(f"Device Activity (casbl2 vs. Ground Truth) - Sample {sample_index}, SNR {snr_value} dB")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sample_index = 0  # Choose a specific sample
snr_index = 5  # Choose a specific SNR index
snr_value = snr_db_array[snr_index]

plot_gamma_casbl2_vs_ground_truth(gamma_casbl2, all_gamma, sample_index, snr_index, snr_value)
