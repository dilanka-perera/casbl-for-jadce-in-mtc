# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 1
pilot_length=pilot_length_array[pilot_length_index]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]

alpha_array = [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]
beta = 0.25
# Out:
# Mounted at /content/drive

# %%
num_samples = 100
sample_range = range(0, 100)

# %% [markdown]
# Correlation-Aware Sparse Bayesian Learning (CA-SBL)

# %%
def casbl_anc_algorithm(theta, y, noise_var, loc, alpha=0.5, beta=0.2, rho=7, U=20, max_iter=500, stopping_criterion=1e-4):
    """Correlation Aware Sparse Bayesian Learning (CASBL) for Multiple Measurement Vectors (MMV)."""

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess

    if rho == 0:
        correlation_matrix = np.eye(N)  # Identity matrix when no correlation
    else:
        # Compute pairwise distances (N x N matrix)
        distance_matrix = np.linalg.norm(loc[:, np.newaxis, :] - loc[np.newaxis, :, :], axis=2)

        # Compute exponential decay matrix
        correlation_matrix = np.maximum((np.exp(-distance_matrix / rho) - np.exp(-U / rho)) / (1 - np.exp(-U / rho)),0)

    # Outer loop over the maximum number of iterations
    for t in range(max_iter):
        # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute Q
        Q = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.diag(Sigma_x)

        # Compute P
        P = 2 * alpha * (beta - correlation_matrix) @ np.diag(Gamma)
        P = np.maximum(P, 1e-8)

        # Compute gamma update
        gamma_new = (np.sqrt(1 + 4 * P * Q) - 1) / (2 * P)

        # Ensure non-negativity (numerical stability)
        gamma_new = np.clip(np.real(gamma_new), 0, 1)

        # Update Gamma
        Gamma_old = np.diag(Gamma)
        Gamma = np.diagflat(gamma_new)

        # Check for convergence
        if np.linalg.norm(Gamma_old - gamma_new) < stopping_criterion:
            print(f"Converged after {t+1} outer iterations")
            break

    Gamma = np.where(Gamma < 0.05, 0, 1)

    Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
    Sigma_y_inv = np.linalg.inv(Sigma_y)
    Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
    mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

    return mu_x, np.diag(Gamma)  # Final estimates

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(alpha_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(alpha_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(alpha_array)))         # HR
fr_res = np.zeros((num_samples, len(alpha_array)))         # FR
srr_res = np.zeros((num_samples, len(alpha_array)))        # SRR
precision_res = np.zeros((num_samples, len(alpha_array)))  # Precision
recall_res = np.zeros((num_samples, len(alpha_array)))     # Recall
f1_res = np.zeros((num_samples, len(alpha_array)))         # F1
nmse_res = np.zeros((num_samples, len(alpha_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    theta = all_theta[sample_index, pilot_length_index, :pilot_length]
    gamma = all_gamma[sample_index]  # True gamma values (ground truth)
    loc = all_DeviceLocations[sample_index]

    received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
    z = all_z[sample_index]
    snr_db = snr_db_array[snr_db_index]
    snr = 10 ** (snr_db / 10)
    signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
    noise_power = signal_power / snr

    # Loop over each SNR level with an inner progress bar
    for alpha_index in tqdm(range(len(alpha_array)), desc="Processing alpha Levels", leave=False, position=1):
        alpha = alpha_array[alpha_index]

        # Apply casbl algorithm for the current sample and SNR level
        z_result, gamma_result = casbl_anc_algorithm(theta, received_signal, noise_power, loc, alpha=alpha, beta=beta)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, alpha_index, :, :] = z_result
        gamma_result_bool = gamma_result > 0.05
        gamma_res[sample_index, alpha_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, alpha_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, alpha_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, alpha_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, alpha_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, alpha_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, alpha_index] + recall_res[sample_index, alpha_index]) > 0:
            f1_res[sample_index, alpha_index] = (
                2 * precision_res[sample_index, alpha_index] * recall_res[sample_index, alpha_index]
                /
                (precision_res[sample_index, alpha_index] + recall_res[sample_index, alpha_index])
            )
        else:
            f1_res[sample_index, alpha_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, alpha_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.70s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:06, 18.12s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:54, 19.13s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:35, 19.19s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:33<01:14, 18.69s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:51<00:55, 18.43s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:12<00:38, 19.17s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:32<00:19, 19.37s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:50<00:00, 18.95s/it]
# Processing Samples:   1%|          | 1/100 [02:50<4:40:58, 170.29s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:30, 18.78s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.33s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.18s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:33, 18.75s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:34<01:14, 18.59s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:58, 19.58s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:38, 19.15s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:32<00:18, 18.80s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:50<00:00, 18.62s/it]
# Processing Samples:   2%|▏         | 2/100 [05:40<4:38:19, 170.40s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:53, 21.66s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:15, 19.42s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:57<01:52, 18.75s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:23<01:47, 21.49s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:21, 20.27s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:58, 19.61s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.17s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.36s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 19.64s/it]
# Processing Samples:   3%|▎         | 3/100 [08:39<4:41:42, 174.25s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:33, 19.13s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:27, 21.01s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:00, 20.08s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:37, 19.41s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:22, 20.55s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:59, 19.82s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.55s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.25s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 20.05s/it]
# Processing Samples:   4%|▍         | 4/100 [11:39<4:42:32, 176.59s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:30, 18.82s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.35s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:59, 19.96s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:37, 19.40s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:15, 18.97s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:00, 20.00s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.73s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.26s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 19.92s/it]
# Processing Samples:   5%|▌         | 5/100 [14:37<4:40:00, 176.85s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:32, 19.04s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:12, 18.94s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:52, 18.73s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:40, 20.01s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.40s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:57, 19.28s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:38, 19.08s/it]
# Converged after 475 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:20, 20.54s/it]
# Converged after 480 outer iterations
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.63s/it]
# Processing Samples:   6%|▌         | 6/100 [17:32<4:36:27, 176.47s/it]
# Converged after 483 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.57s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:25, 20.75s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:57, 19.61s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.13s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:15, 18.94s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:59, 19.95s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.66s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.28s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 20.07s/it]
# Processing Samples:   7%|▋         | 7/100 [20:30<4:33:59, 176.77s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.34s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.36s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:54<01:49, 18.31s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:38, 19.77s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:17, 19.37s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:57, 19.04s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:39, 19.82s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.55s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 19.20s/it]
# Processing Samples:   8%|▊         | 8/100 [23:23<4:29:08, 175.52s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:17<02:23, 17.98s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:22, 20.33s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.56s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.13s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.94s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 20.00s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.42s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.06s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.74s/it]
# Processing Samples:   9%|▉         | 9/100 [26:18<4:26:11, 175.51s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.73s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:09, 18.56s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:52, 18.78s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:40, 20.03s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.30s/it]
# Converged after 479 outer iterations
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:52<00:55, 18.34s/it]
# Converged after 436 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:09<00:35, 17.82s/it]
# Converged after 455 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:27<00:17, 17.89s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:49<00:00, 19.15s/it]
# Processing Samples:  10%|█         | 10/100 [29:07<4:20:24, 173.61s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.46s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:10, 18.67s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:01, 20.19s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:38, 19.69s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.17s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:57, 19.25s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.99s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.55s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:54<00:00, 19.31s/it]
# Processing Samples:  11%|█         | 11/100 [32:02<4:18:03, 173.97s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<03:00, 22.53s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:19, 19.99s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:56, 19.44s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:40, 20.12s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:18, 19.71s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:58, 19.34s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.05s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:19, 19.93s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.42s/it]
# Processing Samples:  12%|█▏        | 12/100 [34:59<4:16:27, 174.86s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.50s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:11, 18.77s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:00, 20.13s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.40s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.96s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<01:00, 20.09s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.64s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.28s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 18.96s/it]
# Processing Samples:  13%|█▎        | 13/100 [37:53<4:12:55, 174.43s/it]
# Converged after 493 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:57, 22.18s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:19, 19.89s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.27s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:38, 19.74s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:20, 20.05s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:58, 19.44s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.13s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:39<00:20, 20.18s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 19.49s/it]
# Processing Samples:  14%|█▍        | 14/100 [40:50<4:11:13, 175.28s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.38s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.43s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.62s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:36, 19.21s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:20, 20.02s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:59, 19.78s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.38s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.15s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 20.10s/it]
# Processing Samples:  15%|█▌        | 15/100 [43:47<4:09:19, 176.00s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:31, 18.99s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:10, 18.70s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:02, 20.41s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:38, 19.61s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.09s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:56, 18.85s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.89s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.30s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.04s/it]
# Processing Samples:  16%|█▌        | 16/100 [46:41<4:05:18, 175.22s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:53, 21.63s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:19, 19.95s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.19s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:34, 18.82s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:19, 19.90s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.41s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.13s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:20, 20.29s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.69s/it]
# Processing Samples:  17%|█▋        | 17/100 [49:38<4:03:05, 175.73s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.33s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.34s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.94s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:35, 19.17s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:34<01:15, 18.86s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:53<00:56, 18.89s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:39, 19.63s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.38s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 19.06s/it]
# Processing Samples:  18%|█▊        | 18/100 [52:30<3:58:42, 174.66s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:54, 21.80s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:17, 19.67s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:53, 18.93s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:33, 18.74s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:19, 19.83s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.65s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.16s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:20, 20.26s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.63s/it]
# Processing Samples:  19%|█▉        | 19/100 [55:27<3:56:34, 175.24s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.66s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:38<02:16, 19.48s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:00, 20.04s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.41s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:17, 19.48s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<01:00, 20.30s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.77s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.29s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 20.20s/it]
# Processing Samples:  20%|██        | 20/100 [58:25<3:54:58, 176.23s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.19s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:09, 18.48s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:57<01:56, 19.38s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.65s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.28s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:56, 18.96s/it]
# Converged after 494 outer iterations
# Converged after 464 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:13<00:38, 19.07s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.39s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 19.07s/it]
# Processing Samples:  21%|██        | 21/100 [1:01:17<3:50:24, 175.00s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.22s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:23, 20.51s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.56s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.16s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.91s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 19.70s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.22s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:18, 18.94s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.92s/it]
# Processing Samples:  22%|██▏       | 22/100 [1:04:13<3:47:45, 175.20s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.56s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.31s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:55<01:51, 18.59s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:38, 19.63s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:16, 19.13s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:53<00:56, 18.79s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:39, 19.81s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.28s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:51<00:00, 19.06s/it]
# Processing Samples:  23%|██▎       | 23/100 [1:07:05<3:43:33, 174.20s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.49s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:24, 20.63s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.57s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.02s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:19, 19.76s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.60s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.18s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:18, 18.85s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.75s/it]
# Processing Samples:  24%|██▍       | 24/100 [1:10:00<3:41:13, 174.65s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.63s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:10, 18.68s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:00, 20.12s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.61s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.20s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:57, 19.01s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:40, 20.03s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.42s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.11s/it]
# Processing Samples:  25%|██▌       | 25/100 [1:12:54<3:37:59, 174.40s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:35, 19.49s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.42s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.50s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.02s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:20, 20.05s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.42s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.10s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:18, 18.80s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.79s/it]
# Processing Samples:  26%|██▌       | 26/100 [1:15:50<3:35:39, 174.85s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.31s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:07, 18.27s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:58, 19.72s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.77s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.20s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:56<00:58, 19.46s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.84s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.29s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 18.94s/it]
# Processing Samples:  27%|██▋       | 27/100 [1:18:43<3:32:02, 174.28s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:57, 22.21s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:19, 19.94s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.23s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:37, 19.58s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:18, 19.72s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:57, 19.13s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:37, 18.80s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.68s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.40s/it]
# Processing Samples:  28%|██▊       | 28/100 [1:21:39<3:29:34, 174.65s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.22s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:07, 18.28s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.86s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:36, 19.24s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:34<01:15, 18.84s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:57, 19.07s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:39, 19.70s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.36s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 19.25s/it]
# Processing Samples:  29%|██▉       | 29/100 [1:24:31<3:26:02, 174.12s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:54, 21.84s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:18, 19.84s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:54, 19.05s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:39, 19.93s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:18, 19.64s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.38s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.02s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:20, 20.17s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 19.63s/it]
# Processing Samples:  30%|███       | 30/100 [1:27:28<3:24:09, 174.99s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.68s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:25, 20.72s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:58, 19.71s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:37, 19.41s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:21, 20.34s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:59, 19.82s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.44s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.25s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 20.03s/it]
# Processing Samples:  31%|███       | 31/100 [1:30:27<3:22:24, 176.00s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.70s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:12, 18.89s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:03, 20.58s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:38, 19.75s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:17, 19.36s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<01:01, 20.56s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.92s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.61s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 20.27s/it]
# Processing Samples:  32%|███▏      | 32/100 [1:33:26<3:20:42, 177.10s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:37, 19.69s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:38<02:14, 19.15s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:57<01:53, 19.00s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:42, 20.55s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:19, 19.93s/it]
# Converged after 496 outer iterations
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.58s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:20<00:41, 20.54s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:19, 19.88s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 19.63s/it]
# Processing Samples:  33%|███▎      | 33/100 [1:36:25<3:18:04, 177.38s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<03:02, 22.82s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:22, 20.41s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<01:59, 19.85s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:22<01:43, 20.68s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:42<01:20, 20.23s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<00:58, 19.57s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:38, 19.14s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.12s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 19.68s/it]
# Processing Samples:  34%|███▍      | 34/100 [1:39:24<3:15:51, 178.05s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.19s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:23, 20.44s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:56, 19.50s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:35, 19.04s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.95s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 19.76s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.25s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.16s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 20.30s/it]
# Processing Samples:  35%|███▌      | 35/100 [1:42:21<3:12:33, 177.75s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.17s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.34s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.83s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:35, 19.17s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:34<01:15, 18.88s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:53<00:56, 18.71s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:39, 19.79s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.29s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:51<00:00, 19.01s/it]
# Processing Samples:  36%|███▌      | 36/100 [1:45:13<3:07:41, 175.96s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:20<02:43, 20.46s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.31s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:56, 19.35s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:34, 19.00s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:20, 20.06s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:58, 19.63s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.14s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.77s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.60s/it]
# Processing Samples:  37%|███▋      | 37/100 [1:48:10<3:04:56, 176.14s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.15s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:09, 18.48s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<02:00, 20.09s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.40s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:16, 19.17s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<01:00, 20.06s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.73s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.26s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.03s/it]
# Processing Samples:  38%|███▊      | 38/100 [1:51:03<3:01:13, 175.38s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:51, 21.39s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:16, 19.50s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.18s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:41, 20.21s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:18, 19.71s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:57, 19.23s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:37, 18.84s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.76s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.25s/it]
# Processing Samples:  39%|███▉      | 39/100 [1:53:58<2:58:15, 175.33s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.33s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:11, 18.78s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.91s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:36, 19.35s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.99s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<01:00, 20.00s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.64s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.18s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 18.84s/it]
# Processing Samples:  40%|████      | 40/100 [1:56:51<2:54:32, 174.54s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:56, 22.01s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:18, 19.74s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:54, 19.16s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:40, 20.11s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:18, 19.62s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:56<00:57, 19.08s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:37, 18.92s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.95s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.37s/it]
# Processing Samples:  41%|████      | 41/100 [1:59:47<2:52:01, 174.93s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:31, 18.99s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.40s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:58, 19.77s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:36, 19.25s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:15, 18.94s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 19.89s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.45s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.31s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.81s/it]
# Processing Samples:  42%|████▏     | 42/100 [2:02:43<2:49:32, 175.39s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:37, 19.73s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:38<02:12, 18.90s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:51, 18.51s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:39, 19.85s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.42s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:57, 19.04s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:12<00:36, 18.48s/it]
# Converged after 459 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:28<00:17, 17.91s/it]
# Converged after 415 outer iterations
# Processing alpha Levels: 100%|██████████| 9/9 [02:50<00:00, 18.94s/it]
# Processing Samples:  43%|████▎     | 43/100 [2:05:34<2:45:08, 173.83s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.37s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.33s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.96s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:36, 19.20s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:16, 19.04s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:57, 19.14s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:38, 19.50s/it]
# Converged after 477 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.56s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.25s/it]
# Processing Samples:  44%|████▍     | 44/100 [2:08:27<2:42:04, 173.65s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:53, 21.63s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:17, 19.66s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:54, 19.14s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:34, 18.95s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:20, 20.07s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:58, 19.54s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.12s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:20, 20.13s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.65s/it]
# Processing Samples:  45%|████▌     | 45/100 [2:11:24<2:40:02, 174.60s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.67s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:25, 20.77s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:59, 19.90s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:36, 19.33s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:16, 19.15s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:00, 20.03s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.44s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.19s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 20.14s/it]
# Processing Samples:  46%|████▌     | 46/100 [2:14:22<2:38:02, 175.60s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.45s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:11, 18.81s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:03, 20.64s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:38, 19.78s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:17, 19.49s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<01:00, 20.30s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.73s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.40s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.04s/it]
# Processing Samples:  47%|████▋     | 47/100 [2:17:17<2:35:00, 175.47s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:55, 21.91s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:18, 19.72s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:54, 19.10s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:41, 20.26s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:18, 19.56s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:57, 19.26s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:37, 18.94s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.48s/it]
# Converged after 430 outer iterations
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.21s/it]
# Processing Samples:  48%|████▊     | 48/100 [2:20:12<2:31:58, 175.35s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:32, 19.05s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:25, 20.74s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:01<02:03, 20.62s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:40, 20.02s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:43<01:24, 21.18s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:03<01:01, 20.55s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:22<00:40, 20.30s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:44<00:20, 20.83s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:02<00:00, 19.96s/it]
# Processing Samples:  49%|████▉     | 49/100 [2:23:15<2:30:59, 177.63s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.56s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:09, 18.46s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:02, 20.34s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.53s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.34s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:00, 20.23s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.64s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.13s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.50s/it]
# Processing Samples:  50%|█████     | 50/100 [2:26:10<2:27:30, 177.01s/it]
# Converged after 492 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:20<02:43, 20.38s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:38<02:14, 19.19s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:57<01:53, 18.93s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:41, 20.32s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.77s/it]
# Converged after 428 outer iterations
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:52<00:54, 18.00s/it]
# Converged after 441 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:11<00:36, 18.30s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:29<00:18, 18.28s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:50<00:00, 19.17s/it]
# Processing Samples:  51%|█████     | 51/100 [2:29:01<2:22:59, 175.10s/it]
# Converged after 470 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.58s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:09, 18.53s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:54, 19.06s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:39, 19.87s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.46s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:56, 18.87s/it]
# Converged after 462 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:39, 19.76s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.45s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.09s/it]
# Processing Samples:  52%|█████▏    | 52/100 [2:31:54<2:19:35, 174.48s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<03:02, 22.83s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:21, 20.23s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:56, 19.46s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:22<01:42, 20.55s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:19, 19.97s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:58, 19.41s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.14s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.10s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 19.78s/it]
# Processing Samples:  53%|█████▎    | 53/100 [2:34:53<2:17:46, 175.87s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.44s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.39s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.65s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:36, 19.31s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.17s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:00, 20.02s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.78s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.48s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 20.32s/it]
# Processing Samples:  54%|█████▍    | 54/100 [2:37:52<2:15:28, 176.70s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.55s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:09, 18.45s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:55<01:50, 18.39s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:38, 19.70s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:17, 19.32s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:57, 19.00s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:40, 20.11s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.52s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:53<00:00, 19.21s/it]
# Processing Samples:  55%|█████▌    | 55/100 [2:40:45<2:11:44, 175.65s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.30s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:22, 20.39s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:56, 19.35s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:35, 19.04s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:20, 20.15s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:56<00:57, 19.33s/it]
# Converged after 470 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.14s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:18, 18.84s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.95s/it]
# Processing Samples:  56%|█████▌    | 56/100 [2:43:41<2:08:53, 175.77s/it]
# Converged after 500 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.44s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:12, 18.89s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:00, 20.04s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:39, 19.80s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.32s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:57, 19.18s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.97s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.68s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:54<00:00, 19.21s/it]
# Processing Samples:  57%|█████▋    | 57/100 [2:46:36<2:05:44, 175.46s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<03:01, 22.68s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:21, 20.16s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<01:57, 19.61s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:20<01:38, 19.77s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:20, 20.14s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:58, 19.45s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.12s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:39<00:20, 20.07s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:57<00:00, 19.46s/it]
# Processing Samples:  58%|█████▊    | 58/100 [2:49:33<2:03:16, 176.11s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:26, 18.31s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:21, 20.26s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.61s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:34, 19.00s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.82s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:56<00:58, 19.64s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.35s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.11s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:52<00:00, 18.83s/it]
# Processing Samples:  59%|█████▉    | 59/100 [2:52:26<1:59:32, 174.93s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:56, 22.12s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:19, 19.95s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:55, 19.23s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:21<01:42, 20.52s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:39<01:18, 19.75s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:57, 19.31s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:37, 18.96s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:38<00:19, 19.83s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.27s/it]
# Processing Samples:  60%|██████    | 60/100 [2:55:22<1:56:53, 175.33s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.20s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:39<02:19, 19.94s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.52s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:34, 18.99s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:15, 18.79s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:56<00:59, 19.81s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:38, 19.29s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.02s/it]
# ...
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 19.59s/it]
# Processing Samples:  80%|████████  | 80/100 [3:55:27<59:52, 179.64s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.40s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:09, 18.52s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<02:00, 20.07s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.41s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:16, 19.08s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:53<00:55, 18.47s/it]
# Converged after 464 outer iterations
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:14<00:39, 19.56s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:33<00:19, 19.11s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:51<00:00, 18.80s/it]
# Processing Samples:  81%|████████  | 81/100 [3:58:18<56:04, 177.10s/it]
# Converged after 478 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.46s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:23, 20.52s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:57, 19.61s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:16<01:34, 18.97s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:18, 19.73s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 19.69s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:15<00:38, 19.24s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.12s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 20.08s/it]
# Processing Samples:  82%|████████▏ | 82/100 [4:01:15<53:07, 177.07s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.24s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.30s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:01, 20.26s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.63s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.17s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:56, 18.85s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.95s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:19, 19.30s/it]
# Converged after 472 outer iterations
# Processing alpha Levels: 100%|██████████| 9/9 [02:51<00:00, 18.70s/it]
# Processing Samples:  83%|████████▎ | 83/100 [4:04:07<49:44, 175.54s/it]
# Converged after 448 outer iterations
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:32, 19.06s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:24, 20.65s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:57, 19.56s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.09s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:19, 19.77s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:57<00:59, 19.68s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:38, 19.24s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:34<00:18, 18.89s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:56<00:00, 20.03s/it]
# Processing Samples:  84%|████████▍ | 84/100 [4:07:04<46:55, 175.96s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:25, 18.20s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:08, 18.30s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:59, 19.89s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.61s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.23s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:01, 20.44s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:39, 19.90s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.52s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:54<00:00, 19.22s/it]
# Processing Samples:  85%|████████▌ | 85/100 [4:09:59<43:55, 175.67s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:56, 22.05s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:20, 20.04s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:57, 19.66s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:22<01:43, 20.74s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:20, 20.03s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:58, 19.66s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:22<00:41, 20.66s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:41<00:19, 19.97s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 19.81s/it]
# Processing Samples:  86%|████████▌ | 86/100 [4:12:59<41:20, 177.17s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:22<02:57, 22.14s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:22, 20.38s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<01:58, 19.77s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:23<01:45, 21.15s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:20, 20.14s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:01<00:59, 19.77s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:23<00:41, 20.55s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:42<00:20, 20.08s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:01<00:00, 19.69s/it]
# Processing Samples:  87%|████████▋ | 87/100 [4:16:01<38:38, 178.35s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:23<03:06, 23.25s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:42<02:26, 20.90s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:01<01:59, 19.90s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:23<01:43, 20.68s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:19, 19.87s/it]
# Converged after 487 outer iterations
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<00:58, 19.54s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:19<00:38, 19.26s/it]
# Converged after 498 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:41<00:20, 20.33s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 19.93s/it]
# Processing Samples:  88%|████████▊ | 88/100 [4:19:01<35:48, 179.08s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:31, 18.88s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:27, 21.05s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<01:59, 19.99s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:37, 19.60s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:22, 20.61s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<01:00, 20.15s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:19<00:39, 19.73s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:42<00:20, 20.62s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:01<00:00, 20.20s/it]
# Processing Samples:  89%|████████▉ | 89/100 [4:22:03<32:57, 179.81s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:29, 18.69s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:24, 20.60s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:00, 20.16s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:37, 19.48s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:21, 20.41s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:59, 19.89s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.65s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.28s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 20.18s/it]
# Processing Samples:  90%|█████████ | 90/100 [4:25:03<29:59, 179.98s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.61s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:36<02:07, 18.28s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<02:00, 20.13s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:38, 19.61s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:35<01:16, 19.03s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<01:00, 20.25s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:16<00:39, 19.65s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.41s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:54<00:00, 19.26s/it]
# Processing Samples:  91%|█████████ | 91/100 [4:27:58<26:45, 178.40s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:21<02:55, 21.94s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:20, 20.12s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:56, 19.42s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:21<01:41, 20.38s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:19, 19.94s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:58, 19.54s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:21<00:40, 20.41s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:19, 19.98s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 19.65s/it]
# Processing Samples:  92%|█████████▏| 92/100 [4:30:57<23:49, 178.68s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:38, 19.87s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:21, 20.22s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:57, 19.57s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:36, 19.20s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:22, 20.58s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:59, 19.92s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.37s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:39<00:20, 20.10s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:58<00:00, 19.67s/it]
# Processing Samples:  93%|█████████▎| 93/100 [4:33:55<20:49, 178.50s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:31, 18.99s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:28, 21.22s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:00, 20.03s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:36, 19.33s/it]
# Converged after 488 outer iterations
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:16, 19.00s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<01:01, 20.34s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.83s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.57s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 20.65s/it]
# Processing Samples:  94%|█████████▍| 94/100 [4:36:56<17:55, 179.20s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:30, 18.78s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:12, 18.97s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<02:03, 20.53s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:19<01:39, 19.93s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:38<01:18, 19.59s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<01:01, 20.60s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:19<00:39, 19.98s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.49s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 20.15s/it]
# Processing Samples:  95%|█████████▌| 95/100 [4:39:56<14:56, 179.32s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:32, 19.12s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:12, 18.93s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:56<01:52, 18.78s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:40, 20.11s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:17, 19.39s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:55<00:57, 19.20s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:40, 20.14s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:36<00:19, 19.72s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:55<00:00, 19.40s/it]
# Processing Samples:  96%|█████████▌| 96/100 [4:42:51<11:52, 178.09s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:19<02:37, 19.74s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:25, 20.72s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:57, 19.64s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:35, 19.12s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:40<01:21, 20.30s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:58<00:59, 19.78s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:38, 19.39s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:20, 20.50s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 19.93s/it]
# Processing Samples:  97%|█████████▋| 97/100 [4:45:50<08:55, 178.41s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:28, 18.57s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:40<02:25, 20.78s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:59<01:59, 19.87s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:18<01:37, 19.54s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:37<01:17, 19.33s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [02:00<01:01, 20.42s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:18<00:39, 19.82s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:37<00:19, 19.44s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [03:00<00:00, 20.46s/it]
# Processing Samples:  98%|█████████▊| 98/100 [4:48:50<05:57, 178.93s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:18<02:27, 18.39s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:37<02:11, 18.84s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [00:58<01:58, 19.70s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:17<01:37, 19.45s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:36<01:16, 19.25s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:54<00:56, 18.96s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:17<00:40, 20.29s/it]
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:35<00:19, 19.64s/it]
# Processing alpha Levels: 100%|██████████| 9/9 [02:54<00:00, 19.33s/it]
# Processing Samples:  99%|█████████▉| 99/100 [4:51:45<02:57, 177.63s/it]
# Processing alpha Levels:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing alpha Levels:  11%|█         | 1/9 [00:23<03:05, 23.13s/it]
# Processing alpha Levels:  22%|██▏       | 2/9 [00:41<02:22, 20.42s/it]
# Processing alpha Levels:  33%|███▎      | 3/9 [01:00<01:57, 19.63s/it]
# Processing alpha Levels:  44%|████▍     | 4/9 [01:22<01:43, 20.75s/it]
# Processing alpha Levels:  56%|█████▌    | 5/9 [01:41<01:19, 20.00s/it]
# Processing alpha Levels:  67%|██████▋   | 6/9 [01:59<00:58, 19.41s/it]
# Processing alpha Levels:  78%|███████▊  | 7/9 [02:22<00:41, 20.57s/it]
# Converged after 495 outer iterations
# Processing alpha Levels:  89%|████████▉ | 8/9 [02:40<00:19, 19.85s/it]
# Converged after 489 outer iterations
# Processing alpha Levels: 100%|██████████| 9/9 [02:59<00:00, 19.28s/it]
# Processing Samples: 100%|██████████| 100/100 [4:54:44<00:00, 176.84s/it]
# Converged after 486 outer iterations

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# Print average results
print("Avg HR  :", avg_hr)
print("Avg SRR :", avg_srr)
print("Avg FR  :", avg_fr)
print("Avg PR  :", avg_pr)
print("Avg RE  :", avg_re)
print("Avg F1  :", avg_f1)
print("Avg NMSE:", avg_nmse)
# Out:
# Avg HR  : [71.9  83.25 84.4  82.6  81.2  78.3  75.55 73.4  70.4 ]
# Avg SRR : [0.37801902 0.51725533 0.54369207 0.53425018 0.52116182 0.49185874
#  0.46274657 0.44153489 0.41360763]
# Avg FR  : [3.70263158 2.71578947 2.39736842 2.31315789 2.35       2.38947368
#  2.51315789 2.65       2.74736842]
# Avg PR  : [0.51048605 0.62594783 0.65876492 0.66244936 0.65553003 0.64213089
#  0.62183382 0.60381435 0.58376186]
# Avg RE  : [0.719  0.8325 0.844  0.826  0.812  0.783  0.7555 0.734  0.704 ]
# Avg F1  : [0.59578232 0.7128678  0.73790564 0.73324349 0.72334939 0.70375366
#  0.68034415 0.66055088 0.63665875]
# Avg NMSE: [0.48295176 0.3842215  0.37345168 0.38691688 0.40338987 0.43000879
#  0.46102743 0.48400951 0.51662661]

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-100-casbl-anc-alpha-all-beta-0-25-snr-db-12-pilot-length-25.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    snr_db=snr_db,
    beta = beta,
    alpha_array=alpha_array
)

print("All results have been saved")
# Out:
# All results have been saved
