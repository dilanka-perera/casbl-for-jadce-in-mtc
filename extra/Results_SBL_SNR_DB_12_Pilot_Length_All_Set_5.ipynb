# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(800, 1000)

# %% [markdown]
# Sparse Bayesian Learning (SBL)

# %%
def sbl_algorithm(theta, y, noise_var, max_iter=500, stopping_criterion=1e-4):
    # Sparse Bayesian Learning (SBL) for Multiple Measurement Vectors (MMV).

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess: identity matrix

    # Iterative update process
    for t in range(max_iter):
       # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute gamma update using the derived formula
        gamma_new = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Ensure non-negativity for numerical stability
        gamma_new = np.maximum(gamma_new, 1e-8)

        # Check for convergence: if change is below threshold, stop iterations
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma with new values
        Gamma = np.diagflat(gamma_new)

    # Return final estimates
    return mu_x, np.diag(Gamma)

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = sbl_algorithm(theta, received_signal, noise_power)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.28s/it]
# Processing Samples:   0%|          | 1/200 [01:59<6:37:06, 119.73s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.27s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.69s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.60s/it]
# Processing Samples:   1%|          | 2/200 [03:59<6:34:19, 119.49s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.73s/it]
# Processing Samples:   2%|▏         | 3/200 [05:58<6:32:03, 119.41s/it]
# Converged after 493 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.43s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.85s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.58s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.36s/it]
# Processing Samples:   2%|▏         | 4/200 [07:55<6:27:32, 118.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.57s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.84s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.89s/it]
# Processing Samples:   2%|▎         | 5/200 [09:52<6:23:43, 118.07s/it]
# Converged after 497 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.48s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.86s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.75s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.90s/it]
# Processing Samples:   3%|▎         | 6/200 [11:50<6:21:32, 118.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.17s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.14s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.99s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 19.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.01s/it]
# Processing Samples:   4%|▎         | 7/200 [13:46<6:17:00, 117.20s/it]
# Converged after 458 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.43s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.54s/it]
# Processing Samples:   4%|▍         | 8/200 [15:40<6:11:47, 116.19s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:19, 19.78s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.32s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.19s/it]
# Processing Samples:   4%|▍         | 9/200 [17:38<6:12:16, 116.95s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.24s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.14s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 19.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.36s/it]
# Processing Samples:   5%|▌         | 10/200 [19:36<6:11:05, 117.19s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.63s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.20s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.38s/it]
# Processing Samples:   6%|▌         | 11/200 [21:33<6:08:45, 117.07s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.65s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.55s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.56s/it]
# Processing Samples:   6%|▌         | 12/200 [23:28<6:04:54, 116.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:39, 19.86s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:37, 18.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.70s/it]
# Converged after 440 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.77s/it]
# Processing Samples:   6%|▋         | 13/200 [25:25<6:03:43, 116.70s/it]
# Converged after 499 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.61s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.23s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.30s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.70s/it]
# Processing Samples:   7%|▋         | 14/200 [27:24<6:03:29, 117.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.15s/it]
# Processing Samples:   8%|▊         | 15/200 [29:20<6:00:47, 117.01s/it]
# Converged after 485 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.64s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.57s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.86s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.84s/it]
# Processing Samples:   8%|▊         | 16/200 [31:18<5:59:20, 117.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:43, 20.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.94s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.88s/it]
# Processing Samples:   8%|▊         | 17/200 [33:16<5:57:53, 117.34s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.53s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.22s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.20s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.81s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.28s/it]
# Processing Samples:   9%|▉         | 18/200 [35:14<5:56:46, 117.62s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.52s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.53s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.43s/it]
# Processing Samples:  10%|▉         | 19/200 [37:11<5:54:38, 117.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.90s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.73s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.34s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.47s/it]
# Processing Samples:  10%|█         | 20/200 [39:05<5:48:58, 116.33s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.89s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.13s/it]
# Processing Samples:  10%|█         | 21/200 [41:02<5:47:28, 116.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.60s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.23s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.17s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.43s/it]
# Processing Samples:  11%|█         | 22/200 [42:56<5:43:59, 115.95s/it]
# Converged after 449 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.18s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.43s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.96s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.92s/it]
# Processing Samples:  12%|█▏        | 23/200 [44:53<5:43:01, 116.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.22s/it]
# Processing Samples:  12%|█▏        | 24/200 [46:51<5:42:43, 116.84s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.11s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.96s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.48s/it]
# Processing Samples:  12%|█▎        | 25/200 [48:49<5:41:06, 116.95s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.44s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.65s/it]
# Processing Samples:  13%|█▎        | 26/200 [50:44<5:37:24, 116.35s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.95s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:15, 18.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.19s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.02s/it]
# Processing Samples:  14%|█▎        | 27/200 [52:42<5:37:01, 116.89s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.11s/it]
# Processing Samples:  14%|█▍        | 28/200 [54:39<5:35:38, 117.08s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.35s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.40s/it]
# Processing Samples:  14%|█▍        | 29/200 [56:36<5:33:45, 117.11s/it]
# Converged after 495 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.36s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.51s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.86s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.44s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.49s/it]
# Processing Samples:  15%|█▌        | 30/200 [58:31<5:29:23, 116.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.31s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.76s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.00s/it]
# Processing Samples:  16%|█▌        | 31/200 [1:00:29<5:28:55, 116.78s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.44s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.34s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.02s/it]
# Converged after 490 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.14s/it]
# Processing Samples:  16%|█▌        | 32/200 [1:02:26<5:27:20, 116.91s/it]
# Converged after 472 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.64s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.25s/it]
# Processing Samples:  16%|█▋        | 33/200 [1:04:23<5:25:43, 117.03s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:13, 18.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.46s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.64s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.88s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.88s/it]
# Processing Samples:  17%|█▋        | 34/200 [1:06:20<5:23:56, 117.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.80s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.92s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:37, 18.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.30s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.10s/it]
# Processing Samples:  18%|█▊        | 35/200 [1:08:19<5:23:29, 117.63s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.37s/it]
# Processing Samples:  18%|█▊        | 36/200 [1:10:17<5:21:10, 117.51s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.84s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.53s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.05s/it]
# Processing Samples:  18%|█▊        | 37/200 [1:12:12<5:17:51, 117.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.16s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.51s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.64s/it]
# Processing Samples:  19%|█▉        | 38/200 [1:14:08<5:14:26, 116.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.51s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.10s/it]
# Processing Samples:  20%|█▉        | 39/200 [1:16:05<5:12:59, 116.65s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.05s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.12s/it]
# Processing Samples:  20%|██        | 40/200 [1:18:01<5:10:44, 116.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.02s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:53, 17.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:37, 18.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.25s/it]
# Processing Samples:  20%|██        | 41/200 [1:19:54<5:06:18, 115.59s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.72s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.88s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.96s/it]
# Converged after 497 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.54s/it]
# Processing Samples:  21%|██        | 42/200 [1:21:48<5:03:06, 115.11s/it]
# Converged after 429 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.42s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.69s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.47s/it]
# Processing Samples:  22%|██▏       | 43/200 [1:23:42<5:00:00, 114.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.19s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.63s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.01s/it]
# Processing Samples:  22%|██▏       | 44/200 [1:25:35<4:56:29, 114.04s/it]
# Converged after 414 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.95s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.88s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.05s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.72s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.41s/it]
# Processing Samples:  22%|██▎       | 45/200 [1:27:29<4:55:00, 114.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.62s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.80s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.75s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.19s/it]
# Converged after 439 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.83s/it]
# Processing Samples:  23%|██▎       | 46/200 [1:29:25<4:54:11, 114.62s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.19s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.53s/it]
# Processing Samples:  24%|██▎       | 47/200 [1:31:23<4:54:46, 115.60s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.43s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.79s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.44s/it]
# Processing Samples:  24%|██▍       | 48/200 [1:33:16<4:51:33, 115.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.72s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.01s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 19.55s/it]
# Processing Samples:  24%|██▍       | 49/200 [1:35:13<4:50:22, 115.38s/it]
# Converged after 472 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.19s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.96s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.05s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.83s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.93s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.39s/it]
# Processing Samples:  25%|██▌       | 50/200 [1:37:10<4:49:56, 115.98s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.38s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.77s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.47s/it]
# Processing Samples:  26%|██▌       | 51/200 [1:39:04<4:46:19, 115.30s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:55, 18.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:36, 18.37s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 19.75s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:41:00<4:45:06, 115.58s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.82s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.62s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:18, 18.56s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.15s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:42:56<4:43:33, 115.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.81s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.15s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:52<00:00, 19.20s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:44:49<4:39:33, 114.89s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.84s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:15, 18.98s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.57s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.89s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:46:46<4:39:32, 115.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.86s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.20s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.39s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:48:42<4:37:33, 115.65s/it]
# Converged after 441 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.41s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.24s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.33s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.71s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:50:40<4:37:39, 116.50s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.52s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.74s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.01s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.59s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.24s/it]
# Processing Samples:  29%|██▉       | 58/200 [1:52:37<4:36:05, 116.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.25s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.77s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.65s/it]
# Processing Samples:  30%|██▉       | 59/200 [1:54:33<4:32:59, 116.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.50s/it]
# Processing Samples:  30%|███       | 60/200 [1:56:30<4:32:17, 116.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.46s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.36s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.57s/it]
# Processing Samples:  30%|███       | 61/200 [1:58:29<4:31:18, 117.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.63s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.68s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.89s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.69s/it]
# Processing Samples:  31%|███       | 62/200 [2:00:23<4:27:48, 116.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:19, 19.79s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.93s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.76s/it]
# Converged after 474 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.02s/it]
# Processing Samples:  32%|███▏      | 63/200 [2:02:21<4:26:36, 116.76s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.56s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.28s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.71s/it]
# Processing Samples:  32%|███▏      | 64/200 [2:04:20<4:25:55, 117.32s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.49s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.72s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.40s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 18.15s/it]
# Processing Samples:  32%|███▎      | 65/200 [2:06:10<4:19:28, 115.32s/it]
# Converged after 390 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.18s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.10s/it]
# Processing Samples:  33%|███▎      | 66/200 [2:08:07<4:18:43, 115.84s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.45s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.78s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:59, 19.74s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.32s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.62s/it]
# Processing Samples:  34%|███▎      | 67/200 [2:10:06<4:18:39, 116.69s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.37s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.37s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.38s/it]
# Processing Samples:  34%|███▍      | 68/200 [2:11:59<4:14:32, 115.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:15, 18.90s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 18.97s/it]
# Processing Samples:  34%|███▍      | 69/200 [2:13:54<4:12:03, 115.45s/it]
# Converged after 411 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.28s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.22s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.57s/it]
# Processing Samples:  35%|███▌      | 70/200 [2:15:52<4:11:35, 116.12s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.57s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.97s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.59s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.50s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.60s/it]
# Processing Samples:  36%|███▌      | 71/200 [2:17:47<4:08:50, 115.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:18, 19.54s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.07s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:37, 18.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.14s/it]
# Processing Samples:  36%|███▌      | 72/200 [2:19:46<4:08:55, 116.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.37s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.22s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.44s/it]
# Processing Samples:  36%|███▋      | 73/200 [2:21:44<4:07:56, 117.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.71s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.71s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.12s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.37s/it]
# Processing Samples:  37%|███▋      | 74/200 [2:23:38<4:04:03, 116.22s/it]
# Converged after 482 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.17s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.20s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:36, 18.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.81s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.72s/it]
# Processing Samples:  38%|███▊      | 75/200 [2:25:33<4:01:37, 115.98s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.34s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.66s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.25s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:27:30<4:00:08, 116.19s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.04s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.02s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.43s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:29:27<3:58:42, 116.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.36s/it]
# ...
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.53s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.26s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.60s/it]
# Processing Samples:  88%|████████▊ | 175/200 [5:38:03<48:35, 116.62s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.43s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.56s/it]
# Processing Samples:  88%|████████▊ | 176/200 [5:39:57<46:22, 115.93s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.18s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.08s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.90s/it]
# Processing Samples:  88%|████████▊ | 177/200 [5:41:55<44:39, 116.48s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.83s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.16s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.88s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.83s/it]
# Processing Samples:  89%|████████▉ | 178/200 [5:43:50<42:34, 116.10s/it]
# Converged after 452 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.08s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:37, 18.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:32<00:19, 19.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:51<00:00, 19.18s/it]
# Processing Samples:  90%|████████▉ | 179/200 [5:45:42<40:11, 114.84s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.82s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.08s/it]
# Processing Samples:  90%|█████████ | 180/200 [5:47:40<38:34, 115.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.60s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.22s/it]
# Processing Samples:  90%|█████████ | 181/200 [5:49:36<36:44, 116.02s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.33s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.48s/it]
# Processing Samples:  91%|█████████ | 182/200 [5:51:30<34:35, 115.31s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.69s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.23s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.08s/it]
# Processing Samples:  92%|█████████▏| 183/200 [5:53:28<32:54, 116.14s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.47s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:18, 18.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.36s/it]
# Processing Samples:  92%|█████████▏| 184/200 [5:55:26<31:06, 116.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.44s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.28s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.23s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.54s/it]
# Processing Samples:  92%|█████████▎| 185/200 [5:57:24<29:15, 117.02s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.36s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.68s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.82s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.53s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.52s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.60s/it]
# Processing Samples:  93%|█████████▎| 186/200 [5:59:18<27:08, 116.32s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:45, 21.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.76s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:37, 18.78s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.66s/it]
# Processing Samples:  94%|█████████▎| 187/200 [6:01:16<25:16, 116.65s/it]
# Converged after 465 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.55s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.07s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.68s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.81s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.27s/it]
# Processing Samples:  94%|█████████▍| 188/200 [6:03:13<23:21, 116.78s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.29s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.77s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.27s/it]
# Processing Samples:  94%|█████████▍| 189/200 [6:05:10<21:24, 116.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.74s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.88s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:36, 18.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.63s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.51s/it]
# Processing Samples:  95%|█████████▌| 190/200 [6:07:03<19:18, 115.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.89s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.19s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:57, 19.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:37, 18.90s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:18, 18.95s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.35s/it]
# Processing Samples:  96%|█████████▌| 191/200 [6:09:00<17:24, 116.01s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.37s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.77s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.36s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.45s/it]
# Processing Samples:  96%|█████████▌| 192/200 [6:10:54<15:23, 115.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.55s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.58s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.85s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.80s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.96s/it]
# Processing Samples:  96%|█████████▋| 193/200 [6:12:51<13:31, 115.90s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.33s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.55s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 20.15s/it]
# Processing Samples:  97%|█████████▋| 194/200 [6:14:47<11:35, 115.90s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.38s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.82s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.92s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:12<00:36, 18.24s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.75s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.72s/it]
# Processing Samples:  98%|█████████▊| 195/200 [6:16:41<09:37, 115.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.98s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.01s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.42s/it]
# Processing Samples:  98%|█████████▊| 196/200 [6:18:39<07:44, 116.23s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.40s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:03, 21.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.20s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.39s/it]
# Processing Samples:  98%|█████████▊| 197/200 [6:20:40<05:53, 117.67s/it]
# Converged after 457 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.67s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:58, 19.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:35<00:19, 19.30s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.68s/it]
# Processing Samples:  99%|█████████▉| 198/200 [6:22:39<03:56, 118.02s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.19s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.33s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.64s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.57s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:53<00:00, 19.29s/it]
# Processing Samples: 100%|█████████▉| 199/200 [6:24:32<01:56, 116.62s/it]
# Converged after 482 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:43, 20.80s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.03s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.50s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.81s/it]
# Processing Samples: 100%|██████████| 200/200 [6:26:30<00:00, 115.95s/it]
# Converged after 490 iterations

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-sbl-snr-db-12-pilot-length-all-set-5.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved
