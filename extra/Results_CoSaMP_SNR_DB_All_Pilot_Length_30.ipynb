# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 2
pilot_length=pilot_length_array[pilot_length_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(0, 1000)

# %% [markdown]
# Compressive Sampling Matching Pursuit (CoSaMP)

# %%
def cosamp_algorithm(theta, y, sparsity_level, max_iter=500, stopping_criterion=1e-4, lambda_reg=1e-2):
    L, N = theta.shape
    _, M = y.shape

    x_hat = np.zeros((N, M), dtype=np.complex128)
    residual = y.copy()
    support = set()

    for t in range(max_iter):
        # Step 1: Compute proxy
        proxy = theta.conj().T @ residual
        row_energy = np.sum(np.abs(proxy)**2, axis=1)
        omega = np.argpartition(row_energy, -2 * sparsity_level)[-2 * sparsity_level:]

        # Step 2: Merge with previous support
        merged_support = list(set(omega).union(support))
        theta_s = theta[:, merged_support]

        # Step 3: Regularized LS on merged support
        A = theta_s
        AHA = A.conj().T @ A + lambda_reg * np.eye(A.shape[1])
        AHY = A.conj().T @ y
        x_temp = np.linalg.solve(AHA, AHY)

        # Step 4: Prune to top-K rows
        row_energy_temp = np.sum(np.abs(x_temp)**2, axis=1)
        top_indices = np.argpartition(row_energy_temp, -sparsity_level)[-sparsity_level:]
        support = set([merged_support[i] for i in top_indices])

        # Step 5: Final LS on pruned support
        theta_final = theta[:, list(support)]
        A = theta_final
        AHA = A.conj().T @ A + lambda_reg * np.eye(A.shape[1])
        AHY = A.conj().T @ y
        x_support = np.linalg.solve(AHA, AHY)

        # Step 6: Construct full x_hat
        x_hat.fill(0)
        for i, idx in enumerate(support):
            x_hat[idx, :] = x_support[i, :]

        # Step 7: Update residual
        new_residual = y - theta @ x_hat

        # Step 8: Check stopping
        if np.linalg.norm(new_residual) < stopping_criterion:
            print(f"CoSaMP converged at iteration {t+1}")
            break

        residual = new_residual

    # Step 9: Binary support vector
    gamma = (np.linalg.norm(x_hat, axis=1) > 1e-6).astype(int)
    return x_hat, gamma

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(snr_db_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(snr_db_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(snr_db_array)))         # HR
fr_res = np.zeros((num_samples, len(snr_db_array)))         # FR
srr_res = np.zeros((num_samples, len(snr_db_array)))        # SRR
precision_res = np.zeros((num_samples, len(snr_db_array)))  # Precision
recall_res = np.zeros((num_samples, len(snr_db_array)))     # Recall
f1_res = np.zeros((num_samples, len(snr_db_array)))         # F1
nmse_res = np.zeros((num_samples, len(snr_db_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    theta = all_theta[sample_index, pilot_length_index, :pilot_length]
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for snr_db_index in tqdm(range(len(snr_db_array)), desc="Processing SNR Levels", leave=False, position=1):
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr_db = snr_db_array[snr_db_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and SNR level
        z_result, gamma_result = cosamp_algorithm(theta, received_signal, sparsity)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, snr_db_index, :, :] = z_result
        gamma_result_bool = gamma_result > 0.05
        gamma_res[sample_index, snr_db_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, snr_db_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, snr_db_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, snr_db_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index]) > 0:
            f1_res[sample_index, snr_db_index] = (
                2 * precision_res[sample_index, snr_db_index] * recall_res[sample_index, snr_db_index]
                /
                (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index])
            )
        else:
            f1_res[sample_index, snr_db_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, snr_db_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.49it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.71it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.86it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.86it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.93it/s]
# Processing Samples:  38%|███▊      | 376/1000 [25:33<43:33,  4.19s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.45it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.75it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.91it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.99it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.96it/s]
# Processing Samples:  38%|███▊      | 377/1000 [25:36<40:21,  3.89s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.52it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.29it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:03<00:04,  1.47s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.85s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.50s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.18s/it]
# Processing Samples:  38%|███▊      | 378/1000 [25:44<52:09,  5.03s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.82it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.94it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  2.00it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.07it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.04it/s]
# Processing Samples:  38%|███▊      | 379/1000 [25:47<45:59,  4.44s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.59it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.78it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.92it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.99it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.97it/s]
# Processing Samples:  38%|███▊      | 380/1000 [25:50<41:56,  4.06s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.64it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.83it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.01it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.92it/s]
# Processing Samples:  38%|███▊      | 381/1000 [25:53<39:04,  3.79s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:09,  1.93s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:09,  2.34s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:05,  1.89s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:02,  1.35s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.03s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.18it/s]
# Processing Samples:  38%|███▊      | 382/1000 [26:01<50:13,  4.88s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.52it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.75it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.88it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.98it/s]
# Processing Samples:  38%|███▊      | 383/1000 [26:04<44:54,  4.37s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.57it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.81it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.94it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.95it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.01it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.06it/s]
# Processing Samples:  38%|███▊      | 384/1000 [26:07<40:49,  3.98s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.50it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.97it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.40it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.44s/it]
# Processing Samples:  38%|███▊      | 385/1000 [26:13<47:15,  4.61s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:09,  1.95s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:02<00:05,  1.28s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:03<00:02,  1.10it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:03<00:01,  1.34it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:04<00:00,  1.54it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:04<00:00,  1.70it/s]
# Processing Samples:  39%|███▊      | 386/1000 [26:18<47:25,  4.63s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.68it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.83it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.87it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.99it/s]
# Processing Samples:  39%|███▊      | 387/1000 [26:21<43:00,  4.21s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.49it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.82it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.96it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.98it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.02it/s]
# Processing Samples:  39%|███▉      | 388/1000 [26:24<39:35,  3.88s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.54it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.88it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.62it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:04<00:03,  1.56s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.51s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.42s/it]
# Processing Samples:  39%|███▉      | 389/1000 [26:32<50:39,  4.98s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.92it/s]
# Processing Samples:  39%|███▉      | 390/1000 [26:35<45:24,  4.47s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.50it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.80it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.87it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.95it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.00it/s]
# Processing Samples:  39%|███▉      | 391/1000 [26:38<41:20,  4.07s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.48it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.80it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.94it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  39%|███▉      | 392/1000 [26:41<38:35,  3.81s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.13s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:10,  2.60s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:06<00:06,  2.03s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:02,  1.41s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.08s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.14it/s]
# Processing Samples:  39%|███▉      | 393/1000 [26:49<49:57,  4.94s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.52it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.82it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.95it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.94it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.97it/s]
# Processing Samples:  39%|███▉      | 394/1000 [26:52<44:28,  4.40s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.46it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.78it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.87it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.93it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.95it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.02it/s]
# Processing Samples:  40%|███▉      | 395/1000 [26:55<40:33,  4.02s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.84it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.96it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:04<00:01,  1.29s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.68s/it]
# Processing Samples:  40%|███▉      | 396/1000 [27:02<50:22,  5.00s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.02it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.46it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.65it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.79it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.89it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.95it/s]
# Processing Samples:  40%|███▉      | 397/1000 [27:06<45:33,  4.53s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.42it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.77it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.86it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.95it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.99it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.98it/s]
# Processing Samples:  40%|███▉      | 398/1000 [27:09<41:21,  4.12s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.42it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.79it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.92it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.95it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.91it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  40%|███▉      | 399/1000 [27:12<38:32,  3.85s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.15it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:06,  2.05s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.69s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.38s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.08s/it]
# Processing Samples:  40%|████      | 400/1000 [27:20<49:53,  4.99s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.75it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.90it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.92it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.95it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  40%|████      | 401/1000 [27:23<44:25,  4.45s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.90it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.93it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.97it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.99it/s]
# Processing Samples:  40%|████      | 402/1000 [27:26<40:28,  4.06s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.52it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.79it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.91it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.89it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.97it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.57it/s]
# Processing Samples:  40%|████      | 403/1000 [27:30<38:53,  3.91s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:03<00:18,  3.77s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:05<00:09,  2.43s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:04,  1.57s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:02,  1.14s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:00,  1.10it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.29it/s]
# Processing Samples:  40%|████      | 404/1000 [27:37<49:00,  4.93s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.69it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.89it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  40%|████      | 405/1000 [27:40<43:54,  4.43s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.38it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.59it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.71it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.83it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  41%|████      | 406/1000 [27:44<40:36,  4.10s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.39it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:04<00:02,  1.34s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.57s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.48s/it]
# Processing Samples:  41%|████      | 407/1000 [27:51<51:09,  5.18s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.91it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.93it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.00it/s]
# Processing Samples:  41%|████      | 408/1000 [27:55<45:12,  4.58s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.42it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.93it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.92it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.97it/s]
# Processing Samples:  41%|████      | 409/1000 [27:58<41:02,  4.17s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.93it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.93it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.93it/s]
# Processing Samples:  41%|████      | 410/1000 [28:01<38:12,  3.89s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:07,  1.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:08,  2.12s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:06,  2.00s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.53s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.17s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.06it/s]
# Processing Samples:  41%|████      | 411/1000 [28:09<49:33,  5.05s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.45it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.87it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.93it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.90it/s]
# Processing Samples:  41%|████      | 412/1000 [28:12<44:10,  4.51s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.87it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.89it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  41%|████▏     | 413/1000 [28:15<40:30,  4.14s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.49it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.78it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.58it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.50s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.64s/it]
# Processing Samples:  41%|████▏     | 414/1000 [28:23<50:07,  5.13s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.05it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.48it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.65it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.77it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.79it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.87it/s]
# Processing Samples:  42%|████▏     | 415/1000 [28:26<45:19,  4.65s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.90it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.91it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  42%|████▏     | 416/1000 [28:30<41:07,  4.23s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.47it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.75it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.93it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.98it/s]
# Processing Samples:  42%|████▏     | 417/1000 [28:33<38:02,  3.92s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.38it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:02<00:05,  1.43s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:05,  1.96s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.78s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.32s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.04s/it]
# Processing Samples:  42%|████▏     | 418/1000 [28:40<49:10,  5.07s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.45it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.67it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.78it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.81it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.87it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.88it/s]
# Processing Samples:  42%|████▏     | 419/1000 [28:44<44:03,  4.55s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.67it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.86it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.87it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.95it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  42%|████▏     | 420/1000 [28:47<40:10,  4.16s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.51it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.87it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.87it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.31it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.58s/it]
# Processing Samples:  42%|████▏     | 421/1000 [28:54<47:04,  4.88s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:08,  1.65s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:02<00:04,  1.06s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.25it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:03<00:01,  1.45it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.62it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:04<00:00,  1.71it/s]
# Processing Samples:  42%|████▏     | 422/1000 [28:58<45:27,  4.72s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.66it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.83it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.94it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.93it/s]
# Processing Samples:  42%|████▏     | 423/1000 [29:01<41:12,  4.29s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.38it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.71it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.84it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.82it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.86it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.86it/s]
# Processing Samples:  42%|████▏     | 424/1000 [29:05<38:25,  4.00s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.38it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:02<00:05,  1.31s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:06,  2.08s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.79s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.36s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.07s/it]
# Processing Samples:  42%|████▎     | 425/1000 [29:12<49:33,  5.17s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.37it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.69it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.77it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  43%|████▎     | 426/1000 [29:16<44:05,  4.61s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.71it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.89it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.91it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  43%|████▎     | 427/1000 [29:19<40:09,  4.21s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.34it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.64it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.71it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.50s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.49s/it]
# Processing Samples:  43%|████▎     | 428/1000 [29:26<48:00,  5.04s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.20s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.12it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.40it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.59it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.69it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.79it/s]
# Processing Samples:  43%|████▎     | 429/1000 [29:30<44:45,  4.70s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.37it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.63it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.78it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.80it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.85it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# Processing Samples:  43%|████▎     | 430/1000 [29:33<40:59,  4.31s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.64it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.75it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.78it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.86it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.86it/s]
# Processing Samples:  43%|████▎     | 431/1000 [29:37<38:15,  4.04s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.34it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:03<00:07,  1.90s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:05,  1.99s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.71s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.29s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.02s/it]
# Processing Samples:  43%|████▎     | 432/1000 [29:45<49:10,  5.19s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.70it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.78it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.87it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  43%|████▎     | 433/1000 [29:48<43:42,  4.62s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.46it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.84it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.89it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.87it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  43%|████▎     | 434/1000 [29:51<39:43,  4.21s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.90it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.30it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.67s/it]
# Processing Samples:  44%|████▎     | 435/1000 [29:58<47:04,  5.00s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:06,  1.36s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.10it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.38it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.61it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.74it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.85it/s]
# Processing Samples:  44%|████▎     | 436/1000 [30:02<43:56,  4.68s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.49it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.77it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.86it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.87it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.90it/s]
# Processing Samples:  44%|████▎     | 437/1000 [30:05<39:58,  4.26s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.91it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.91it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.95it/s]
# Processing Samples:  44%|████▍     | 438/1000 [30:08<37:00,  3.95s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.65it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:03<00:04,  1.55s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:03,  1.74s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.55s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.20s/it]
# Processing Samples:  44%|████▍     | 439/1000 [30:16<47:26,  5.07s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.80it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.90it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.90it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.92it/s]
# Processing Samples:  44%|████▍     | 440/1000 [30:19<42:17,  4.53s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.37it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.83it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.92it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.96it/s]
# Processing Samples:  44%|████▍     | 441/1000 [30:23<38:34,  4.14s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.70it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.76it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.33it/s]
# Processing Samples:  44%|████▍     | 442/1000 [30:27<38:00,  4.09s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:02<00:13,  2.71s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:08,  2.05s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:04,  1.64s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.19s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:00,  1.05it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.25it/s]
# Processing Samples:  44%|████▍     | 443/1000 [30:34<46:04,  4.96s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.69it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.82it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.91it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.93it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.97it/s]
# Processing Samples:  44%|████▍     | 444/1000 [30:37<41:07,  4.44s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.84it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.94it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.92it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.97it/s]
# Processing Samples:  44%|████▍     | 445/1000 [30:40<37:37,  4.07s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.33it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.69it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:03<00:01,  1.16it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.60s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.52s/it]
# Processing Samples:  45%|████▍     | 446/1000 [30:47<46:45,  5.06s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.12s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.30it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:01,  1.54it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.66it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.76it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.80it/s]
# Processing Samples:  45%|████▍     | 447/1000 [30:51<43:01,  4.67s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.64it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.84it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.90it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.89it/s]
# Processing Samples:  45%|████▍     | 448/1000 [30:54<39:12,  4.26s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.49it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.69it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.85it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.85it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.94it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.92it/s]
# Processing Samples:  45%|████▍     | 449/1000 [30:58<36:21,  3.96s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:04,  1.10it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:03<00:08,  2.04s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:05,  1.81s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.64s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.22s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.01it/s]
# Processing Samples:  45%|████▌     | 450/1000 [31:05<46:35,  5.08s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.36it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.66it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.86it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.94it/s]
# Processing Samples:  45%|████▌     | 451/1000 [31:09<41:34,  4.54s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.74it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.82it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.85it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.93it/s]
# Processing Samples:  45%|████▌     | 452/1000 [31:12<37:59,  4.16s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.27it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.66it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.74it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.86it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.37s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.61s/it]
# Processing Samples:  45%|████▌     | 453/1000 [31:19<46:18,  5.08s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.20s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.27it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.48it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.65it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.72it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.82it/s]
# Processing Samples:  45%|████▌     | 454/1000 [31:23<42:43,  4.70s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.73it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.77it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.87it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.86it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  46%|████▌     | 455/1000 [31:26<38:50,  4.28s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.35it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.62it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.77it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.86it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.87it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.91it/s]
# Processing Samples:  46%|████▌     | 456/1000 [31:30<36:11,  3.99s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.31it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:08,  2.24s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:05,  1.96s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:03,  1.62s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:07<00:01,  1.21s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.02it/s]
# Processing Samples:  46%|████▌     | 457/1000 [31:37<46:28,  5.14s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.46it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.68it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.83it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.83it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.88it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.88it/s]
# Processing Samples:  46%|████▌     | 458/1000 [31:41<41:26,  4.59s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.31it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.63it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.70it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.73it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.80it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.81it/s]
# Processing Samples:  46%|████▌     | 459/1000 [31:44<38:23,  4.26s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.71it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.79it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.33it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.52s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.44s/it]
# Processing Samples:  46%|████▌     | 460/1000 [31:51<45:39,  5.07s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:07,  1.41s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:03,  1.16it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:02,  1.41it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.61it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:03<00:00,  1.71it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.80it/s]
# Processing Samples:  46%|████▌     | 461/1000 [31:55<42:32,  4.74s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.40it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.72it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.81it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.88it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.90it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.96it/s]
# Processing Samples:  46%|████▌     | 462/1000 [31:58<38:25,  4.28s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:03,  1.42it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.76it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.83it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.90it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.91it/s]
# ...
# Processing Samples:  97%|█████████▋| 971/1000 [1:10:22<01:50,  3.81s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.20it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.21it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  1.86it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:03,  1.75s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.70s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:08<00:00,  1.87s/it]
# Processing Samples:  97%|█████████▋| 972/1000 [1:10:31<02:30,  5.36s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:02<00:11,  2.37s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:03<00:06,  1.70s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:04<00:03,  1.12s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:04<00:01,  1.16it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:04<00:00,  1.42it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:05<00:00,  1.64it/s]
# Processing Samples:  97%|█████████▋| 973/1000 [1:10:36<02:24,  5.36s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.25it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.38it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.33it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Processing Samples:  97%|█████████▋| 974/1000 [1:10:39<01:57,  4.54s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.35it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.30it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.36it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.26it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Processing Samples:  98%|█████████▊| 975/1000 [1:10:41<01:38,  3.96s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.17it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.31it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.24it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.31it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.32it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples:  98%|█████████▊| 976/1000 [1:10:44<01:25,  3.56s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.02it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:03<00:08,  2.05s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:06,  2.00s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:06<00:02,  1.48s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.09s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.15it/s]
# Processing Samples:  98%|█████████▊| 977/1000 [1:10:51<01:46,  4.63s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.41it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.35it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Samples:  98%|█████████▊| 978/1000 [1:10:54<01:28,  4.04s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.41it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.32it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.34it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.28it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.34it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.41it/s]
# Processing Samples:  98%|█████████▊| 979/1000 [1:10:56<01:15,  3.59s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.27it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.41it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.34it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.33it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.33it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Processing Samples:  98%|█████████▊| 980/1000 [1:10:59<01:06,  3.30s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.26it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:03<00:04,  1.41s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:03,  1.65s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.52s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.16s/it]
# Processing Samples:  98%|█████████▊| 981/1000 [1:11:06<01:25,  4.48s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.46it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.41it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.33it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.39it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.35it/s]
# Processing Samples:  98%|█████████▊| 982/1000 [1:11:09<01:10,  3.91s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.39it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.31it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.40it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.32it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.34it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.36it/s]
# Processing Samples:  98%|█████████▊| 983/1000 [1:11:11<00:59,  3.51s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.24it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.34it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.29it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.32it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.34it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples:  98%|█████████▊| 984/1000 [1:11:14<00:51,  3.24s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.48it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.26it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.32it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:04<00:01,  1.28s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.48s/it]
# Processing Samples:  98%|█████████▊| 985/1000 [1:11:20<01:02,  4.19s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:01<00:05,  1.18s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.36it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:02<00:01,  1.63it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:02<00:01,  1.85it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  1.96it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  2.02it/s]
# Processing Samples:  99%|█████████▊| 986/1000 [1:11:24<00:55,  3.97s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.42it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.26it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.22it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Processing Samples:  99%|█████████▊| 987/1000 [1:11:26<00:46,  3.56s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.21it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.35it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.23it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.27it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.22it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Processing Samples:  99%|█████████▉| 988/1000 [1:11:29<00:39,  3.30s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.38it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.26it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.29it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.24it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.28it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:03<00:00,  1.62it/s]
# Processing Samples:  99%|█████████▉| 989/1000 [1:11:32<00:35,  3.27s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:03<00:16,  3.39s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:04<00:08,  2.10s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:05<00:04,  1.46s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:02,  1.04s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:00,  1.19it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:06<00:00,  1.43it/s]
# Processing Samples:  99%|█████████▉| 990/1000 [1:11:39<00:42,  4.27s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.30it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.36it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.40it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.35it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.41it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.41it/s]
# Processing Samples:  99%|█████████▉| 991/1000 [1:11:41<00:33,  3.75s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.22it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.35it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.31it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.40it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.47it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.39it/s]
# Processing Samples:  99%|█████████▉| 992/1000 [1:11:44<00:27,  3.38s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.43it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.29it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.37it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.38it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.30it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Processing Samples:  99%|█████████▉| 993/1000 [1:11:46<00:21,  3.14s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.28it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:01<00:02,  1.84it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:03<00:04,  1.42s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:05<00:03,  1.63s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:06<00:01,  1.45s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.11s/it]
# Processing Samples:  99%|█████████▉| 994/1000 [1:11:54<00:25,  4.32s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.24it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.30it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.36it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.36it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.29it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Processing Samples: 100%|█████████▉| 995/1000 [1:11:56<00:19,  3.80s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.15it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.30it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.28it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.32it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.35it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples: 100%|█████████▉| 996/1000 [1:11:59<00:13,  3.45s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:01,  2.55it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.33it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.38it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.38it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.33it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.38it/s]
# Processing Samples: 100%|█████████▉| 997/1000 [1:12:01<00:09,  3.18s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.15it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.31it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.36it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.04it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:05<00:01,  1.67s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [00:07<00:00,  1.59s/it]
# Processing Samples: 100%|█████████▉| 998/1000 [1:12:08<00:08,  4.36s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.44it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.31it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.30it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.35it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.26it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Processing Samples: 100%|█████████▉| 999/1000 [1:12:11<00:03,  3.83s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:00<00:02,  2.20it/s]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:00<00:01,  2.30it/s]
# Processing SNR Levels:  50%|█████     | 3/6 [00:01<00:01,  2.37it/s]
# Processing SNR Levels:  67%|██████▋   | 4/6 [00:01<00:00,  2.29it/s]
# Processing SNR Levels:  83%|████████▎ | 5/6 [00:02<00:00,  2.33it/s]
# Processing SNR Levels: 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Processing Samples: 100%|██████████| 1000/1000 [1:12:14<00:00,  4.33s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-cosamp-snr-db-all-pilot-length-30.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length=pilot_length,
    snr_db_array=snr_db_array
)

print("All results have been saved")
# Out:
# All results have been saved
