# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 2
pilot_length=pilot_length_array[pilot_length_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(800, 1000)

# %% [markdown]
# Correlation-Aware Sparse Bayesian Learning (CA-SBL)

# %%
def casbl_anc_algorithm(theta, y, noise_var, loc, alpha=1.00, beta=0.1, rho=7, U=20, max_iter=500, stopping_criterion=1e-4):
    """Correlation Aware Sparse Bayesian Learning (CASBL) for Multiple Measurement Vectors (MMV)."""

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess

    if rho == 0:
        correlation_matrix = np.eye(N)  # Identity matrix when no correlation
    else:
        # Compute pairwise distances (N x N matrix)
        distance_matrix = np.linalg.norm(loc[:, np.newaxis, :] - loc[np.newaxis, :, :], axis=2)

        # Compute exponential decay matrix
        correlation_matrix = np.maximum((np.exp(-distance_matrix / rho) - np.exp(-U / rho)) / (1 - np.exp(-U / rho)),0)

    # Outer loop over the maximum number of iterations
    for t in range(max_iter):
        # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute Q
        Q = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.diag(Sigma_x)

        # Compute P
        P = 2 * alpha * (beta - correlation_matrix) @ np.diag(Gamma)
        P = np.maximum(P, 1e-8)

        # Compute gamma update
        gamma_new = (np.sqrt(1 + 4 * P * Q) - 1) / (2 * P)

        # Ensure non-negativity (numerical stability)
        gamma_new = np.clip(np.real(gamma_new), 0, 1)

        # Update Gamma
        Gamma_old = np.diag(Gamma)
        Gamma = np.diagflat(gamma_new)

        # Check for convergence
        if np.linalg.norm(Gamma_old - gamma_new) < stopping_criterion:
            print(f"Converged after {t+1} outer iterations")
            break

    Gamma = np.where(Gamma < 0.05, 0, 1)

    Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
    Sigma_y_inv = np.linalg.inv(Sigma_y)
    Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
    mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

    return mu_x, np.diag(Gamma)  # Final estimates

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(snr_db_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(snr_db_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(snr_db_array)))         # HR
fr_res = np.zeros((num_samples, len(snr_db_array)))         # FR
srr_res = np.zeros((num_samples, len(snr_db_array)))        # SRR
precision_res = np.zeros((num_samples, len(snr_db_array)))  # Precision
recall_res = np.zeros((num_samples, len(snr_db_array)))     # Recall
f1_res = np.zeros((num_samples, len(snr_db_array)))         # F1
nmse_res = np.zeros((num_samples, len(snr_db_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    theta = all_theta[sample_index, pilot_length_index, :pilot_length]
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for snr_db_index in tqdm(range(len(snr_db_array)), desc="Processing SNR Levels", leave=False, position=1):
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr_db = snr_db_array[snr_db_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and SNR level
        z_result, gamma_result = casbl_anc_algorithm(theta, received_signal, noise_power, loc)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, snr_db_index, :, :] = z_result
        gamma_result_bool = gamma_result > 0.05
        gamma_res[sample_index, snr_db_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, snr_db_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, snr_db_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, snr_db_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index]) > 0:
            f1_res[sample_index, snr_db_index] = (
                2 * precision_res[sample_index, snr_db_index] * recall_res[sample_index, snr_db_index]
                /
                (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index])
            )
        else:
            f1_res[sample_index, snr_db_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, snr_db_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:20<01:42, 20.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:37<01:12, 18.18s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:52, 17.39s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.04s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:16, 16.97s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:45<00:00, 17.49s/it]
# Processing Samples:   0%|          | 1/200 [01:45<5:49:28, 105.37s/it]
# Converged after 477 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.25s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.84s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.86s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:32, 16.39s/it]
# Converged after 468 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:15, 15.81s/it]
# Converged after 440 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 16.03s/it]
# Processing Samples:   1%|          | 2/200 [03:22<5:32:40, 100.81s/it]
# Converged after 483 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.28s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.50s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:53, 17.90s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.34s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.02s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 16.18s/it]
# Processing Samples:   2%|▏         | 3/200 [05:02<5:29:45, 100.43s/it]
# Converged after 429 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.90s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.62s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.57s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.75s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.69s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:41<00:00, 16.73s/it]
# Processing Samples:   2%|▏         | 4/200 [06:44<5:28:56, 100.70s/it]
# Converged after 438 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.41s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.41s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.39s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.38s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.37s/it]
# Converged after 493 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.95s/it]
# Processing Samples:   2%|▎         | 5/200 [08:18<5:19:31, 98.32s/it]
# Converged after 335 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:05, 16.50s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:54, 18.13s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.65s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.20s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:40<00:00, 16.11s/it]
# Processing Samples:   3%|▎         | 6/200 [09:58<5:20:11, 99.03s/it]
# Converged after 407 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.39s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.36s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.42s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.36s/it]
# Converged after 492 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.58s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 16.09s/it]
# Processing Samples:   4%|▎         | 7/200 [11:36<5:17:04, 98.57s/it]
# Converged after 452 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.22s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.03s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:51, 17.14s/it]
# Converged after 486 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:33, 16.87s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:15, 15.55s/it]
# Converged after 375 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 14.64s/it]
# Processing Samples:   4%|▍         | 8/200 [13:11<5:12:09, 97.55s/it]
# Converged after 362 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.39s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.38s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.39s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.40s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.39s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 16.16s/it]
# Processing Samples:   4%|▍         | 9/200 [14:49<5:10:39, 97.59s/it]
# Converged after 474 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.19s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.65s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:57<00:57, 19.12s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:13<00:35, 17.99s/it]
# Converged after 492 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:16, 16.31s/it]
# Converged after 378 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 15.14s/it]
# Processing Samples:   5%|▌         | 10/200 [16:29<5:11:14, 98.29s/it]
# Converged after 364 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.88s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.65s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:49, 16.65s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.26s/it]
# Converged after 471 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.29s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.48s/it]
# Processing Samples:   6%|▌         | 11/200 [18:03<5:06:03, 97.16s/it]
# Converged after 342 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.29s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.02s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:50, 16.81s/it]
# Converged after 459 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:31, 15.76s/it]
# Converged after 409 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:15, 15.73s/it]
# Converged after 445 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.18s/it]
# Processing Samples:   6%|▌         | 12/200 [19:39<5:03:22, 96.82s/it]
# Converged after 385 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.44s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.43s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.45s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.43s/it]
# Converged after 418 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.89s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 14.42s/it]
# Processing Samples:   6%|▋         | 13/200 [21:13<4:58:57, 95.92s/it]
# Converged after 333 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.44s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.49s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:52, 17.57s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.13s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:16, 16.87s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:42<00:00, 16.72s/it]
# Processing Samples:   7%|▋         | 14/200 [22:55<5:03:12, 97.81s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.35s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:06, 16.52s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:53, 17.93s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.42s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.22s/it]
# Converged after 410 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.46s/it]
# Processing Samples:   8%|▊         | 15/200 [24:30<4:58:23, 96.78s/it]
# Converged after 359 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.34s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.56s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.11s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.88s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.49s/it]
# Converged after 470 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 15.63s/it]
# Processing Samples:   8%|▊         | 16/200 [26:08<4:58:08, 97.22s/it]
# Converged after 386 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.49s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.43s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:53, 17.89s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.32s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:15, 15.02s/it]
# Converged after 317 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:28<00:00, 12.65s/it]
# Processing Samples:   8%|▊         | 17/200 [27:36<4:48:29, 94.59s/it]
# Converged after 277 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:53, 17.96s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.04s/it]
# Converged after 469 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:14, 14.86s/it]
# Converged after 372 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.26s/it]
# Processing Samples:   9%|▉         | 18/200 [29:09<4:44:55, 93.93s/it]
# Converged after 425 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:39, 19.91s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:37<01:13, 18.31s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:52, 17.43s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:32, 16.35s/it]
# Converged after 435 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.17s/it]
# Converged after 477 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 15.93s/it]
# Processing Samples:  10%|▉         | 19/200 [30:48<4:48:24, 95.61s/it]
# Converged after 437 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.44s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.81s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.86s/it]
# Converged after 450 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.16s/it]
# Processing Samples:  10%|█         | 20/200 [32:25<4:47:25, 95.81s/it]
# Converged after 388 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.13s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.29s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:48, 16.31s/it]
# Converged after 449 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:31, 15.90s/it]
# Converged after 440 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:15, 15.23s/it]
# Converged after 380 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 13.72s/it]
# Processing Samples:  10%|█         | 21/200 [33:55<4:40:43, 94.10s/it]
# Converged after 313 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.21s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.78s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.84s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.67s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.13s/it]
# Converged after 451 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.06s/it]
# Processing Samples:  11%|█         | 22/200 [35:30<4:40:07, 94.42s/it]
# Converged after 355 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.38s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.45s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:50, 16.70s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:02<00:30, 15.27s/it]
# Converged after 390 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:15<00:14, 14.14s/it]
# Converged after 332 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:25<00:00, 12.95s/it]
# Processing Samples:  12%|█▏        | 23/200 [36:56<4:30:51, 91.82s/it]
# Converged after 278 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.97s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.61s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.54s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:32, 16.45s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.23s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.71s/it]
# Processing Samples:  12%|█▏        | 24/200 [38:30<4:31:45, 92.64s/it]
# Converged after 331 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.42s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:52, 17.52s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.07s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:16, 16.84s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 15.39s/it]
# Processing Samples:  12%|█▎        | 25/200 [40:08<4:34:58, 94.28s/it]
# Converged after 354 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.43s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.51s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.58s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:03<00:31, 15.65s/it]
# Converged after 410 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:18<00:15, 15.43s/it]
# Converged after 443 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:31<00:00, 14.36s/it]
# Processing Samples:  13%|█▎        | 26/200 [41:39<4:30:45, 93.37s/it]
# Converged after 341 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.55s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.47s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.80s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.67s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.74s/it]
# Converged after 449 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.00s/it]
# Processing Samples:  14%|█▎        | 27/200 [43:12<4:28:51, 93.24s/it]
# Converged after 333 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.40s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:11, 17.80s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.93s/it]
# Converged after 479 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.74s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:15, 15.78s/it]
# Converged after 410 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.56s/it]
# Processing Samples:  14%|█▍        | 28/200 [44:50<4:31:05, 94.57s/it]
# Converged after 436 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.59s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.97s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.77s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:31, 15.77s/it]
# Converged after 414 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:18<00:15, 15.08s/it]
# Converged after 402 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:29<00:00, 13.77s/it]
# Processing Samples:  14%|█▍        | 29/200 [46:20<4:25:20, 93.10s/it]
# Converged after 299 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.48s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.56s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.53s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.84s/it]
# Converged after 488 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.57s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:42<00:00, 17.17s/it]
# Processing Samples:  15%|█▌        | 30/200 [48:03<4:32:09, 96.06s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.40s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.40s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.44s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.43s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.06s/it]
# Converged after 483 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:42<00:00, 17.43s/it]
# Processing Samples:  16%|█▌        | 31/200 [49:45<4:35:37, 97.86s/it]
# Converged after 476 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.85s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.60s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.52s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.70s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.13s/it]
# Converged after 449 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.90s/it]
# Processing Samples:  16%|█▌        | 32/200 [51:22<4:33:30, 97.68s/it]
# Converged after 462 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:39, 19.96s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:11, 17.88s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:51, 17.29s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.66s/it]
# Converged after 474 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.15s/it]
# Converged after 454 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 14.59s/it]
# Processing Samples:  16%|█▋        | 33/200 [52:58<4:30:02, 97.02s/it]
# Converged after 312 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.93s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.64s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.51s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:32, 16.47s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.49s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.63s/it]
# Processing Samples:  17%|█▋        | 34/200 [54:34<4:28:05, 96.90s/it]
# Converged after 409 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.24s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:11, 17.92s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:51, 17.23s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:31, 15.79s/it]
# Converged after 391 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:15, 15.91s/it]
# Converged after 474 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.00s/it]
# Processing Samples:  18%|█▊        | 35/200 [56:10<4:25:24, 96.51s/it]
# Converged after 377 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.54s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.46s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.43s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.44s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:15, 15.73s/it]
# Converged after 425 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.41s/it]
# Processing Samples:  18%|█▊        | 36/200 [57:45<4:22:37, 96.08s/it]
# Converged after 436 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.11s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:52, 17.64s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.16s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.53s/it]
# Converged after 463 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 15.78s/it]
# Processing Samples:  18%|█▊        | 37/200 [59:24<4:23:24, 96.96s/it]
# Converged after 417 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.56s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.47s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.48s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.19s/it]
# Converged after 436 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.29s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.88s/it]
# Processing Samples:  19%|█▉        | 38/200 [1:00:58<4:19:52, 96.25s/it]
# Converged after 399 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.08s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:11, 17.97s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:52, 17.50s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.30s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:16, 16.71s/it]
# Converged after 471 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.11s/it]
# Processing Samples:  20%|█▉        | 39/200 [1:02:36<4:19:35, 96.74s/it]
# Converged after 328 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.46s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.46s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.43s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.60s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:42<00:00, 17.27s/it]
# Processing Samples:  20%|██        | 40/200 [1:04:18<4:22:15, 98.35s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.49s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.50s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.47s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.43s/it]
# Converged after 497 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.14s/it]
# Converged after 470 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.58s/it]
# Processing Samples:  20%|██        | 41/200 [1:05:51<4:16:21, 96.74s/it]
# Converged after 310 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.45s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.54s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:54, 18.11s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.61s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.19s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 14.69s/it]
# Processing Samples:  21%|██        | 42/200 [1:07:28<4:14:17, 96.57s/it]
# Converged after 302 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.83s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.10s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.81s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:31, 15.69s/it]
# Converged after 404 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:18<00:14, 15.00s/it]
# Converged after 394 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.47s/it]
# Processing Samples:  22%|██▏       | 43/200 [1:09:00<4:09:10, 95.23s/it]
# Converged after 371 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.87s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.91s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:50, 16.72s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.60s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:15, 15.46s/it]
# Converged after 385 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.45s/it]
# Processing Samples:  22%|██▏       | 44/200 [1:10:32<4:05:35, 94.46s/it]
# Converged after 346 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.38s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.40s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.34s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:31, 15.85s/it]
# Converged after 449 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:15, 15.50s/it]
# Converged after 442 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:29<00:00, 13.79s/it]
# Processing Samples:  22%|██▎       | 45/200 [1:12:02<4:00:11, 92.98s/it]
# Converged after 269 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.54s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.44s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.55s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.93s/it]
# Converged after 455 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:17<00:14, 14.73s/it]
# Converged after 369 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.55s/it]
# Processing Samples:  23%|██▎       | 46/200 [1:13:34<3:58:00, 92.73s/it]
# Converged after 415 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.48s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:14, 18.64s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:53, 17.69s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.36s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:16, 16.87s/it]
# Converged after 466 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 14.75s/it]
# Processing Samples:  24%|██▎       | 47/200 [1:15:11<3:59:29, 93.92s/it]
# Converged after 278 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.48s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.47s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:47, 15.84s/it]
# Converged after 449 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.05s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:16, 16.08s/it]
# Converged after 490 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.54s/it]
# Processing Samples:  24%|██▍       | 48/200 [1:16:46<3:58:47, 94.26s/it]
# Converged after 425 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.22s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.78s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:53<00:52, 17.67s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:33, 17.00s/it]
# Converged after 481 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:15, 15.82s/it]
# Converged after 397 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.22s/it]
# Processing Samples:  24%|██▍       | 49/200 [1:18:23<3:59:27, 95.15s/it]
# Converged after 408 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.44s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.87s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.63s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.08s/it]
# Converged after 451 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:17<00:14, 14.74s/it]
# Converged after 340 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:27<00:00, 13.03s/it]
# Processing Samples:  25%|██▌       | 50/200 [1:19:50<3:51:58, 92.79s/it]
# Converged after 246 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.35s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.67s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.53s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.17s/it]
# Converged after 460 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:15, 15.50s/it]
# Converged after 423 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 14.84s/it]
# Processing Samples:  26%|██▌       | 51/200 [1:21:23<3:50:40, 92.89s/it]
# Converged after 390 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.40s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.40s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.60s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.89s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:18<00:14, 14.59s/it]
# Converged after 322 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.60s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:22:59<3:51:18, 93.77s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.68s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:09, 17.39s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.91s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.68s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.64s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 15.95s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:24:38<3:53:36, 95.35s/it]
# Converged after 429 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.43s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.49s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:53, 17.87s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.41s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.21s/it]
# Converged after 495 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:42<00:00, 16.86s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:26:21<3:57:02, 97.42s/it]
# Converged after 488 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.52s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.50s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.60s/it]
# Converged after 421 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.20s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.04s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:27:53<3:51:46, 95.91s/it]
# Converged after 331 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.41s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.17s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:52, 17.55s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.09s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:16, 16.97s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 15.95s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:29:33<3:52:57, 97.06s/it]
# Converged after 403 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.44s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.81s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.32s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 16.01s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:31:12<3:52:50, 97.70s/it]
# Converged after 382 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.49s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.42s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.37s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.34s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.55s/it]
# Processing Samples:  29%|██▉       | 58/200 [1:32:48<3:49:55, 97.15s/it]
# Converged after 395 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.01s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.65s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.02s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.72s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:15, 15.10s/it]
# Converged after 344 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.50s/it]
# Processing Samples:  30%|██▉       | 59/200 [1:34:24<3:48:01, 97.03s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.29s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.31s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.33s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.75s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.25s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 16.10s/it]
# Processing Samples:  30%|███       | 60/200 [1:36:04<3:47:52, 97.66s/it]
# Converged after 399 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.07s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.25s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.27s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.24s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.17s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 14.61s/it]
# Processing Samples:  30%|███       | 61/200 [1:37:37<3:43:17, 96.38s/it]
# Converged after 369 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.57s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.14s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:51, 17.21s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.80s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.58s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.45s/it]
# Processing Samples:  31%|███       | 62/200 [1:39:15<3:42:42, 96.83s/it]
# Converged after 390 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.49s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.39s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.51s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.45s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:15, 15.16s/it]
# Converged after 377 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 13.71s/it]
# Processing Samples:  32%|███▏      | 63/200 [1:40:45<3:36:40, 94.89s/it]
# Converged after 339 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.25s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.98s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.14s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.73s/it]
# Converged after 500 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:16<00:13, 13.84s/it]
# Converged after 276 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:26<00:00, 12.49s/it]
# Processing Samples:  32%|███▏      | 64/200 [1:42:12<3:29:14, 92.31s/it]
# Converged after 312 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:08, 17.11s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.32s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.86s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.57s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.46s/it]
# Processing Samples:  32%|███▎      | 65/200 [1:43:49<3:30:52, 93.72s/it]
# Converged after 388 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.22s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.11s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.13s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.14s/it]
# Converged after 499 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:16<00:14, 14.55s/it]
# Converged after 330 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:31<00:00, 14.84s/it]
# Processing Samples:  33%|███▎      | 66/200 [1:45:20<3:27:58, 93.12s/it]
# Converged after 472 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.21s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.12s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.25s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.84s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.61s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 16.05s/it]
# Processing Samples:  34%|███▎      | 67/200 [1:47:00<3:30:30, 94.96s/it]
# Converged after 451 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.22s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.22s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:54, 18.13s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.34s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.58s/it]
# Converged after 463 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:39<00:00, 16.10s/it]
# Processing Samples:  34%|███▍      | 68/200 [1:48:39<3:31:50, 96.29s/it]
# Converged after 462 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.23s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.21s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.12s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.28s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.92s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.57s/it]
# Processing Samples:  34%|███▍      | 69/200 [1:50:16<3:30:32, 96.44s/it]
# Converged after 367 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.77s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:05, 16.47s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:48, 16.30s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.07s/it]
# Converged after 485 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:16, 16.09s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.52s/it]
# Processing Samples:  35%|███▌      | 70/200 [1:51:51<3:28:16, 96.12s/it]
# Converged after 419 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.51s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.13s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.19s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:33, 16.78s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:15, 15.96s/it]
# Converged after 440 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.65s/it]
# Processing Samples:  36%|███▌      | 71/200 [1:53:26<3:25:41, 95.67s/it]
# Converged after 343 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.59s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.30s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.36s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.25s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.63s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 15.27s/it]
# Processing Samples:  36%|███▌      | 72/200 [1:55:01<3:23:46, 95.52s/it]
# Converged after 405 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.32s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:09, 17.44s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.85s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.57s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:15, 15.94s/it]
# Converged after 435 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.58s/it]
# Processing Samples:  36%|███▋      | 73/200 [1:56:38<3:23:24, 96.10s/it]
# Converged after 454 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.08s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:03, 16.00s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:50<00:51, 17.24s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.90s/it]
# Converged after 492 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:15, 15.90s/it]
# Converged after 422 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 13.71s/it]
# Processing Samples:  37%|███▋      | 74/200 [1:58:09<3:18:25, 94.49s/it]
# Converged after 367 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:36, 19.30s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:09, 17.37s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.74s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:32, 16.46s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.22s/it]
# Converged after 490 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.63s/it]
# Processing Samples:  38%|███▊      | 75/200 [1:59:47<3:18:49, 95.43s/it]
# Converged after 438 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.57s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.99s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:52<00:53, 17.76s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.06s/it]
# Converged after 498 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.23s/it]
# Converged after 451 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.43s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:01:24<3:18:17, 95.95s/it]
# Converged after 412 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.04s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.05s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.27s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.59s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 14.75s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:02:58<3:15:27, 95.34s/it]
# Converged after 355 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.53s/it]
# ...
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.02s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:52, 17.49s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.90s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.21s/it]
# Converged after 446 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 14.73s/it]
# Processing Samples:  88%|████████▊ | 175/200 [4:36:45<39:36, 95.06s/it]
# Converged after 354 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.42s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.14s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.08s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.04s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:16, 16.15s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.55s/it]
# Processing Samples:  88%|████████▊ | 176/200 [4:38:17<37:40, 94.19s/it]
# Converged after 324 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.00s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.00s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.04s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.23s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.57s/it]
# Converged after 441 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:31<00:00, 13.87s/it]
# Processing Samples:  88%|████████▊ | 177/200 [4:39:48<35:45, 93.29s/it]
# Converged after 334 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.80s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.64s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.99s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.61s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.38s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 15.81s/it]
# Processing Samples:  89%|████████▉ | 178/200 [4:41:27<34:45, 94.78s/it]
# Converged after 445 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.10s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.21s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:52, 17.57s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.89s/it]
# Converged after 477 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.81s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 15.99s/it]
# Processing Samples:  90%|████████▉ | 179/200 [4:43:05<33:33, 95.90s/it]
# Converged after 434 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.05s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.02s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.02s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:02<00:30, 15.33s/it]
# Converged after 432 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:16, 16.07s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:29<00:00, 14.10s/it]
# Processing Samples:  90%|█████████ | 180/200 [4:44:35<31:22, 94.14s/it]
# Converged after 307 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.03s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.65s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.11s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.67s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:15, 15.87s/it]
# Converged after 435 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 15.60s/it]
# Processing Samples:  90%|█████████ | 181/200 [4:46:12<30:04, 94.95s/it]
# Converged after 465 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.14s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.07s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.08s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.04s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:15<00:14, 14.47s/it]
# Converged after 353 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 14.55s/it]
# Processing Samples:  91%|█████████ | 182/200 [4:47:43<28:05, 93.66s/it]
# Converged after 438 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.07s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.14s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:52, 17.45s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.89s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.45s/it]
# Converged after 489 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.92s/it]
# Processing Samples:  92%|█████████▏| 183/200 [4:49:21<26:53, 94.93s/it]
# Converged after 457 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.13s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.09s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.09s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:03<00:31, 15.66s/it]
# Converged after 458 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.82s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 14.06s/it]
# Processing Samples:  92%|█████████▏| 184/200 [4:50:51<24:59, 93.72s/it]
# Converged after 328 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.14s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.04s/it]
# Converged after 491 outer iterations
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:31, 15.86s/it]
# Converged after 422 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:14<00:13, 13.38s/it]
# Converged after 344 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 15.31s/it]
# Processing Samples:  92%|█████████▎| 185/200 [4:52:25<23:24, 93.65s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.83s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.03s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.12s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:02<00:30, 15.20s/it]
# Converged after 438 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:15<00:14, 14.53s/it]
# Converged after 396 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:27<00:00, 13.70s/it]
# Processing Samples:  93%|█████████▎| 186/200 [4:53:52<21:25, 91.80s/it]
# Converged after 366 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.98s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.95s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.19s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.15s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:16, 16.10s/it]
# Converged after 472 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:36<00:00, 16.21s/it]
# Processing Samples:  94%|█████████▎| 187/200 [4:55:29<20:13, 93.34s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.01s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.67s/it]
# Converged after 488 outer iterations
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.41s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:05<00:32, 16.21s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:15, 15.90s/it]
# Converged after 474 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:31<00:00, 14.08s/it]
# Processing Samples:  94%|█████████▍| 188/200 [4:57:01<18:33, 92.83s/it]
# Converged after 284 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.07s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.07s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.02s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.03s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:19<00:15, 15.63s/it]
# Converged after 458 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:34<00:00, 15.48s/it]
# Processing Samples:  94%|█████████▍| 189/200 [4:58:35<17:05, 93.26s/it]
# Converged after 450 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.54s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:09, 17.42s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.75s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:32, 16.47s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.38s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 15.54s/it]
# Processing Samples:  95%|█████████▌| 190/200 [5:00:13<15:45, 94.56s/it]
# Converged after 414 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.20s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.18s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:49<00:49, 16.63s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.86s/it]
# Converged after 469 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.21s/it]
# Converged after 456 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:30<00:00, 13.72s/it]
# Processing Samples:  96%|█████████▌| 191/200 [5:01:44<14:00, 93.40s/it]
# Converged after 343 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.08s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.57s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:50, 16.83s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.55s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:15, 15.38s/it]
# Converged after 393 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 14.52s/it]
# Processing Samples:  96%|█████████▌| 192/200 [5:03:17<12:28, 93.53s/it]
# Converged after 377 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.05s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.03s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.04s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.08s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:17<00:15, 15.06s/it]
# Converged after 390 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:33<00:00, 15.42s/it]
# Processing Samples:  96%|█████████▋| 193/200 [5:04:51<10:54, 93.56s/it]
# Converged after 499 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.35s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.92s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.07s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:32, 16.18s/it]
# Converged after 448 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.11s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:38<00:00, 16.08s/it]
# Processing Samples:  97%|█████████▋| 194/200 [5:06:29<09:29, 94.97s/it]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.05s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.19s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.80s/it]
# Converged after 465 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:13<00:13, 13.43s/it]
# Converged after 282 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:28<00:00, 14.05s/it]
# Processing Samples:  98%|█████████▊| 195/200 [5:07:58<07:45, 93.16s/it]
# Converged after 468 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.52s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.13s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:51<00:51, 17.19s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.02s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:24<00:16, 16.68s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:35<00:00, 14.84s/it]
# Processing Samples:  98%|█████████▊| 196/200 [5:09:34<06:16, 94.00s/it]
# Converged after 318 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.06s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.98s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:47, 15.99s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.01s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:20<00:16, 16.14s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:29<00:00, 13.90s/it]
# Processing Samples:  98%|█████████▊| 197/200 [5:11:04<04:38, 92.79s/it]
# Converged after 262 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.03s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.99s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.10s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.16s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.75s/it]
# Processing SNR Levels: 100%|██████████| 6/6 [01:37<00:00, 16.09s/it]
# Processing Samples:  99%|█████████▉| 198/200 [5:12:42<03:08, 94.32s/it]
# Converged after 453 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.71s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.26s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:48, 16.13s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:02<00:30, 15.23s/it]
# Converged after 415 outer iterations
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:15<00:14, 14.30s/it]
# Converged after 366 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:25<00:00, 12.94s/it]
# Processing Samples: 100%|█████████▉| 199/200 [5:14:08<01:31, 91.66s/it]
# Converged after 277 outer iterations
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing SNR Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.03s/it]
# Processing SNR Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.00s/it]
# Processing SNR Levels:  50%|█████     | 3/6 [00:48<00:47, 16.00s/it]
# Processing SNR Levels:  67%|██████▋   | 4/6 [01:03<00:31, 15.99s/it]
# Processing SNR Levels:  83%|████████▎ | 5/6 [01:18<00:15, 15.32s/it]
# Converged after 426 outer iterations
# Processing SNR Levels: 100%|██████████| 6/6 [01:32<00:00, 14.99s/it]
# Processing Samples: 100%|██████████| 200/200 [5:15:40<00:00, 94.70s/it]
# Converged after 434 outer iterations

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-casbl-anc-alpha-1-00-beta-0-10-snr-db-all-pilot-length-30-set-5.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length=pilot_length,
    snr_db_array=snr_db_array
)

print("All results have been saved")
# Out:
# All results have been saved
