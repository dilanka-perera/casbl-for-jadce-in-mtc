# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(600, 800)

# %% [markdown]
# Sparse Bayesian Learning (SBL)

# %%
def sbl_algorithm(theta, y, noise_var, max_iter=500, stopping_criterion=1e-4):
    # Sparse Bayesian Learning (SBL) for Multiple Measurement Vectors (MMV).

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess: identity matrix

    # Iterative update process
    for t in range(max_iter):
       # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute gamma update using the derived formula
        gamma_new = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Ensure non-negativity for numerical stability
        gamma_new = np.maximum(gamma_new, 1e-8)

        # Check for convergence: if change is below threshold, stop iterations
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma with new values
        Gamma = np.diagflat(gamma_new)

    # Return final estimates
    return mu_x, np.diag(Gamma)

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = sbl_algorithm(theta, received_signal, noise_power)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:21, 20.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.25s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.44s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 20.93s/it]
# Processing Samples:   0%|          | 1/200 [02:03<6:50:01, 123.63s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.05s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.18s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:40, 20.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.63s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.42s/it]
# Processing Samples:   1%|          | 2/200 [04:09<6:52:02, 124.86s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:54, 22.92s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:22, 20.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:00, 20.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:10<00:00, 22.47s/it]
# Processing Samples:   2%|▏         | 3/200 [06:19<6:58:36, 127.49s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:02, 20.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.33s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.32s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.12s/it]
# Processing Samples:   2%|▏         | 4/200 [08:23<6:51:11, 125.87s/it]
# Converged after 447 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.90s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.79s/it]
# Processing Samples:   2%|▎         | 5/200 [10:27<6:47:01, 125.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.32s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.91s/it]
# Processing Samples:   3%|▎         | 6/200 [12:30<6:42:26, 124.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:16, 19.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.68s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.93s/it]
# Processing Samples:   4%|▎         | 7/200 [14:32<6:38:14, 123.80s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.85s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.05s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.05s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.79s/it]
# Processing Samples:   4%|▍         | 8/200 [16:34<6:34:15, 123.21s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.70s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.71s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.25s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.13s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.04s/it]
# Processing Samples:   4%|▍         | 9/200 [18:37<6:31:20, 122.93s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:25, 21.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:01, 20.39s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:39, 19.98s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.26s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.26s/it]
# Processing Samples:   5%|▌         | 10/200 [20:42<6:31:35, 123.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:49, 21.90s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:21, 20.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<00:59, 19.93s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.57s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.01s/it]
# Processing Samples:   6%|▌         | 11/200 [22:47<6:30:59, 124.12s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:48, 21.80s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:42, 21.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.88s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:08<00:00, 22.17s/it]
# Processing Samples:   6%|▌         | 12/200 [24:55<6:32:44, 125.34s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.55s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:02, 20.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.78s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.35s/it]
# Processing Samples:   6%|▋         | 13/200 [26:58<6:28:08, 124.54s/it]
# Converged after 399 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.18s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.73s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:02, 20.68s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.35s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.72s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.50s/it]
# Processing Samples:   7%|▋         | 14/200 [29:03<6:26:50, 124.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.39s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:23, 20.99s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:23<00:42, 21.48s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.58s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:10<00:00, 22.54s/it]
# Processing Samples:   8%|▊         | 15/200 [31:13<6:29:40, 126.38s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.46s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.00s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.67s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.48s/it]
# Processing Samples:   8%|▊         | 16/200 [33:18<6:25:51, 125.82s/it]
# Converged after 469 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:02, 20.87s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:40, 20.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.01s/it]
# Converged after 463 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.45s/it]
# Processing Samples:   8%|▊         | 17/200 [35:19<6:19:50, 124.54s/it]
# Converged after 406 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.46s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.96s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.43s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.55s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.99s/it]
# Processing Samples:   9%|▉         | 18/200 [37:25<6:18:32, 124.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:01, 20.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:40, 20.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.44s/it]
# Processing Samples:  10%|▉         | 19/200 [39:30<6:17:11, 125.04s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:40, 20.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:22, 20.67s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.18s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.81s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.05s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 20.87s/it]
# Processing Samples:  10%|█         | 20/200 [41:35<6:14:40, 124.89s/it]
# Converged after 492 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:23<01:55, 23.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:42<01:24, 21.05s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:02<01:00, 20.32s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:25<00:42, 21.48s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:20, 21.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02
02s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.52s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 20.96s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:48:51<5:08:32, 125.09s/it]
# Converged after 463 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.37s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:23, 20.78s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.91s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.23s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:07<00:00, 21.84s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:50:58<5:07:57, 125.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:39, 19.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.98s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:41, 20.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.54s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.81s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:53:04<5:05:28, 125.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.23s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.47s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.69s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 22.05s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:55:09<5:03:06, 125.42s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.99s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.83s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.69s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:57:10<4:58:01, 124.18s/it]
# Converged after 462 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.58s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.68s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.53s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:59:14<4:55:41, 124.06s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.66s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.66s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.34s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.97s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.12s/it]
# Processing Samples:  29%|██▉       | 58/200 [2:01:17<4:53:21, 123.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.95s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.61s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.86s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.35s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.24s/it]
# Processing Samples:  30%|██▉       | 59/200 [2:03:22<4:51:31, 124.05s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:49, 21.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:21, 20.26s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.57s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 21.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:20, 20.87s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 20.74s/it]
# Processing Samples:  30%|███       | 60/200 [2:05:26<4:49:28, 124.06s/it]
# Converged after 492 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.28s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.26s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.61s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.51s/it]
# Processing Samples:  30%|███       | 61/200 [2:07:31<4:48:16, 124.43s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:15, 18.95s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:20<00:41, 20.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.43s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.84s/it]
# Processing Samples:  31%|███       | 62/200 [2:09:36<4:46:27, 124.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.16s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:37<01:14, 18.61s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.20s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.47s/it]
# Processing Samples:  32%|███▏      | 63/200 [2:11:39<4:43:36, 124.21s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.92s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.01s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.38s/it]
# Processing Samples:  32%|███▏      | 64/200 [2:13:42<4:40:20, 123.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.38s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.15s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.65s/it]
# Processing Samples:  32%|███▎      | 65/200 [2:15:44<4:36:59, 123.11s/it]
# Converged after 470 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.92s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 18.00s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.69s/it]
# Processing Samples:  33%|███▎      | 66/200 [2:17:44<4:33:19, 122.38s/it]
# Converged after 463 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.29s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:01, 20.38s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.10s/it]
# Processing Samples:  34%|███▎      | 67/200 [2:19:47<4:31:18, 122.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.77s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<01:00, 20.20s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.61s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.77s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.07s/it]
# Processing Samples:  34%|███▍      | 68/200 [2:21:49<4:29:00, 122.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.30s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.60s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<01:00, 20.10s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:40, 20.04s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.04s/it]
# Processing Samples:  34%|███▍      | 69/200 [2:23:53<4:28:07, 122.81s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.23s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:21, 20.27s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.68s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.56s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.72s/it]
# Processing Samples:  35%|███▌      | 70/200 [2:25:54<4:25:21, 122.47s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.12s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.53s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 19.74s/it]
# Processing Samples:  36%|███▌      | 71/200 [2:27:53<4:21:08, 121.46s/it]
# Converged after 405 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.06s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.83s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:20, 20.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.71s/it]
# Processing Samples:  36%|███▌      | 72/200 [2:29:55<4:19:16, 121.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 20.00s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.88s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.71s/it]
# Processing Samples:  36%|███▋      | 73/200 [2:31:57<4:17:28, 121.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.99s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.96s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.15s/it]
# Processing Samples:  37%|███▋      | 74/200 [2:33:59<4:15:28, 121.66s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.91s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.44s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.11s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.26s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.01s/it]
# Processing Samples:  38%|███▊      | 75/200 [2:36:02<4:14:23, 122.11s/it]
# Converged after 496 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:59, 19.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.01s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.87s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:38:05<4:12:44, 122.29s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:20, 20.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.04s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:40:08<4:11:28, 122.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:49, 21.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.98s/it]
# ...
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.09s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:37, 18.96s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.65s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.62s/it]
# Processing Samples:  88%|████████▊ | 175/200 [5:57:58<48:56, 117.47s/it]
# Converged after 421 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:58, 19.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.20s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:56<00:00, 20.08s/it]
# Processing Samples:  88%|████████▊ | 176/200 [5:59:55<46:51, 117.16s/it]
# Converged after 458 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:10, 17.52s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.78s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.64s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:55<00:00, 19.76s/it]
# Processing Samples:  88%|████████▊ | 177/200 [6:01:50<44:40, 116.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:41, 20.33s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:15, 18.88s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:55, 18.57s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.82s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.83s/it]
# Processing Samples:  89%|████████▉ | 178/200 [6:03:47<42:51, 116.90s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:43, 20.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:15, 18.97s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:56, 18.68s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.17s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.63s/it]
# Processing Samples:  90%|████████▉ | 179/200 [6:05:47<41:13, 117.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 19.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.96s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:37, 18.90s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.26s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 19.99s/it]
# Processing Samples:  90%|█████████ | 180/200 [6:07:45<39:17, 117.90s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.31s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:14<00:38, 19.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:33<00:19, 19.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.49s/it]
# Processing Samples:  90%|█████████ | 181/200 [6:09:43<37:15, 117.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:26, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:55<00:56, 18.97s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:38, 19.17s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.26s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 20.63s/it]
# Processing Samples:  91%|█████████ | 182/200 [6:11:40<35:18, 117.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.41s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.57s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.84s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:15<00:39, 19.62s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:34<00:19, 19.41s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:54<00:00, 19.58s/it]
# Processing Samples:  92%|█████████▏| 183/200 [6:13:35<33:05, 116.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:20<01:44, 20.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:16, 19.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.98s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:39, 19.56s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.32s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:59<00:00, 20.22s/it]
# Processing Samples:  92%|█████████▏| 184/200 [6:15:35<31:22, 117.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.12s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:39<00:20, 20.50s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:57<00:00, 19.59s/it]
# Processing Samples:  92%|█████████▎| 185/200 [6:17:32<29:22, 117.52s/it]
# Converged after 426 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.32s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:18, 19.69s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:57, 19.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:38, 19.24s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:19, 19.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.03s/it]
# Processing Samples:  93%|█████████▎| 186/200 [6:19:33<27:40, 118.58s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:38<01:17, 19.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:58, 19.51s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:38, 19.48s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:41<00:21, 21.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 20.92s/it]
# Processing Samples:  94%|█████████▎| 187/200 [6:21:35<25:54, 119.60s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.61s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:20, 20.03s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:39, 19.88s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:21, 21.11s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 21.13s/it]
# Processing Samples:  94%|█████████▍| 188/200 [6:23:38<24:08, 120.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:31, 18.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:22, 20.63s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.07s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:19<00:39, 19.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:21, 21.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:05<00:00, 21.44s/it]
# Processing Samples:  94%|█████████▍| 189/200 [6:25:44<22:23, 122.12s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:50, 22.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:41<01:21, 20.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:01<01:00, 20.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:43, 21.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:45<00:21, 21.08s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:09<00:00, 22.29s/it]
# Processing Samples:  95%|█████████▌| 190/200 [6:27:53<20:44, 124.42s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.81s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.19s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:40, 20.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:20, 20.26s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.51s/it]
# Processing Samples:  96%|█████████▌| 191/200 [6:29:56<18:35, 123.97s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.27s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:59, 19.89s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:40, 20.02s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:38<00:19, 19.88s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:01<00:00, 21.18s/it]
# Processing Samples:  96%|█████████▌| 192/200 [6:31:58<16:26, 123.32s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.55s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.82s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:56<00:57, 19.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:16<00:39, 19.59s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:36<00:19, 19.62s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:58<00:00, 20.71s/it]
# Processing Samples:  96%|█████████▋| 193/200 [6:33:57<14:14, 122.03s/it]
# Converged after 467 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.53s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.82s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:54, 18.22s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:17<00:40, 20.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:37<00:20, 20.20s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 21.83s/it]
# Processing Samples:  97%|█████████▋| 194/200 [6:36:00<12:13, 122.20s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.59s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:21, 20.37s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:04<01:06, 22.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:49<00:22, 22.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:10<00:00, 21.92s/it]
# Processing Samples:  98%|█████████▊| 195/200 [6:38:10<10:22, 124.59s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.58s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:21, 20.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<01:00, 20.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:43<00:21, 21.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:04<00:00, 21.06s/it]
# Processing Samples:  98%|█████████▊| 196/200 [6:40:14<08:18, 124.60s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:22<01:51, 22.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.92s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [01:00<00:59, 19.75s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:24<00:42, 21.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:44<00:20, 20.92s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:03<00:00, 20.37s/it]
# Processing Samples:  98%|█████████▊| 197/200 [6:42:18<06:12, 124.24s/it]
# Converged after 442 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:49, 21.91s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:40<01:19, 19.92s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:59<00:58, 19.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:22<00:41, 20.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:42<00:20, 20.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:02<00:00, 20.48s/it]
# Processing Samples:  99%|█████████▉| 198/200 [6:44:20<04:07, 123.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:47, 21.53s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.45s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:58<00:57, 19.13s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:21<00:41, 20.59s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.17s/it]
# Processing Samples: 100%|█████████▉| 199/200 [6:46:21<02:02, 122.81s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:21<01:46, 21.34s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:39<01:17, 19.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:57<00:56, 18.95s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:18<00:38, 19.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:40<00:20, 20.63s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [02:00<00:00, 20.28s/it]
# Processing Samples: 100%|██████████| 200/200 [6:48:21<00:00, 122.51s/it]
# Converged after 469 iterations

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-sbl-snr-db-12-pilot-length-all-set-4.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved
