# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(200, 400)

# %% [markdown]
# Sparse Bayesian Learning (SBL)

# %%
def sbl_algorithm(theta, y, noise_var, max_iter=500, stopping_criterion=1e-4):
    # Sparse Bayesian Learning (SBL) for Multiple Measurement Vectors (MMV).

    M = y.shape[1]  # Number of antennas (columns of y)

    L = theta.shape[0]  # Pilot Length (rows of theta)
    N = theta.shape[1] # Number of MTDs (columns of theta)

    # Initialize Gamma (covariance matrix of the signal)
    Gamma = np.eye(N) * 0.1  # Initial guess: identity matrix

    # Iterative update process
    for t in range(max_iter):
       # E-Step: Compute the mean (mu_x) and covariance (Sigma_x) of x
        Sigma_y = theta @ Gamma @ theta.conj().T + noise_var * np.eye(L)
        Sigma_y_inv = np.linalg.inv(Sigma_y)
        Sigma_x = Gamma - Gamma @ theta.conj().T @ Sigma_y_inv @ theta @ Gamma
        mu_x = Gamma @ theta.conj().T @ Sigma_y_inv @ y

        # Compute gamma update using the derived formula
        gamma_new = (np.linalg.norm(mu_x, axis=1) ** 2) / M + np.real(np.diag(Sigma_x))

        # Ensure non-negativity for numerical stability
        gamma_new = np.maximum(gamma_new, 1e-8)

        # Check for convergence: if change is below threshold, stop iterations
        if np.linalg.norm(gamma_new - np.diag(Gamma)) < stopping_criterion:
            print(f"Converged after {t+1} iterations")
            break

        # Update Gamma with new values
        Gamma = np.diagflat(gamma_new)

    # Return final estimates
    return mu_x, np.diag(Gamma)

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(pilot_length_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(pilot_length_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(pilot_length_array)))         # HR
fr_res = np.zeros((num_samples, len(pilot_length_array)))         # FR
srr_res = np.zeros((num_samples, len(pilot_length_array)))        # SRR
precision_res = np.zeros((num_samples, len(pilot_length_array)))  # Precision
recall_res = np.zeros((num_samples, len(pilot_length_array)))     # Recall
f1_res = np.zeros((num_samples, len(pilot_length_array)))         # F1
nmse_res = np.zeros((num_samples, len(pilot_length_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for pilot_length_index in tqdm(range(len(pilot_length_array)), desc="Processing Pilot Length Levels", leave=False, position=1):
        pilot_length = pilot_length_array[pilot_length_index]
        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and Pilot Length
        z_result, gamma_result = sbl_algorithm(theta, received_signal, noise_power)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, pilot_length_index, :, :] = z_result
        gamma_result_bool =  gamma_result > 0.05
        gamma_res[sample_index, pilot_length_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, pilot_length_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, pilot_length_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, pilot_length_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, pilot_length_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index]) > 0:
            f1_res[sample_index, pilot_length_index] = (
                2 * precision_res[sample_index, pilot_length_index] * recall_res[sample_index, pilot_length_index]
                /
                (precision_res[sample_index, pilot_length_index] + recall_res[sample_index, pilot_length_index])
            )
        else:
            f1_res[sample_index, pilot_length_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, pilot_length_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.05s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.50s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.48s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.23s/it]
# Processing Samples:   0%|          | 1/200 [01:45<5:51:25, 105.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:02, 15.67s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:47<00:47, 15.95s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:18, 18.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:42<00:00, 17.54s/it]
# Processing Samples:   1%|          | 2/200 [03:28<5:42:39, 103.84s/it]
# Converged after 451 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.24s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:13<00:38, 19.38s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:30<00:18, 18.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.45s/it]
# Processing Samples:   2%|▏         | 3/200 [05:16<5:48:00, 105.99s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:16, 15.36s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.82s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:52, 17.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.57s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.63s/it]
# Processing Samples:   2%|▏         | 4/200 [07:00<5:43:33, 105.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:04, 16.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:51, 17.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.82s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.65s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.73s/it]
# Processing Samples:   2%|▎         | 5/200 [08:45<5:41:08, 104.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:16, 15.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:15, 18.94s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:55, 18.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:35, 17.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 17.78s/it]
# Processing Samples:   3%|▎         | 6/200 [10:32<5:41:32, 105.63s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.69s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.72s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:51, 17.15s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.51s/it]
# Processing Samples:   4%|▎         | 7/200 [12:16<5:38:10, 105.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.92s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:51, 17.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.15s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.22s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.41s/it]
# Processing Samples:   4%|▍         | 8/200 [14:00<5:35:09, 104.74s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:16, 15.22s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.80s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:54<00:56, 18.96s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:36, 18.30s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:29<00:17, 17.98s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 19.09s/it]
# Processing Samples:   4%|▍         | 9/200 [15:50<5:39:16, 106.58s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.39s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.77s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.09s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.64s/it]
# Processing Samples:   5%|▌         | 10/200 [17:36<5:36:33, 106.28s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.74s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.06s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.21s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.73s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 18.30s/it]
# Processing Samples:   6%|▌         | 11/200 [19:20<5:32:27, 105.54s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.07s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.84s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:16, 16.95s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.57s/it]
# Processing Samples:   6%|▌         | 12/200 [21:05<5:30:26, 105.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.70s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:02, 15.62s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:47<00:48, 16.08s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:04<00:32, 16.46s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:22<00:16, 16.72s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 18.32s/it]
# Processing Samples:   6%|▋         | 13/200 [22:49<5:26:53, 104.88s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.31s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.71s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.13s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.81s/it]
# Processing Samples:   7%|▋         | 14/200 [24:32<5:23:34, 104.38s/it]
# Converged after 430 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.77s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:06, 16.65s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.73s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.00s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.24s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.45s/it]
# Processing Samples:   8%|▊         | 15/200 [26:18<5:23:24, 104.89s/it]
# Converged after 468 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.63s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.93s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.43s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.81s/it]
# Processing Samples:   8%|▊         | 16/200 [28:02<5:20:41, 104.57s/it]
# Converged after 416 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.66s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.01s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.60s/it]
# Processing Samples:   8%|▊         | 17/200 [29:47<5:19:38, 104.80s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.15s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.27s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.14s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.68s/it]
# Processing Samples:   9%|▉         | 18/200 [31:33<5:18:57, 105.15s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.85s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:21<00:16, 16.09s/it]
# Converged after 405 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:42<00:00, 17.95s/it]
# Processing Samples:  10%|▉         | 19/200 [33:16<5:15:14, 104.50s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.76s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:04, 16.02s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.30s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.07s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.58s/it]
# Processing Samples:  10%|█         | 20/200 [35:01<5:14:05, 104.70s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.92s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.79s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 18.10s/it]
# Processing Samples:  10%|█         | 21/200 [36:45<5:11:53, 104.54s/it]
# Converged after 473 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.17s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.37s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.11s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.56s/it]
# Processing Samples:  11%|█         | 22/200 [38:31<5:10:52, 104.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.11s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.38s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.58s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.44s/it]
# Processing Samples:  12%|█▏        | 23/200 [40:16<5:09:33, 104.94s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.84s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.32s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.39s/it]
# Processing Samples:  12%|█▏        | 24/200 [42:02<5:08:38, 105.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.87s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.24s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.37s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.39s/it]
# Processing Samples:  12%|█▎        | 25/200 [43:49<5:08:09, 105.65s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.35s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:52, 17.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.16s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.21s/it]
# Processing Samples:  13%|█▎        | 26/200 [45:36<5:07:43, 106.11s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.98s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.81s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.74s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.68s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.20s/it]
# Processing Samples:  14%|█▎        | 27/200 [47:23<5:07:06, 106.51s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:30, 18.12s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.15s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:51, 17.03s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.15s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.56s/it]
# Processing Samples:  14%|█▍        | 28/200 [49:11<5:06:04, 106.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.29s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.59s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 18.20s/it]
# Processing Samples:  14%|█▍        | 29/200 [50:55<5:02:34, 106.17s/it]
# Converged after 476 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:22, 16.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.46s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.66s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.96s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.28s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.81s/it]
# Processing Samples:  15%|█▌        | 30/200 [52:42<5:01:27, 106.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.34s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.60s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.91s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.34s/it]
# Processing Samples:  16%|█▌        | 31/200 [54:29<4:59:33, 106.35s/it]
# Converged after 489 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.65s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.17s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.83s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.42s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.39s/it]
# Processing Samples:  16%|█▌        | 32/200 [56:15<4:57:32, 106.26s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.84s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:03, 16.00s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.72s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.94s/it]
# Converged after 497 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.04s/it]
# Processing Samples:  16%|█▋        | 33/200 [58:00<4:54:46, 105.91s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.27s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:36, 18.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.89s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.00s/it]
# Processing Samples:  17%|█▋        | 34/200 [59:45<4:52:42, 105.80s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.03s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.92s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:36, 18.09s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.99s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.11s/it]
# Processing Samples:  18%|█▊        | 35/200 [1:01:31<4:50:50, 105.76s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.43s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.91s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.63s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 17.89s/it]
# Processing Samples:  18%|█▊        | 36/200 [1:03:17<4:49:30, 105.92s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:32, 18.56s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.88s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.26s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.49s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.57s/it]
# Processing Samples:  18%|█▊        | 37/200 [1:05:06<4:49:47, 106.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.34s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.29s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.70s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.06s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.59s/it]
# Processing Samples:  19%|█▉        | 38/200 [1:06:51<4:47:07, 106.35s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.01s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.17s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:23<00:17, 17.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:39<00:00, 16.68s/it]
# Processing Samples:  20%|█▉        | 39/200 [1:08:31<4:40:05, 104.38s/it]
# Converged after 427 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:35, 19.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:10, 17.59s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:51, 17.18s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.20s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.13s/it]
# Processing Samples:  20%|██        | 40/200 [1:10:18<4:40:17, 105.11s/it]
# Converged after 493 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.62s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.83s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.05s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.25s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.74s/it]
# Processing Samples:  20%|██        | 41/200 [1:12:05<4:40:21, 105.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.44s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.72s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.50s/it]
# Processing Samples:  21%|██        | 42/200 [1:13:51<4:38:19, 105.69s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:19, 16.00s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.16s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.76s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.36s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.34s/it]
# Processing Samples:  22%|██▏       | 43/200 [1:15:36<4:36:36, 105.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.19s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:18, 18.18s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.57s/it]
# Processing Samples:  22%|██▏       | 44/200 [1:17:20<4:32:56, 104.98s/it]
# Converged after 445 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.82s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.30s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.88s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.36s/it]
# Processing Samples:  22%|██▎       | 45/200 [1:19:06<4:32:02, 105.31s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.19s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.04s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.13s/it]
# Processing Samples:  23%|██▎       | 46/200 [1:20:52<4:30:56, 105.56s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.32s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.91s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.87s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.02s/it]
# Processing Samples:  24%|██▎       | 47/200 [1:22:38<4:29:52, 105.83s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:17, 15.58s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.27s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.70s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.86s/it]
# Processing Samples:  24%|██▍       | 48/200 [1:24:24<4:27:55, 105.76s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:27, 17.59s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:12, 18.14s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.55s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.42s/it]
# Processing Samples:  24%|██▍       | 49/200 [1:26:12<4:27:54, 106.45s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.77s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.05s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:50, 17.00s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.16s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.80s/it]
# Processing Samples:  25%|██▌       | 50/200 [1:28:00<4:27:14, 106.90s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.72s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.13s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.42s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.77s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.21s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.61s/it]
# Processing Samples:  26%|██▌       | 51/200 [1:29:46<4:24:27, 106.50s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.07s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.33s/it]
# Converged after 496 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.32s/it]
# Processing Samples:  26%|██▌       | 52/200 [1:31:32<4:22:18, 106.34s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.83s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.22s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.07s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.95s/it]
# Converged after 476 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.98s/it]
# Processing Samples:  26%|██▋       | 53/200 [1:33:16<4:19:17, 105.83s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.14s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.45s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.98s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.06s/it]
# Processing Samples:  27%|██▋       | 54/200 [1:35:02<4:17:22, 105.77s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:17, 15.51s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:04, 16.04s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.29s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.97s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.86s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.99s/it]
# Processing Samples:  28%|██▊       | 55/200 [1:36:47<4:15:01, 105.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.19s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.94s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.93s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.82s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.01s/it]
# Processing Samples:  28%|██▊       | 56/200 [1:38:33<4:13:56, 105.81s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.96s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:06, 16.55s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.80s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.59s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.67s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.85s/it]
# Processing Samples:  28%|██▊       | 57/200 [1:40:19<4:11:57, 105.71s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:34, 18.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.77s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.38s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.41s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.56s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:49<00:00, 19.03s/it]
# Processing Samples:  29%|██▉       | 58/200 [1:42:09<4:13:13, 107.00s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.97s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.18s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.73s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.46s/it]
# Processing Samples:  30%|██▉       | 59/200 [1:43:55<4:10:36, 106.64s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.33s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.22s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.36s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.37s/it]
# Processing Samples:  30%|███       | 60/200 [1:45:41<4:08:44, 106.60s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.16s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.26s/it]
# Processing Samples:  30%|███       | 61/200 [1:47:28<4:07:08, 106.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.25s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.13s/it]
# Processing Samples:  31%|███       | 62/200 [1:49:15<4:05:37, 106.79s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:19<01:37, 19.48s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:10, 17.74s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:52, 17.41s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:34, 17.42s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.56s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:50<00:00, 19.02s/it]
# Processing Samples:  32%|███▏      | 63/200 [1:51:05<4:06:08, 107.80s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.54s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.78s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.44s/it]
# Processing Samples:  32%|███▏      | 64/200 [1:52:51<4:03:04, 107.24s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.10s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.38s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.85s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.46s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.45s/it]
# Processing Samples:  32%|███▎      | 65/200 [1:54:38<4:00:48, 107.03s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.31s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.50s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.76s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:11<00:36, 18.50s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.24s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.29s/it]
# Processing Samples:  33%|███▎      | 66/200 [1:56:25<3:59:14, 107.13s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:06, 16.50s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:54, 18.12s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.82s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.85s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.72s/it]
# Processing Samples:  34%|███▎      | 67/200 [1:58:11<3:56:29, 106.69s/it]
# Converged after 467 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.11s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.92s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.72s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.58s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.62s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.76s/it]
# Processing Samples:  34%|███▍      | 68/200 [1:59:56<3:54:10, 106.44s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.72s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.93s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.33s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.44s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.55s/it]
# Processing Samples:  34%|███▍      | 69/200 [2:01:45<3:53:31, 106.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.86s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.90s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.10s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:41<00:00, 16.63s/it]
# Processing Samples:  35%|███▌      | 70/200 [2:03:26<3:47:59, 105.22s/it]
# Converged after 401 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:23, 16.68s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.83s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.35s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.40s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.48s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.01s/it]
# Processing Samples:  36%|███▌      | 71/200 [2:05:09<3:44:58, 104.64s/it]
# Converged after 423 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:11, 17.84s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.80s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.72s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.73s/it]
# Processing Samples:  36%|███▌      | 72/200 [2:06:58<3:45:58, 105.93s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:25, 17.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.85s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.89s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.12s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.39s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.88s/it]
# Processing Samples:  36%|███▋      | 73/200 [2:08:46<3:45:27, 106.52s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.49s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.80s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.34s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.23s/it]
# Processing Samples:  37%|███▋      | 74/200 [2:10:32<3:43:07, 106.25s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.04s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.22s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:05<00:33, 16.59s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:18, 18.10s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 18.07s/it]
# Processing Samples:  38%|███▊      | 75/200 [2:12:16<3:40:18, 105.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.85s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.10s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:48, 16.33s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:35, 17.64s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.92s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.94s/it]
# Processing Samples:  38%|███▊      | 76/200 [2:14:01<3:37:57, 105.46s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.80s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:04, 16.02s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.40s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:36, 18.06s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.11s/it]
# Processing Samples:  38%|███▊      | 77/200 [2:15:47<3:36:20, 105.53s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.26s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.71s/it]
# ...
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.56s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.89s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.43s/it]
# Processing Samples:  88%|████████▊ | 175/200 [5:09:07<44:47, 107.48s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.31s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.97s/it]
# Converged after 494 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.09s/it]
# Processing Samples:  88%|████████▊ | 176/200 [5:10:54<42:50, 107.09s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.99s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.20s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:52, 17.36s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.94s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.80s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.95s/it]
# Processing Samples:  88%|████████▊ | 177/200 [5:12:39<40:53, 106.68s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.17s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:09, 17.28s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.99s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.73s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.76s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:44<00:00, 17.42s/it]
# Processing Samples:  89%|████████▉ | 178/200 [5:14:24<38:55, 106.17s/it]
# Converged after 448 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:36<01:13, 18.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:53, 17.73s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.60s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.61s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 17.98s/it]
# Processing Samples:  90%|████████▉ | 179/200 [5:16:11<37:13, 106.37s/it]
# Converged after 480 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:18<01:33, 18.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:09, 17.49s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:51, 17.25s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:34, 17.27s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.40s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:49<00:00, 18.90s/it]
# Processing Samples:  90%|█████████ | 180/200 [5:18:00<35:43, 107.17s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.17s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.32s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:50, 16.67s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.98s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.52s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.45s/it]
# Processing Samples:  90%|█████████ | 181/200 [5:19:47<33:53, 107.04s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.24s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.36s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.47s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.14s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:24<00:17, 17.22s/it]
# Converged after 437 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:43<00:00, 17.72s/it]
# Processing Samples:  91%|█████████ | 182/200 [5:21:30<31:47, 105.99s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.08s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.21s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:34, 17.07s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.27s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.26s/it]
# Processing Samples:  92%|█████████▏| 183/200 [5:23:16<30:01, 105.96s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.17s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.32s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.58s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.19s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.00s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.15s/it]
# Processing Samples:  92%|█████████▏| 184/200 [5:25:03<28:16, 106.05s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.20s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:53<00:54, 18.17s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.85s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.71s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.76s/it]
# Processing Samples:  92%|█████████▎| 185/200 [5:26:49<26:30, 106.03s/it]
# Converged after 486 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.13s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:13, 18.33s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.54s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.60s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.43s/it]
# Processing Samples:  93%|█████████▎| 186/200 [5:28:37<24:52, 106.61s/it]
# Converged after 498 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:29, 17.93s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:08, 17.17s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:51, 17.05s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.21s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.38s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.87s/it]
# Processing Samples:  94%|█████████▎| 187/200 [5:30:25<23:12, 107.14s/it]
# Converged after 495 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.14s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.31s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.60s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.93s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.47s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.42s/it]
# Processing Samples:  94%|█████████▍| 188/200 [5:32:11<21:23, 106.95s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.90s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:31<01:03, 15.87s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:48<00:49, 16.34s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:36, 18.03s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:18, 18.03s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.17s/it]
# Processing Samples:  94%|█████████▍| 189/200 [5:33:57<19:32, 106.59s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.31s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.47s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:54, 18.02s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.98s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.96s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.14s/it]
# Processing Samples:  95%|█████████▌| 190/200 [5:35:44<17:47, 106.75s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.64s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:52, 17.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:35, 17.52s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.66s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.81s/it]
# Processing Samples:  96%|█████████▌| 191/200 [5:37:33<16:06, 107.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:24, 16.94s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:33<01:07, 16.75s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:50<00:50, 16.86s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.99s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.29s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.84s/it]
# Processing Samples:  96%|█████████▌| 192/200 [5:39:21<14:19, 107.40s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:19, 15.88s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.41s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.65s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.92s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:18, 18.51s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.49s/it]
# Processing Samples:  96%|█████████▋| 193/200 [5:41:07<12:30, 107.21s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.21s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.42s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.61s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:36, 18.18s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.90s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.86s/it]
# Processing Samples:  97%|█████████▋| 194/200 [5:42:53<10:40, 106.67s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.06s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.14s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.62s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:09<00:36, 18.13s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.97s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 17.97s/it]
# Processing Samples:  98%|█████████▊| 195/200 [5:44:38<08:51, 106.34s/it]
# Converged after 491 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:20, 16.09s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.25s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:54, 18.14s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.78s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:27<00:17, 17.82s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:46<00:00, 18.03s/it]
# Processing Samples:  98%|█████████▊| 196/200 [5:46:25<07:05, 106.36s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.29s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:35<01:12, 18.23s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:52<00:53, 17.70s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:10<00:35, 17.65s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:28<00:17, 17.73s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:48<00:00, 18.49s/it]
# Processing Samples:  98%|█████████▊| 197/200 [5:48:13<05:20, 106.97s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:17<01:28, 17.70s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:34<01:07, 16.91s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:51<00:50, 16.93s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:08<00:34, 17.08s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.31s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:47<00:00, 18.81s/it]
# Processing Samples:  99%|█████████▉| 198/200 [5:50:01<03:34, 107.22s/it]
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:16<01:21, 16.25s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:05, 16.39s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.66s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:07<00:33, 16.95s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:26<00:17, 17.77s/it]
# Converged after 478 iterations
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.10s/it]
# Processing Samples: 100%|█████████▉| 199/200 [5:51:46<01:46, 106.58s/it]
# Converged after 470 iterations
# Processing Pilot Length Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Pilot Length Levels:  17%|█▋        | 1/6 [00:15<01:18, 15.63s/it]
# Processing Pilot Length Levels:  33%|███▎      | 2/6 [00:32<01:04, 16.09s/it]
# Processing Pilot Length Levels:  50%|█████     | 3/6 [00:49<00:49, 16.52s/it]
# Processing Pilot Length Levels:  67%|██████▋   | 4/6 [01:06<00:33, 16.87s/it]
# Processing Pilot Length Levels:  83%|████████▎ | 5/6 [01:25<00:17, 17.70s/it]
# Processing Pilot Length Levels: 100%|██████████| 6/6 [01:45<00:00, 18.46s/it]
# Processing Samples: 100%|██████████| 200/200 [5:53:32<00:00, 106.06s/it]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-sbl-snr-db-12-pilot-length-all-set-2.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length_array=pilot_length_array,
    snr_db=snr_db
)

print("All results have been saved")
# Out:
# All results have been saved
