# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')
data = np.load('/content/drive/My Drive/Github/mtc-device-activation/data/activity-models/e2-general-model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-theta.npz", allow_pickle=True)
all_theta = data["all_theta"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-gamma.npz", allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-z.npz", allow_pickle=True)
all_z = data["all_z"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-noise.npz", allow_pickle=True)
all_noise = data["all_noise"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-received-signal.npz", allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load("/content/drive/My Drive/Github/mtc-device-activation/data/communication-models/e2-communication-simulation-general.npz", allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 2
pilot_length=pilot_length_array[pilot_length_index]
# Out:
# Mounted at /content/drive

# %%
num_samples = 1000
sample_range = range(0, 1000)

# %% [markdown]
# Orthogonal Matching Pursuit (OMP)

# %%
def omp_algorithm(theta, y, sparsity_level, stopping_criterion=1e-4):
    L, N = theta.shape
    _, M = y.shape

    residual = y.copy()
    support = []

    for _ in range(sparsity_level):
        # Step 1: Compute proxy (theta^H * residual)
        proxy = theta.conj().T @ residual  # N x M
        row_energy = np.sum(np.abs(proxy)**2, axis=1)

        # Step 2: Exclude already selected atoms
        row_energy[support] = 0
        idx = np.argmax(row_energy)
        support.append(idx)

        # Step 3: Solve least squares on current support
        theta_s = theta[:, support]  # L x |S|
        x_temp, _, _, _ = np.linalg.lstsq(theta_s, y, rcond=None)  # |S| x M

        # Step 4: Update residual
        residual = y - theta_s @ x_temp

        # Step 5: Early stopping if residual is small
        if np.linalg.norm(residual) < stopping_criterion:
            break

    # Step 6: Final x_hat reconstruction
    x_hat = np.zeros((N, M), dtype=np.complex128)
    for i, idx in enumerate(support):
        x_hat[idx, :] = x_temp[i, :]  # x_temp already correct

    # Step 7: Binary gamma (1 if row is active)
    gamma = (np.linalg.norm(x_hat, axis=1) > 1e-6).astype(int)

    return x_hat, gamma

# %%
# Placeholder arrays for results
z_res = np.zeros((num_samples, len(snr_db_array), device_count, M), dtype=np.complex128)  # Z estimates
gamma_res = np.zeros((num_samples, len(snr_db_array), device_count), dtype=bool)  # Gamma support

hr_res = np.zeros((num_samples, len(snr_db_array)))         # HR
fr_res = np.zeros((num_samples, len(snr_db_array)))         # FR
srr_res = np.zeros((num_samples, len(snr_db_array)))        # SRR
precision_res = np.zeros((num_samples, len(snr_db_array)))  # Precision
recall_res = np.zeros((num_samples, len(snr_db_array)))     # Recall
f1_res = np.zeros((num_samples, len(snr_db_array)))         # F1
nmse_res = np.zeros((num_samples, len(snr_db_array)))       # NMSE

# %%
# Loop through each sample with an outer progress bar
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    theta = all_theta[sample_index, pilot_length_index, :pilot_length]
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]

    # Loop over each SNR level with an inner progress bar
    for snr_db_index in tqdm(range(len(snr_db_array)), desc="Processing SNR Levels", leave=False, position=1):
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]
        z = all_z[sample_index]
        snr_db = snr_db_array[snr_db_index]
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Apply SBL algorithm for the current sample and SNR level
        z_result, gamma_result = omp_algorithm(theta, received_signal, sparsity)

        # Zero-out results with low gamma values
        z_result[gamma_result <= 0.05] = 0
        z_res[sample_index, snr_db_index, :, :] = z_result
        gamma_result_bool = gamma_result > 0.05
        gamma_res[sample_index, snr_db_index, :] = gamma_result_bool

        # Compute number of active/inactive devices from ground truth
        active_devices = np.sum(gamma == 1)
        inactive_devices = np.sum(gamma == 0)

        # Hit rate: percentage of correctly identified active devices
        hr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 1)) / active_devices if active_devices > 0 else 0
        )

        # False alarm rate: percentage of inactive devices wrongly detected as active
        fr_res[sample_index, snr_db_index] = (
            100 * np.sum((gamma_result_bool == 1) & (gamma == 0)) / inactive_devices if inactive_devices > 0 else 0
        )

        # Support recovery rate: proportion of correctly identified active devices
        srr_res[sample_index, snr_db_index] = (
            np.sum((gamma_result_bool == 1) & (gamma == 1)) /
            (np.sum((gamma_result_bool == 1) & (gamma == 0)) + np.sum((gamma_result_bool == 0) & (gamma == 1)) + sparsity)
        )

        # Classification metrics: TP, FP, FN
        TP = np.sum((gamma_result_bool == 1) & (gamma == 1))
        FP = np.sum((gamma_result_bool == 1) & (gamma == 0))
        FN = np.sum((gamma_result_bool == 0) & (gamma == 1))

        # Precision: proportion of predicted active devices that are actually active
        precision_res[sample_index, snr_db_index] = TP / (TP + FP) if (TP + FP) > 0 else 0

        # Recall: proportion of actual active devices that are correctly identified
        recall_res[sample_index, snr_db_index] = TP / (TP + FN) if (TP + FN) > 0 else 0

        # F1 Score: harmonic mean of precision and recall
        if (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index]) > 0:
            f1_res[sample_index, snr_db_index] = (
                2 * precision_res[sample_index, snr_db_index] * recall_res[sample_index, snr_db_index]
                /
                (precision_res[sample_index, snr_db_index] + recall_res[sample_index, snr_db_index])
            )
        else:
            f1_res[sample_index, snr_db_index] = 0

        # Normalized Mean Squared Error: compares estimated and true z vectors for active devices
        nmse_res[sample_index, snr_db_index] = (
            np.linalg.norm(z[gamma == 1] - z_result[gamma == 1])**2 / np.linalg.norm(z[gamma == 1])**2
        )
# Out:
# Processing Samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   0%|          | 3/1000 [00:00<00:36, 27.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 8/1000 [00:00<00:28, 35.13it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   1%|          | 12/1000 [00:00<00:26, 37.08it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 16/1000 [00:00<00:25, 37.90it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 20/1000 [00:00<00:26, 36.40it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   2%|▏         | 24/1000 [00:00<00:26, 37.27it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 28/1000 [00:00<00:26, 37.28it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   3%|▎         | 32/1000 [00:00<00:25, 37.57it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▎         | 36/1000 [00:00<00:25, 38.07it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 40/1000 [00:01<00:26, 36.67it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   4%|▍         | 44/1000 [00:01<00:25, 37.36it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   5%|▍         | 48/1000 [00:01<00:25, 37.08it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   5%|▌         | 52/1000 [00:01<00:25, 37.25it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▌         | 56/1000 [00:01<00:25, 36.81it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▌         | 60/1000 [00:01<00:25, 37.17it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   6%|▋         | 64/1000 [00:01<00:25, 37.41it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   7%|▋         | 68/1000 [00:01<00:27, 34.27it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   7%|▋         | 72/1000 [00:02<00:28, 32.63it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 76/1000 [00:02<00:30, 30.59it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 80/1000 [00:02<00:30, 30.22it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 84/1000 [00:02<00:30, 29.92it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   9%|▉         | 88/1000 [00:02<00:30, 30.13it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:   9%|▉         | 92/1000 [00:02<00:29, 30.34it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|▉         | 96/1000 [00:02<00:29, 30.39it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|█         | 100/1000 [00:02<00:28, 31.09it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  10%|█         | 104/1000 [00:03<00:28, 31.65it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  11%|█         | 108/1000 [00:03<00:28, 31.26it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  11%|█         | 112/1000 [00:03<00:31, 28.64it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 115/1000 [00:03<00:30, 28.79it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 119/1000 [00:03<00:29, 29.72it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  12%|█▏        | 123/1000 [00:03<00:28, 30.34it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  13%|█▎        | 127/1000 [00:03<00:29, 30.04it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  13%|█▎        | 131/1000 [00:03<00:28, 30.81it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▎        | 135/1000 [00:04<00:28, 30.33it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 139/1000 [00:04<00:30, 28.21it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 142/1000 [00:04<00:30, 27.98it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  14%|█▍        | 145/1000 [00:04<00:31, 27.43it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  15%|█▍        | 148/1000 [00:04<00:31, 27.17it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  15%|█▌        | 151/1000 [00:04<00:30, 27.69it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  15%|█▌        | 154/1000 [00:04<00:32, 26.36it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▌        | 157/1000 [00:04<00:31, 26.61it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▌        | 160/1000 [00:05<00:31, 26.54it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  16%|█▋        | 163/1000 [00:05<00:31, 26.66it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  17%|█▋        | 166/1000 [00:05<00:32, 25.49it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  17%|█▋        | 169/1000 [00:05<00:31, 26.30it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  17%|█▋        | 173/1000 [00:05<00:28, 29.19it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 177/1000 [00:05<00:26, 31.06it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 181/1000 [00:05<00:25, 32.61it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  18%|█▊        | 185/1000 [00:05<00:24, 33.22it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  19%|█▉        | 189/1000 [00:05<00:24, 33.27it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  19%|█▉        | 193/1000 [00:06<00:24, 33.62it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|█▉        | 197/1000 [00:06<00:23, 34.16it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|██        | 201/1000 [00:06<00:23, 34.25it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  20%|██        | 205/1000 [00:06<00:23, 33.28it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  21%|██        | 209/1000 [00:06<00:23, 33.50it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  21%|██▏       | 213/1000 [00:06<00:22, 34.37it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▏       | 217/1000 [00:06<00:22, 34.96it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▏       | 221/1000 [00:06<00:22, 35.30it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  22%|██▎       | 225/1000 [00:07<00:21, 35.47it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  23%|██▎       | 229/1000 [00:07<00:21, 35.42it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  23%|██▎       | 233/1000 [00:07<00:22, 34.81it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▎       | 237/1000 [00:07<00:21, 34.90it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▍       | 241/1000 [00:07<00:22, 33.19it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  24%|██▍       | 245/1000 [00:07<00:22, 33.89it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  25%|██▍       | 249/1000 [00:07<00:22, 33.80it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  25%|██▌       | 253/1000 [00:07<00:22, 33.82it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▌       | 257/1000 [00:07<00:22, 33.61it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▌       | 261/1000 [00:08<00:21, 34.14it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  26%|██▋       | 265/1000 [00:08<00:21, 34.32it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  27%|██▋       | 269/1000 [00:08<00:21, 34.58it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  27%|██▋       | 273/1000 [00:08<00:20, 34.76it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 277/1000 [00:08<00:21, 33.67it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 281/1000 [00:08<00:20, 34.30it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  28%|██▊       | 285/1000 [00:08<00:20, 34.24it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  29%|██▉       | 289/1000 [00:08<00:20, 33.96it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  29%|██▉       | 293/1000 [00:09<00:21, 33.41it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|██▉       | 297/1000 [00:09<00:21, 33.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 301/1000 [00:09<00:21, 32.96it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  30%|███       | 305/1000 [00:09<00:21, 32.65it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███       | 309/1000 [00:09<00:22, 31.22it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  31%|███▏      | 313/1000 [00:09<00:21, 31.55it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 317/1000 [00:09<00:21, 31.48it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▏      | 321/1000 [00:09<00:21, 31.68it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  32%|███▎      | 325/1000 [00:10<00:21, 31.88it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 329/1000 [00:10<00:20, 32.00it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  33%|███▎      | 333/1000 [00:10<00:20, 31.90it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▎      | 337/1000 [00:10<00:20, 32.08it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▍      | 341/1000 [00:10<00:21, 30.84it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  34%|███▍      | 345/1000 [00:10<00:21, 31.13it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  35%|███▍      | 349/1000 [00:10<00:20, 31.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  35%|███▌      | 353/1000 [00:10<00:20, 32.05it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▌      | 357/1000 [00:11<00:20, 31.56it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▌      | 361/1000 [00:11<00:19, 32.18it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  36%|███▋      | 365/1000 [00:11<00:19, 32.49it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  37%|███▋      | 369/1000 [00:11<00:19, 32.30it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  37%|███▋      | 373/1000 [00:11<00:19, 32.40it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 377/1000 [00:11<00:20, 30.82it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 381/1000 [00:11<00:20, 30.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  38%|███▊      | 385/1000 [00:11<00:19, 30.75it/s]
# ...
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  87%|████████▋ | 874/1000 [00:28<00:04, 31.37it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  88%|████████▊ | 878/1000 [00:28<00:03, 31.56it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  88%|████████▊ | 882/1000 [00:28<00:03, 31.71it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  89%|████████▊ | 886/1000 [00:28<00:03, 30.96it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  89%|████████▉ | 890/1000 [00:28<00:03, 30.85it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  89%|████████▉ | 894/1000 [00:28<00:03, 31.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  90%|████████▉ | 898/1000 [00:28<00:03, 30.92it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  90%|█████████ | 902/1000 [00:28<00:03, 31.19it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  91%|█████████ | 906/1000 [00:29<00:03, 30.77it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  91%|█████████ | 910/1000 [00:29<00:02, 31.02it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  91%|█████████▏| 914/1000 [00:29<00:02, 30.45it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 918/1000 [00:29<00:02, 29.71it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 921/1000 [00:29<00:02, 29.29it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  92%|█████████▏| 924/1000 [00:29<00:02, 29.18it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 927/1000 [00:29<00:02, 27.48it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 930/1000 [00:29<00:02, 26.84it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  93%|█████████▎| 933/1000 [00:30<00:02, 26.83it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▎| 936/1000 [00:30<00:02, 27.07it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 939/1000 [00:30<00:02, 26.68it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 942/1000 [00:30<00:02, 27.20it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  94%|█████████▍| 945/1000 [00:30<00:01, 27.90it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  95%|█████████▍| 949/1000 [00:30<00:01, 29.42it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  95%|█████████▌| 952/1000 [00:30<00:01, 29.48it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 955/1000 [00:30<00:01, 29.22it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 958/1000 [00:30<00:01, 28.49it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▌| 961/1000 [00:31<00:01, 26.85it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  96%|█████████▋| 964/1000 [00:31<00:01, 26.47it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  97%|█████████▋| 968/1000 [00:31<00:01, 28.40it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  97%|█████████▋| 971/1000 [00:31<00:01, 28.46it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  97%|█████████▋| 974/1000 [00:31<00:00, 27.64it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  98%|█████████▊| 977/1000 [00:31<00:00, 25.75it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  98%|█████████▊| 980/1000 [00:31<00:00, 26.32it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  98%|█████████▊| 984/1000 [00:31<00:00, 27.72it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▊| 987/1000 [00:31<00:00, 27.82it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▉| 991/1000 [00:32<00:00, 29.10it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples:  99%|█████████▉| 994/1000 [00:32<00:00, 29.24it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|█████████▉| 997/1000 [00:32<00:00, 29.15it/s]
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Processing SNR Levels:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Samples: 100%|██████████| 1000/1000 [00:32<00:00, 30.82it/s]

# %%
# Compute the average across all samples for each SNR level
avg_hr = np.mean(hr_res, axis=0)         # HR
avg_srr = np.mean(srr_res, axis=0)       # SRR
avg_fr = np.mean(fr_res, axis=0)         # FR
avg_pr = np.mean(precision_res, axis=0)  # Precision
avg_re = np.mean(recall_res, axis=0)     # Recall
avg_f1 = np.mean(f1_res, axis=0)         # F1
avg_nmse = np.mean(nmse_res, axis=0)     # NMSE

# %%
np.savez_compressed(
    '/content/drive/My Drive/Github/mtc-device-activation/data/results/e2-results-1000-omp-snr-db-all-pilot-length-30.npz',
    z_res=z_res,
    gamma_res=gamma_res,
    hr_res=hr_res,
    fr_res=fr_res,
    srr_res=srr_res,
    precision_res=precision_res,
    recall_res=recall_res,
    f1_res=f1_res,
    nmse_res=nmse_res,
    avg_hr=avg_hr,
    avg_fr=avg_fr,
    avg_srr=avg_srr,
    avg_pr=avg_pr,
    avg_re=avg_re,
    avg_f1=avg_f1,
    avg_nmse=avg_nmse,
    pilot_length=pilot_length,
    snr_db_array=snr_db_array
)

print("All results have been saved")
# Out:
# All results have been saved
